# %%
from complextree import *

# %%
print("Welcome to Yifei Sun's final project for SI 507!")
print("Here you will explore languages and linguistics using trees and graphs.")
print("Here I have prepared 5 language family for you to explore:")
exit = False
while exit!= True:
    print("Press 1 for Indo-European languages")
    print("Press 2 for Sino-Tibetan languages")
    print("Press 3 for Altaic languages")
    print("Press 4 for Uralic languages")
    print("Press 5 for Afroasiatic languages")
    print("Press 6 to exit")
    answer_1 = int(input("Which language family do you want to explore?"))
    if answer_1 == 1:
        json = "Indo-European language data.json"
    elif answer_1 == 2:
        json = "Sino-Tibetan language data.json"
    elif answer_1 == 3:
        json = "Altaic language data.json"
    elif answer_1 == 4:
        json = "Uralic language data.json"
    elif answer_1 == 5:
        json = "Afroasiatic language data.json"
    elif answer_1 == 6:
        print("Thank you for playing this game!")
        exit = True
    else:
        print("Your choice does not exist! Please try agian!")
    if answer_1 in [1,2,3,4,5]:
        lang_tree = create_tree(json)
        class_simple_lang_tree = creat_simple_tree(json,status="classification")
        proto_simple_lang_tree = creat_simple_tree(json,status="proto")
        exit_2 = False
        while exit_2!=True:
            print("Here you have two options: show the whole tree or only a part of the tree")
            print("Show the whole linguistic tree for "+json.split(" ")[0]+", please press 1")
            print("Show the a part of the linguistic tree for "+json.split(" ")[0]+", please press 2")
            print("If you want exit from this language family, please press 3")
            answer_2 = int(input("Do you want to explore the whole tree or only part of it, or exit?"))
            if answer_2 == 3:
                exit_2 = True
                break
            answer_3 = int(input("Press 1 to show linguistic classification tree\nPress 2 to show Proto language tree"))
            if answer_3 == 1:
                status="classification"
            elif answer_3 == 2:
                status="proto"
            else:
                print("This is not a valid answer")
            if answer_2 == 1:
                show_simple_tree(json,status)
            elif answer_2 == 2:
                answer_6 = int(input("Do you want to search the language tree for a language or linguistic unit? Press 1 for Yes, 2 for No"))
                if answer_6 == 1:
                    lang = input("Please enter the name of the language or linguistic unit that you want to search")
                    answer_7 = int(input("Press 1 if you want simple information\nPress 2 if you want detailed information"))
                    if answer_7 == 1:
                        class_simple_lang_tree.searchLang(lang)
                    elif answer_7 == 2:
                        lang_tree.searchLang(lang)
                    else:
                        print("This not a balid answer")
                    answer_8 = int(input("Do you want to show the lineage of that language?\nPress 1 for Yes\nPress 2 for No"))       
                    if answer_8 == 1:
                        answer_9 = int(input("Press 1 for short information\nPress 2 for detailed information"))
                        if answer_9 == 1:
                            try:
                                find_lineage(json,lang,status,form="short")   
                            except:
                                print("That language you entered does not exist in the tree, probably a misspelling")
                        elif answer_9 == 2:
                            try:
                                find_lineage(json,lang,status,form="long") 
                            except:
                                print("That language you entered does not exist in the tree, probably a misspelling")
                        else:
                            print("This not a valid answer")
                    elif answer_8 == 2:
                        pass
                elif answer_6 == 2: 
                    pass
                else:
                    print("This not a valid answer")
                answer_4 = input("Which sub-branch do you want to explore?")
                answer_5 = int(input("Press 1 for simple tree\nPress 2 for complex tree"))
                if answer_5 == 1:
                    try:
                        show_simple_tree(json,status,start=answer_4)
                    except:
                        print("The branch you enter does not exist. Maybe it is a misspelling. Please check again.")
                elif answer_5 == 2:
                    try:
                        show_complex_tree(json,status,start=answer_4)
                    except:
                        print("The branch you enter does not exist. Maybe it is a misspelling. Please check again.")
                else:
                    print("This is not a valid answer")
            else:
                print("This is not a valid answer")
# Out:
# Welcome to Yifei Sun's final project for SI 507!
# Here you will explore languages and linguistics using trees and graphs.
# Here I have prepared 5 language family for you to explore:
# Press 1 for Indo-European languages
# Press 2 for Sino-Tibetan languages
# Press 3 for Altaic languages
# Press 4 for Uralic languages
# Press 5 for Afroasiatic languages
# Press 6 to exit
# Which language family do you want to explore?4
# Here you have two options: show the whole tree or only a part of the tree
# Show the whole linguistic tree for Uralic, please press 1
# Show the a part of the linguistic tree for Uralic, please press 2
# If you want exit from this language family, please press 3
# Do you want to explore the whole tree or only part of it, or exit?1
# Press 1 to show linguistic classification tree
# Press 2 to show Proto language tree1
# Show the linguistic tree of Uralic languages......
# 85 languages haven't been added.
# 32 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Uralic
# ├── Finno-Samic
# ├── Finno-Ugric
# │   ├── Finno-Permic
# │   │   ├── Finnic
# │   │   │   ├── Meryan
# │   │   │   ├── Northern Finnic
# │   │   │   │   ├── Finnish
# │   │   │   │   │   ├── Ingrian Finnish
# │   │   │   │   │   ├── Kven
# │   │   │   │   │   ├── Meänkieli
# │   │   │   │   │   ├── Rauma dialect
# │   │   │   │   │   └── Värmland Finnish dialect
# │   │   │   │   ├── Ingrian
# │   │   │   │   ├── Karelian
# │   │   │   │   │   └── Livvi-Karelian
# │   │   │   │   ├── Ludic
# │   │   │   │   └── Veps
# │   │   │   ├── South Estonian
# │   │   │   │   ├── Kraasna
# │   │   │   │   ├── Leivu
# │   │   │   │   ├── Ludza
# │   │   │   │   └── Võro
# │   │   │   │       └── Seto
# │   │   │   └── Southern Finnic
# │   │   │       ├── Estonian
# │   │   │       ├── Livonian
# │   │   │       │   ├── Courland
# │   │   │       │   └── Salaca
# │   │   │       └── Votic
# │   │   │           ├── Krevinian
# │   │   │           └── Kukkuzi
# │   │   ├── Finno-Volgaic
# │   │   │   └── Mordvinic
# │   │   │       ├── Erzya
# │   │   │       ├── Meshchera
# │   │   │       └── Moksha
# │   │   ├── Mari
# │   │   │   ├── Meadow Mari
# │   │   │   └── Western Mari
# │   │   │       ├── Hill Mari
# │   │   │       └── Northwestern Mari
# │   │   ├── Permic
# │   │   │   ├── Komi language
# │   │   │   │   └── Komi-Yodz
# │   │   │   ├── Permyak
# │   │   │   └── Udmurt
# │   │   └── Sámi
# │   │       ├── Akkala Sámi
# │   │       ├── Inari Sámi
# │   │       ├── Kainuu Sámi
# │   │       ├── Kemi Sámi
# │   │       ├── Lule Sámi
# │   │       ├── Northern Sámi
# │   │       ├── Peninsula
# │   │       │   └── Kildin Sámi
# │   │       ├── Pite Sámi
# │   │       ├── Skolt Sámi
# │   │       ├── Southern Sámi
# │   │       ├── Ter Sámi
# │   │       └── Ume Sámi
# │   └── Ugric
# │       ├── Hungarian
# │       └── Ob-Ugric
# │           ├── Khanty
# │           │   ├── Far Eastern
# │           │   ├── Northern Khanty
# │           │   ├── Southern Khanty
# │           │   └── Surgut
# │           └── Mansi
# │               ├── Eastern Mansi
# │               ├── Northern Mansi
# │               ├── Southern Mansi
# │               └── Western Mansi
# └── Samoyedic
#     ├── Core Samoyedic
#     │   └── Kamas–Selkup
#     │       ├── Kamassian
#     │       │   └── Koibal
#     │       └── Selkup
#     ├── Enets
#     │   └── Nenets
#     │       ├── Forest Nenets
#     │       └── Tundra Nenets
#     ├── Enets–Nenets
#     │   └── Yurats
#     ├── Mator
#     │   ├── Karagas
#     │   └── Taygi
#     └── Nganasan
#         ├── Avam
#         └── Vadey
#
# Here you have two options: show the whole tree or only a part of the tree
# Show the whole linguistic tree for Uralic, please press 1
# Show the a part of the linguistic tree for Uralic, please press 2
# If you want exit from this language family, please press 3
# Do you want to explore the whole tree or only part of it, or exit?3
# Press 1 for Indo-European languages
# Press 2 for Sino-Tibetan languages
# Press 3 for Altaic languages
# Press 4 for Uralic languages
# Press 5 for Afroasiatic languages
# Press 6 to exit
# Which language family do you want to explore?2
# Here you have two options: show the whole tree or only a part of the tree
# Show the whole linguistic tree for Sino-Tibetan, please press 1
# Show the a part of the linguistic tree for Sino-Tibetan, please press 2
# If you want exit from this language family, please press 3
# Do you want to explore the whole tree or only part of it, or exit?2
# Press 1 to show linguistic classification tree
# Press 2 to show Proto language tree1
# Do you want to search the language tree for a language or linguistic unit? Press 1 for Yes, 2 for No2
# Which sub-branch do you want to explore?Chinese
# Press 1 for simple tree
# Press 2 for complex tree1
# Show the linguistic tree of Chinese languages......
# 9 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Chinese
# ├── Mandarin
# │   ├── Beijing
# │   ├── Central Plains
# │   ├── Jiao–Liao
# │   ├── Ji–Lu
# │   ├── Lan–Yin
# │   ├── Lower Yangtze
# │   ├── Northeastern Mandarin
# │   └── Southwestern Mandarin
# │       └── Wu-Tian
# │           └── Wuhan dialect
# ├── Min
# │   └── Coastal Min
# │       └── Southern Min
# ├── Wu
# │   └── Taizhou Wu
# │       └── Taizhou
# │           └── Tiantai Dialect
# ├── Xiang
# │   ├── Chen-Xu Xiang
# │   ├── Hengzhou Xiang
# │   ├── New Xiang
# │   ├── Old Xiang
# │   └── Yong-Quan Xiang
# ├── Xiangnan Tuhua
# └── Yue
#     ├── Gao–Yang
#     ├── Gou–Lou
#     ├── Qin–Lian
#     ├── Siyiincl. Taishanese
#     ├── Wu–Hua
#     ├── Yong–Xun
#     ├── Yuehai
#     │   ├── Cantonese
#     │   │   ├── Hong Kong
#     │   │   ├── Hong Kong Cantonese
#     │   │   ├── Malaysian
#     │   │   └── Xiguan
#     │   ├── Guanbao
#     │   ├── Guangfu
#     │   ├── Guan–Bao
#     │   │   └── Weitou dialect
#     │   ├── Sanyi
#     │   └── Xiangshan
#     └── Yuehaiincl. Cantonese
#
# Here you have two options: show the whole tree or only a part of the tree
# Show the whole linguistic tree for Sino-Tibetan, please press 1
# Show the a part of the linguistic tree for Sino-Tibetan, please press 2
# If you want exit from this language family, please press 3
# Do you want to explore the whole tree or only part of it, or exit?3
# Press 1 for Indo-European languages
# Press 2 for Sino-Tibetan languages
# Press 3 for Altaic languages
# Press 4 for Uralic languages
# Press 5 for Afroasiatic languages
# Press 6 to exit
# Which language family do you want to explore?6
# Thank you for playing this game!

# %%
print("Search a language or linguistic unit")
exit = False
tree_list = []
class_simple_tree_list = []
proto_simple_tree_list = []
json_list = ["Indo-European language data.json","Sino-Tibetan language data.json","Altaic language data.json",\
             "Uralic language data.json","Afroasiatic language data.json"]
for json in json_list:   
    lang_tree = create_tree(json)
    tree_list.append(lang_tree)
    class_simple_lang_tree = creat_simple_tree(json,status="classification")
    class_simple_tree_list.append(class_simple_lang_tree)
    proto_simple_lang_tree = creat_simple_tree(json,status="proto")
    proto_simple_tree_list.append(proto_simple_lang_tree)
while exit!= True:
    answer_1 = input("Enter a keyword that you would like to search, or press 1 to exit")
    try:
        if int(answer_1) == 1:
            print("Thank you for playing this game!")
            exit=True
    except:
        answer_2 = input("Press 1 for detailed information\nPress 2 for simple information")
        if int(answer_2)==1:
            for lang_tree in tree_list:
                lang_tree.searchLang(answer_1)
            answer_3 = input("Do you want to show the lineage of the language?\nPress 1 for Yes\nPress 2 for No")
            answer_4 = input("Do you want to show the linguistic classification lineage or Proto language lineage of the language?\nPress 1 for linguistic classification\nPress Proto language for No")
            if int(answer_4)==1:
                status="classification"
            elif int(answer_4)==2:
                status="proto"
            if int(answer_3)==1:
                try:
                    for json in json_list:
                        find_lineage(json,answer_1,status=status,form="long")
                except:
                    print("The name of the language you entered does not exist. May be a misspelling. Please try again!")
            elif int(answer_3)==2:
                print("Thank you for playing this game!")
                exit=True
        elif int(answer_2)==2:
            for lang_tree in class_simple_tree_list:
                lang_tree.searchLang(answer_1)
            answer_3 = input("Do you want to show the lineage of the language?\nPress 1 for Yes\nPress 2 for No")
            answer_4 = input("Do you want to show the linguistic classification lineage or Proto language lineage of the language?\nPress 1 for linguistic classification\nPress Proto language for No")
            if int(answer_4)==1:
                status="classification"
            elif int(answer_4)==2:
                status="proto"
            if int(answer_3)==1:
                try:
                    for json in json_list:
                        find_lineage(json,answer_1,status=status,form="short")
                except:
                    print("The name of the language you entered does not exist. May be a misspelling. Please try again!")
            elif int(answer_3)==2:
                print("Thank you for playing this game!")
                exit=True
# Out:
# Search a language or linguistic unit
# Enter a keyword that you would like to search, or press 1 to exitsinitic
# Press 1 for detailed information
# Press 2 for simple information1
# English Name: Sinitic
# URL: https://en.wikipedia.org/wiki/Sinitic_languages
# Other Names: Chinese
# Status: Normal
# Ethnicity: Sinitic peoples
# Geographic distribution: Greater China, Singapore, Christmas Island, Han diaspora communities, Ferghana Valley (Uzbekistan) and Chu Valley (Kyrgyzstan) (Dungans), Russian Far East (Tazs)
# Linguistic classification: Sino-Tibetan ——> Sinitic
# Proto-language: Proto-Sinitic
# Subdivisions: Chinese, Greater Bai
# Linguistic classification corrected: Sino-Tibetan ——> Sinitic
# Proto-language corrected: Proto-Sinitic
# Subdivisions corrected: Chinese, Greater Bai
# Related URLs: https://en.wikipedia.org/wiki/Sino-Tibetan_languages, https://en.wikipedia.org/wiki/Chinese_language, https://en.wikipedia.org/wiki/Greater_Bai_languages
# Proto-Language Parent:
# Proto-Language Children:
# Proto-Language Depth: 0
# Language Classification Parent: Sino-Tibetan
# Language Classification Children: Min, Chinese, Ba-Shu Chinese, Hakka, Mandarin, Wu, Yue, Greater Bai, Xiang, Gan, Tuhua, Badong Yao, Maihua, She, Waxiang, Yeheni, Old Chinese, Huizhou, Middle Chinese, Eastern Han Chinese, Classical Chinese, Cai–Long
# Language Classification Depth: 2
#
#
# Do you want to show the lineage of the language?
# Press 1 for Yes
# Press 2 for No1
# Do you want to show the linguistic classification lineage or Proto language lineage of the language?
# Press 1 for linguistic classification
# Press Proto language for No1
# The name of the language you entered does not exist. May be a misspelling. Please try again!
# Enter a keyword that you would like to search, or press 1 to exit1
# Thank you for playing this game!

# %%
print("Find the lineage of a language or linguistic unit")
exit = False
tree_list = []
class_simple_tree_list = []
proto_simple_tree_list = []
json_list = ["Indo-European language data.json","Sino-Tibetan language data.json","Altaic language data.json",\
             "Uralic language data.json","Afroasiatic language data.json"]
while exit!= True:
    answer_1 = input("Enter a language or linguistic unit that you would like to search, or press 1 to exit")
    try:
        if int(answer_1) == 1:
            print("Thank you for playing this game!")
            exit=True
    except:
        answer_4 = input("Do you want to show the linguistic classification lineage or Proto language lineage of the language?\nPress 1 for linguistic classification\nPress Proto language for No")
        if int(answer_4)==1:
            status="classification"
        elif int(answer_4)==2:
            status="proto"
        answer_5 = input("Press 1 to get detailed information\nPress 2 to get simple information")
        if int(answer_5)==1:
            form="long"
        elif int(answer_5)==2:
            form="short"
        try:
            for json in json_list:
                find_lineage(json,answer_1,status=status,form=form)
        except:
            print("The name of the language you entered does not exist. May be a misspelling. Please try again!")
# Out:
# Find the lineage of a language or linguistic unit
# Enter a language or linguistic unit that you would like to search, or press 1 to exitGerman
# Do you want to show the linguistic classification lineage or Proto language lineage of the language?
# Press 1 for linguistic classification
# Press Proto language for No1
# Press 1 to get detailed information
# Press 2 to get simple information2
# Language Name: Indo-European
# Parent:
# Parents: {}
# Children: Germanic, Indo-Iranian, Balto-Slavic, Proto-Greek, Graeco-Phrygian, Albanian, Anatolian, Mixed language., Italo-Celtic, Armenic, Tocharian, Illyrian, Sicel, Dacian, Thracian, Paeonian, Liburnian, Classical Armenian, Cilician Armenian/Middle Armenian
#
# Language Name: Germanic
# Parent: Indo-European
# Parents: {'Indo-European': 1}
# Children: West Germanic, North Germanic, East Germanic, Proto-Norse
#
# Language Name: West Germanic
# Parent: Germanic
# Parents: {'Germanic': 1}
# Children: North Sea Germanic, Elbe Germanic, Weser-Rhine Germanic, Old High German
#
# Language Name: Elbe Germanic
# Parent: West Germanic
# Parents: {'West Germanic': 1}
# Children: High German dialects, Lombardic
#
# Language Name: High German dialects
# Parent: Elbe Germanic
# Parents: {'Elbe Germanic': 1, 'West Germanic': 1}
# Children: Central German, Middle German, Upper German, Standard High German, Yiddish, Texas German, German
#
# Language Name: German
# Parent: High German dialects
# Parents: {'Elbe Germanic': 1, 'High German dialects': 1, 'West Germanic': 1}
# Children: United States German, Brazilian German, Middle High German, Early New High German, New High German
#
# The name of the language you entered does not exist. May be a misspelling. Please try again!
# Enter a language or linguistic unit that you would like to search, or press 1 to exit1
# Thank you for playing this game!

# %%
print("Visualize the cluster of 242 languages")
exit = False
while exit!= True:
    answer_1 = input("Enter a similarity threshold\nLanguages that have smaller similarity distance value will be connected\nOr press 1 to exit")
    try:
        if int(answer_1) == 1:
            print("Thank you for playing this game!")
            exit=True
    except:
        lang_graph("new_language_distance_data_total.json","lang_list.json",threshold=float(answer_1))
# Out:
# Visualize the cluster of 242 languages
# Enter a similarity threshold
# Languages that have smaller similarity distance value will be connected
# Or press 1 to exit0.1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [22], in <cell line: 3>()
#       2 exit = False
#       3 while exit!= True:
# ----> 4     answer_1 = input("Enter a similarity threshold\nLanguages that have smaller similarity distance value will be connected\nOr press 1 to exit")
#       5     try:
#       6         if int(answer_1) == 1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1159, in Kernel.raw_input(self, prompt)
#    1155 if not self._allow_stdin:
#    1156     raise StdinNotImplementedError(
#    1157         "raw_input was called, but this frontend does not support input requests."
#    1158     )
# -> 1159 return self._input_request(
#    1160     str(prompt),
#    1161     self._parent_ident["shell"],
#    1162     self.get_parent("shell"),
#    1163     password=False,
#    1164 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1201, in Kernel._input_request(self, prompt, ident, parent, password)
#    1198             break
#    1199 except KeyboardInterrupt:
#    1200     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1201     raise KeyboardInterrupt("Interrupted by user") from None
#    1202 except Exception:
#    1203     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
import re
print("Draw dendrogram of languages")
json_list = ["Indo-European language data.json","Sino-Tibetan language data.json","Altaic language data.json",\
             "Uralic language data.json","Afroasiatic language data.json"]
exit = False
while exit!= True:
    answer_1 = input("Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)\nOr press 1 to exit")
    try:
        if int(answer_1) == 1:
            print("Thank you for playing this game!")
            exit=True
    except:
        if "," in answer_1:
            start = re.split(r" *, *",answer_1)
        else:
            start = answer_1
        try:
            for json in json_list:
                lang_dendrogram("new_language_distance_data_total.json","lang_list.json",json=json,start=start)
        except:
            print("The linguistic units you entered can not be drawn. Maybe a misspelling.")
# Out:
# Draw dendrogram of languages
# Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)
# Or press 1 to exitGermanic, Celtic, Romance
# (40, 40)
# C:\Users\DELL\SI 507\Final Project\Part 1\newest\complextree.py:884: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   linkage_matrix = linkage(dists, "single")
# (0,)
# The linguistic units you entered can not be drawn. Maybe a misspelling.
# Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)
# Or press 1 to exitAltaic
# (0,)
# The linguistic units you entered can not be drawn. Maybe a misspelling.
# Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)
# Or press 1 to exitAltaic
# (0,)
# The linguistic units you entered can not be drawn. Maybe a misspelling.
# Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)
# Or press 1 to exitTurkic, Mongolic, Tungusic
# (0,)
# The linguistic units you entered can not be drawn. Maybe a misspelling.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 6>()
#       5 exit = False
#       6 while exit!= True:
# ----> 7     answer_1 = input("Enter one or more linguistic units that you would like to draw a dendrogram of (separated by commas)\nOr press 1 to exit")
#       8     try:
#       9         if int(answer_1) == 1:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1159, in Kernel.raw_input(self, prompt)
#    1155 if not self._allow_stdin:
#    1156     raise StdinNotImplementedError(
#    1157         "raw_input was called, but this frontend does not support input requests."
#    1158     )
# -> 1159 return self._input_request(
#    1160     str(prompt),
#    1161     self._parent_ident["shell"],
#    1162     self.get_parent("shell"),
#    1163     password=False,
#    1164 )
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\ipykernel\kernelbase.py:1201, in Kernel._input_request(self, prompt, ident, parent, password)
#    1198             break
#    1199 except KeyboardInterrupt:
#    1200     # re-raise KeyboardInterrupt, to truncate traceback
# -> 1201     raise KeyboardInterrupt("Interrupted by user") from None
#    1202 except Exception:
#    1203     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user

# %%
lang_dendrogram("new_language_distance_data_total.json","lang_list.json",json="Sino-Tibetan language data.json",start="Sino-Tibetan")
# Out:
# (8, 8)
