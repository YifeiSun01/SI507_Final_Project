# %%
def write_to_json(data,file_name):
    """write a nested dictionary and list into a json file"""
    import json
    data_json = json.dumps(data)
    with open(file_name, "w") as outfile:
        outfile.write(data_json)

def read_from_json(file_name):
    """read a json file into a nested dictionary and list"""
    import json
    with open(file_name, "r",encoding="UTF-8") as outfile:
        read_data = outfile.read()
    return json.loads(read_data)

# %%
def get_list_from_json(json,status,start=None,remove_duplicate=False,branch=None):
    """read the json file into nested dictionary and list, get the field related to language classification
    and proto language. These fields are a list. Collect all these list into a big list and return. If there is
    redundant element in the list, remove them. If there is unnecessary letter or symbol in the text, remove them.
    If there are dialects under one language, for every dialect, create a list and append to the big list. If there is 
    unclear element, make them clear. This big list will be used to build the classification tree."""
    import re
    dictionary = read_from_json(json)
    list_2 = []
    if status == "classification":
        for i in dictionary:
            dict_1 = dictionary[i]
            list_1 = []
            if dict_1.get("Language family corrected")!= None:
                list_1 = dict_1.get("Language family corrected")
            if dict_1.get("Linguistic classification corrected")!= None:
                list_1 = dict_1.get("Linguistic classification corrected")
            if dict_1.get("Dialects")!= None:
                for dialect in dict_1.get("Dialects"):
                    if re.findall(r",|·",dialect)!=[]:
                        dialect_list = re.split(r" *, *| *· *",dialect)
                        for dialect_1 in dialect_list:
                            list_2.append(list_1+[dialect_1])
                    else:
                        dialect_1 = re.sub(r" *◇ *| *◆ *|\*","",dialect)
                        list_2.append(list_1+[dialect_1])
            else:
                list_2.append(list_1)
    if status == "proto":
        for i in dictionary:
            dict_1 = dictionary[i]
            if dict_1.get("Early forms corrected")!= None:
                list_4 = dict_1.get("Early forms corrected")
                if dict_1.get("English Name") != None:
                    list_4.append(dict_1.get("English Name"))
                elif ddict_1.get("Name") != None:
                    list_4.append(dict_1.get("Name"))
                list_2.append(list_4)
            if dict_1.get("Early form corrected")!= None:
                list_4 = dict_1.get("Early form corrected")
                if dict_1.get("English Name") != None:
                    list_4.append(dict_1.get("English Name"))
                elif dict_1.get("Name") != None:
                    list_4.append(dict_1.get("Name"))
                list_2.append(list_4)
    list_3 = [i for i in list_2 if i != []]
    list_3.sort(key=lambda x: len(x)) 
    list_4 = []
    for i in range(len(list_3)):
        a = 0
        for j in range(i+1,len(list_3)):
            if list_3[i] == list_3[j][:len(list_3[i])]:
                a += 1
        if a == 0:
            list_4.append(list_3[i])
    list_4.sort(key=lambda x: len(x),reverse=True)  
    if re.findall(r"altaic",json,re.I|re.M)!=[]:
        list_10 = []
        for i in list_4:
            i = ["Altaic"]+i
            list_10.append(i)
        list_4 = list_10
    if remove_duplicate!=False:
        list_6 = []
        for i in list_4:
            list_5 = []
            for j in range(len(i)):
                if j == 0:
                    list_5.append(i[j])
                else:
                    if i[j-1] == i[j]:
                        pass
                    else:
                        list_5.append(i[j])
            list_6.append(list_5) 
        list_4 = list_6
    list_7 = []
    for i in list_4:
        list_8 = []
        for j in i:
            if j != "" and j != "?":
                list_8.append(re.sub(r" *\? *| *† *|\(.*\)|(\d)+| *\( *| *\) *","",j))
        list_7.append(list_8)
    if start != None:
        list_9 = []
        for i in list_7:
            try:
                list_9.append(i[i.index(start):])
            except:
                pass
        list_7 = list_9
    list_11 = []
    for i in range(len(list_7)):
        list_12 = []
        for j in range(len(list_7[i])):
            if re.findall(r"^ *eastern *$|^ *western *$|^ *southern *$|^ *northern *$|^ *central *$|^ *northeastern *$|^ *northwestern *$|^ *southeastern *$|^ *southwestern *$|^ *insular *$|^ *canadian *$|^ *Costeño *$|^ *Llanero *$|^ *Mainland *$",list_7[i][j],re.I|re.M)!=[]:
                list_12.append(list_7[i][j]+" "+list_7[i][j-1])
            else:
                list_12.append(list_7[i][j])
        list_11.append(list_12)
    list_7 = list_11
    if branch == "Koreanic":
        list_7 = [ x for x in list_7 if 'Koreanic' in x]
    if branch == "Japonic":
        list_7 = [ x for x in list_7 if 'Japonic' in x]
    if branch == "Turkic":
        list_7 = [ x for x in list_7 if 'Turkic' in x]
    if branch == "Mongolic":
        list_7 = [ x for x in list_7 if 'Mongolic' in x]
    if branch == "Tungusic":
        list_7 = [ x for x in list_7 if 'Tungusic' in x]
    return list_7

# %%
def check(json,status,mode):
    """This function is only used for finding out languages with abnormal data. This function finds
    languages that have repetitive elements in the classification field, and languages with keywords such as 
    "eastern", "western", "southern", "northern" in the classification units, which are unclear messages"""
    import re
    dictionary = read_from_json(json)
    list_2 = []
    if status == "classification":
        for i in dictionary:
            dict_1 = dictionary[i]
            list_1 = []
            if dict_1.get("Language family corrected")!= None:
                list_1 = dict_1.get("Language family corrected")
            if dict_1.get("Linguistic classification corrected")!= None:
                list_1 = dict_1.get("Linguistic classification corrected")
            if dict_1.get("Dialects")!= None:
                for dialect in dict_1.get("Dialects"):
                    if re.findall(r",|·",dialect)!=[]:
                        dialect_list = re.split(r" *, *| *· *",dialect)
                        for dialect_1 in dialect_list:
                            list_2.append((list_1+[dialect_1],dict_1["English Name"]))
                    else:
                        dialect_1 = re.sub(r" *◇ *| *◆ *|\*","",dialect)
                        list_2.append((list_1+[dialect_1],dict_1["English Name"]))
            else:
                list_2.append((list_1,dict_1["English Name"]))
    if status == "proto":
        for i in dictionary:
            dict_1 = dictionary[i]
            if dict_1.get("Early forms corrected")!= None:
                list_4 = dict_1.get("Early forms corrected")
                if dict_1.get("English Name") != None:
                    list_4.append(dict_1.get("English Name"))
                elif ddict_1.get("Name") != None:
                    list_4.append(dict_1.get("Name"))
                list_2.append((list_4,dict_1["English Name"]))
            if dict_1.get("Early form corrected")!= None:
                list_4 = dict_1.get("Early form corrected")
                if dict_1.get("English Name") != None:
                    list_4.append(dict_1.get("English Name"))
                elif dict_1.get("Name") != None:
                    list_4.append(dict_1.get("Name"))
                list_2.append((list_4,dict_1["English Name"]))
    return_list = []
    for i in range(len(list_2)):
        if mode == "repetitve":
            if len(set(list_2[i][0])) < len(list_2[i][0]):
                if dictionary[list_2[i][1]] not in return_list:
                    return_list.append(dictionary[list_2[i][1]])
        if mode == "direction":
            a = 0
            for j in list_2[i][0]:
                if re.findall(r"^ *eastern *$|^ *western *$|^ *southern *$|^ *northern *$|^ *central *$|^ *northeastern *$|^ *northwestern *$|^ *southeastern *$|^ *southwestern *$|^ *insular *$|^ *canadian *$|^ *Costeño *$|^ *Llanero *$|^ *Mainland *$"\
                              ,j,re.I|re.M)!=[]:
                    a += 1
                if a > 0:
                    if dictionary[list_2[i][1]] not in return_list:
                        return_list.append(dictionary[list_2[i][1]])
    return return_list

# %%
def search_from_json(json,status,term):
    list_2 = get_list_from_json(json,status,remove_duplicate=False)
    lang_list = [i for i in list_2 if i != []]
    lang_list.sort(key=lambda x: len(x)) 
    return_list = []
    for i in lang_list:
        a = 0
        for j in i:
            if re.findall(term,j,re.I)!=[]:
                a += 1
        if a > 0:
            return_list.append(i)
    return return_list

# %%
def get_parent_child_pair(json,status,start=None,branch=None):
    list_of_pairs = []
    list_of_list = get_list_from_json(json,status,start,remove_duplicate=True)
    if branch == "Koreanic":
        list_of_list = [ x for x in list_of_list if 'Koreanic' in x]
    if branch == "Japonic":
        list_of_list = [ x for x in list_of_list if 'Japonic' in x]
    if branch == "Turkic":
        list_of_list = [ x for x in list_of_list if 'Turkic' in x]
    if branch == "Mongolic":
        list_of_list = [ x for x in list_of_list if 'Mongolic' in x]
    if branch == "Tungusic":
        list_of_list = [ x for x in list_of_list if 'Tungusic' in x]
    for list_1 in list_of_list:
        for i in range(len(list_1)):
            if i+1!=len(list_1):
                if (list_1[i],list_1[i+1]) not in list_of_pairs:
                    list_of_pairs.append((list_1[i],list_1[i+1])) 
    list_of_pairs.sort(key=lambda x: x[0])        
    return list_of_pairs

# %%
def get_length_dict(json):
    lang_list = get_list_from_json(json)
    d = {}
    for k, v in [(len(i),i) for i in lang_list]:
        d.setdefault(k, []).append(v)
    return d

# %%
def formTree(json,status):
    tree = {}
    for item in get_list_from_json(json,status,remove_duplicate=True):
        currTree = tree
        for key in item:
            if key not in currTree:
                currTree[key] = {}
            currTree = currTree[key]   
    return tree      
tree = formTree("Indo-European language data.json",status="classification")

# %%
import re
class Language:
    def __init__(self, dictionary):
        self.information = dictionary
        self.proto = {}
        self.classification = {}
        self.proto["parents"] = {}
        self.proto["sole parent"] = []
        self.proto["children"]= {}
        self.proto["depth"] = 0
        self.classification["parents"] = {}
        self.classification["sole parent"] = []
        self.classification["children"] = {}
        self.classification["depth"] = 0
        for i in dictionary:
            if re.findall(r"linguistic classification|language family",i,re.I|re.M) != []:
                if isinstance(dictionary[i],list):
                    self.classification["depth"] = len(dictionary[i])
                else:
                    self.classification["depth"] = 1
            if re.findall(r"early form",i,re.I|re.M) != []:
                if isinstance(dictionary[i],list):
                    self.proto["depth"] = len(dictionary[i])
                else:
                    self.proto["depth"] = 1
 
    def __str__(self):
        return_info = ""
        for i in self.information:
            if re.findall(r"Name|English Name",i,re.I|re.M)!=[] and re.findall(r"Other|Local",i,re.I|re.M)==[]:
                if isinstance(self.information.get(i),list):
                    info = '\033[91m\033[1m'+i+'\033[0m\033[0m'+": "+", ".join(self.information.get(i))+"\n"
                    return_info += info
                else:
                    info = '\033[91m\033[1m'+i+'\033[0m\033[0m'+": "+self.information.get(i)+"\n"
                    return_info += info
            elif re.findall(r"early form",i,re.I|re.M)!=[]:
                info = '\033[1m'+i+'\033[0m'+": "+" ——> ".join(self.information.get(i)+[self.information.get("English Name")\
                                                         or self.information.get("Name")])+"\n"
                return_info += info
            elif re.findall(r"linguistic classification|proto.*language|language family",i,re.I|re.M) != []:
                info = '\033[1m'+i+'\033[0m'+": "+" ——> ".join(self.information.get(i))+"\n"
                return_info += info
            elif isinstance(self.information.get(i),list):
                info = '\033[1m'+i+'\033[0m'+": "+", ".join(self.information.get(i))+"\n"
                return_info += info
            elif isinstance(self.information.get(i),dict):
                string = "\n".join([key+": "+", ".join(self.information.get(i)[key]) for key in self.information.get(i)])
                info = '\033[1m'+i+'\033[0m'+": "+string+"\n"
                return_info += info
            else:
                info = '\033[1m'+i+'\033[0m'+": "+self.information.get(i)+"\n"
                return_info += info
        #return_info += "\033[1mProto-Language Parents\033[0m: "+str(self.proto["parents"])+"\n"
        return_info += "\033[1mProto-Language Parent\033[0m: "+", ".join(self.proto["sole parent"])+"\n"
        #return_info += "\033[1mProto-Language Lineage\033[0m: "\
        #               +str(self.information.get("Early form corrected"))+"\n"
        #return_info += "\033[1mProto-Language Lineage\033[0m: "\
        #               +str(self.information.get("Early forms corrected"))+"\n"
        #return_info += "\033[1mProto-Language Lineage\033[0m: "\
        #               +str(self.information.get("Reconstructed ancestors"))+"\n"
        return_info += "\033[1mProto-Language Children\033[0m: "+", ".join(self.proto["children"])+"\n"
        return_info += "\033[1mProto-Language Depth\033[0m: "+str(self.proto["depth"])+"\n"
        #return_info += "\033[1mLanguage Classification Parents\033[0m: "+str(self.classification["parents"])+"\n"
        return_info += "\033[1mLanguage Classification Parent\033[0m: "\
                       +", ".join(self.classification["sole parent"])+"\n"
        #return_info += "\033[1mLanguage Classification Lineage\033[0m: "\
        #               +str(self.information.get("Language family corrected"))+"\n"
        #return_info += "\033[1mLanguage Classification Lineage\033[0m: "\
        #               +str(self.information.get("Linguistic classification corrected"))+"\n"
        return_info += "\033[1mLanguage Classification Children\033[0m: "\
                       +", ".join(list(self.classification["children"].keys()))+"\n"  
        return_info += "\033[1mLanguage Classification Depth\033[0m: "+str(self.classification["depth"])+"\n"
        return return_info
    
    def get_all_attributes(self):
        return self.__dict__

class Tree:
    def __init__(self):
        self.langList = {}
        self.numLangs = 0
        
    def addLang(self,dictionary):
        self.numLangs = self.numLangs + 1
        newLang = Language(dictionary)
        if dictionary.get("English Name") != None:
            self.langList[re.sub(r"\[\d+\]","",dictionary.get("English Name"))] = newLang
        elif dictionary.get("Name") != None: 
            self.langList[re.sub(r"\[\d+\]","",dictionary.get("Name"))] = newLang
        return newLang
    
    def getLang(self,name):
        if name in self.langList:
            return self.langList[name]
        else:
            return None
        
    def searchLang(self,name):
        lang_list = []
        for lang in self.langList:
            if re.findall(name,lang,re.I|re.M) != []:
                lang_list.append(lang)
        for i in lang_list:
            print(self.langList[i],"\n")  
        
    def __contains__(self,name):
        return name in self.langList
    
    def getLangs(self):
        return self.langList.keys()
    
    def __iter__(self):
        return iter(self.langList.values())
    
def Merge(dict1, dict2):
    res = {**dict1, **dict2}
    return res        

def create_tree(json,start=None): 
    dictionary = read_from_json(json)
    lang_list = []
    if start != None:
        for i in get_parent_child_pair(json,status="classification",start=start):
            for j in i:
                if j not in lang_list:
                    lang_list.append(j)
    else:
        lang_list = dictionary.keys()
    lang_tree = Tree()
    for i in lang_list:
        try:
            new_lang = lang_tree.addLang(dictionary[i])
        except:
            pass
    for pair in get_parent_child_pair(json,status="classification",start=start):
        if pair[0] in lang_tree.langList.keys() and pair[1] in lang_tree.langList.keys():
            if pair[1] not in lang_tree.langList[pair[0]].classification["children"]:
                lang_tree.langList[pair[0]].classification["children"][pair[1]] = 1
            else:
                lang_tree.langList[pair[0]].classification["children"][pair[1]] += 1
            if pair[0] not in lang_tree.langList[pair[1]].classification["parents"]:
                lang_tree.langList[pair[1]].classification["parents"][pair[0]] = 1
            else:
                lang_tree.langList[pair[1]].classification["parents"][pair[0]] += 1
    for pair in get_parent_child_pair(json,status="proto",start=start):
        if pair[0] in lang_tree.langList.keys() and pair[1] in lang_tree.langList.keys():
            if pair[1] not in lang_tree.langList[pair[0]].proto["children"]:
                lang_tree.langList[pair[0]].proto["children"][pair[1]] = 1
            else:
                lang_tree.langList[pair[0]].proto["children"][pair[1]] += 1
            if pair[0] not in lang_tree.langList[pair[1]].proto["parents"]:
                lang_tree.langList[pair[1]].proto["parents"][pair[0]] = 1
            else:
                lang_tree.langList[pair[1]].proto["parents"][pair[0]] += 1
    for lang in lang_tree.langList:
        class_parents = lang_tree.langList[lang].classification["parents"]
        class_parents_list = []
        if class_parents != {}:
            prepared_list_1 = []
            if len(class_parents) == 1:
                lang_tree.langList[lang].classification["sole parent"] += list(class_parents.keys())
            else:
                for class_parent in class_parents:
                    class_parent_children = list(lang_tree.langList[class_parent].classification["children"].keys())
                    other_class_parents = list(class_parents.keys())
                    n = 0
                    for other_class_parent in other_class_parents:
                        if other_class_parent in class_parent_children:
                            n += 1
                    if n == 0:
                        if class_parent not in prepared_list_1:
                            prepared_list_1 += [class_parent]  
            prepared_list_1 = [*set(prepared_list_1)]
            if len(prepared_list_1)<=1: 
                lang_tree.langList[lang].classification["sole parent"] += prepared_list_1
            else:
                if lang_tree.langList[lang].information.get("Language family corrected"):
                    if len(lang_tree.langList[lang].information.get("Language family corrected")) > 1:
                        for i in prepared_list_1:
                            if i == lang_tree.langList[lang].information.get("Language family corrected")[-2]:
                                if i not in lang_tree.langList[lang].classification["sole parent"]:
                                    lang_tree.langList[lang].classification["sole parent"].append(i)
                if lang_tree.langList[lang].information.get("Linguistic classification corrected"):
                    if len(lang_tree.langList[lang].information.get("Linguistic classification corrected")) > 1:
                        for i in prepared_list_1:
                            if i == lang_tree.langList[lang].information.get("Linguistic classification corrected")[-2]:
                                if i not in lang_tree.langList[lang].classification["sole parent"]:
                                    lang_tree.langList[lang].classification["sole parent"].append(i)
    for lang in lang_tree.langList:
        class_parents = lang_tree.langList[lang].proto["parents"]
        class_parents_list = []
        if class_parents != {}:
            prepared_list_2 = []
            if len(class_parents) == 1:
                lang_tree.langList[lang].proto["sole parent"] += list(class_parents.keys())
            else:
                for class_parent in class_parents:
                    class_parent_children = list(lang_tree.langList[class_parent].proto["children"].keys())
                    other_class_parents = list(class_parents.keys())
                    n = 0
                    for other_class_parent in other_class_parents:
                        if other_class_parent in class_parent_children:
                            n += 1
                    if n == 0:
                        if class_parent not in prepared_list_2:
                            prepared_list_2 += [class_parent]  
            prepared_list_2 = [*set(prepared_list_2)]
            if len(prepared_list_2)<=1:
                lang_tree.langList[lang].proto["sole parent"] += prepared_list_2
            else:
                if lang_tree.langList[lang].information.get("Early forms corrected"):
                    if len(lang_tree.langList[lang].information.get("Early forms corrected")) > 0:
                        for i in prepared_list_2:
                            if i == lang_tree.langList[lang].information.get("Early forms corrected")[-1]:
                                if i not in lang_tree.langList[lang].proto["sole parent"]:
                                    lang_tree.langList[lang].proto["sole parent"].append(i)
                if lang_tree.langList[lang].information.get("Early form corrected"):
                    if len(lang_tree.langList[lang].information.get("Early form corrected")) > 0:
                        for i in prepared_list_2:
                            if i == lang_tree.langList[lang].information.get("Early form corrected")[-1]:
                                if i not in lang_tree.langList[lang].proto["sole parent"]:
                                    lang_tree.langList[lang].proto["sole parent"].append(i) 
                if lang_tree.langList[lang].information.get("Reconstructed ancestors"):
                    if len(lang_tree.langList[lang].information.get("Reconstructed ancestors")) > 0:
                        for i in prepared_list_2:
                            if i == lang_tree.langList[lang].information.get("Reconstructed ancestors")[-1]:
                                if i not in lang_tree.langList[lang].proto["sole parent"]:
                                    lang_tree.langList[lang].proto["sole parent"].append(i) 
    for lang in lang_tree.langList:
        if (len(lang_tree.langList[lang].classification["sole parent"])==0 and \
            len(lang_tree.langList[lang].classification["parents"])!=0):
            if lang_tree.langList[lang].information.get("Language family corrected"):
                if len(lang_tree.langList[lang].information.get("Language family corrected")) > 1:  
                    lang_tree.langList[lang].classification["sole parent"] +=\
                    [lang_tree.langList[lang].information.get("Language family corrected")[-2]]
            if lang_tree.langList[lang].information.get("Linguistic classification corrected"):
                if len(lang_tree.langList[lang].information.get("Linguistic classification corrected")) > 1:  
                    lang_tree.langList[lang].classification["sole parent"] +=\
                    [lang_tree.langList[lang].information.get("Linguistic classification corrected")[-2]]
        if (len(lang_tree.langList[lang].proto["sole parent"])==0 and \
            len(lang_tree.langList[lang].proto["parents"])!=0):    
            if lang_tree.langList[lang].information.get("Early forms corrected"):
                if len(lang_tree.langList[lang].information.get("Early forms corrected")) > 0:  
                    lang_tree.langList[lang].proto["sole parent"].\
                    append(lang_tree.langList[lang].information.get("Early forms corrected")[-1])
            if lang_tree.langList[lang].information.get("Early form corrected"):
                if len(lang_tree.langList[lang].information.get("Early form corrected")) > 0:  
                    lang_tree.langList[lang].proto["sole parent"].\
                    append(lang_tree.langList[lang].information.get("Early form corrected")[-1])
            if lang_tree.langList[lang].information.get("Reconstructed ancestors"):
                if len(lang_tree.langList[lang].information.get("Reconstructed ancestors")) > 0:  
                    lang_tree.langList[lang].proto["sole parent"].\
                    append(lang_tree.langList[lang].information.get("Reconstructed ancestors")[-1])
    return lang_tree

# %%
import re
class Simplified_Language:
    def __init__(self,name):
        self.name = name
        self.parents = {}
        self.parent = []
        self.children = {}
        self.real_children = []
    
    def __str__(self):
        string = "\n".join(("\033[91m\033[1mLanguage Name\033[0m\033[0m: "+self.name,\
                            "\033[1mParent\033[0m: "+", ".join(self.parent),\
                            "\033[1mParents\033[0m: "+str(self.parents),\
                            "\033[1mChildren\033[0m: "+", ".join(self.real_children)))
        return string
        
class Simplified_Tree():
    def __init__(self):
        self.langList = {}
        self.numLangs = 0
    def addLang(self,name):
        self.numLangs = self.numLangs + 1
        newLang = Simplified_Language(name)
        self.langList[name] = newLang
        return newLang
    def searchLang(self,name):
        list_1 = []
        for lang in self.langList:
            if re.findall(name,lang,re.I|re.M) != []:
                list_1.append(lang)
        for i in list_1:
            print(self.langList[i],"\n")
            
def creat_simple_tree(json,status,start=None,branch=None):
    longTree = create_tree(json,start=start)
    list_of_pair = get_parent_child_pair(json,status,start=start,branch=branch)
    lang_tree = Simplified_Tree()
    for pair in list_of_pair:
        if pair[0] not in lang_tree.langList:
            lang_tree.addLang(pair[0])
            lang_tree.langList[pair[0]].children[pair[1]] = 1
        else:
            if pair[1] not in lang_tree.langList[pair[0]].children:
                lang_tree.langList[pair[0]].children[pair[1]] = 1
            else:
                lang_tree.langList[pair[0]].children[pair[1]] += 1
        if pair[1] not in lang_tree.langList:
            lang_tree.addLang(pair[1])
            lang_tree.langList[pair[1]].parents[pair[0]] = 1
        else:
            if pair[0] not in lang_tree.langList[pair[1]].parents:
                lang_tree.langList[pair[1]].parents[pair[0]] = 1
            else:
                lang_tree.langList[pair[1]].parents[pair[0]] += 1
    for lang in lang_tree.langList:
        parents = lang_tree.langList[lang].parents
        if len(parents) <= 1:
            lang_tree.langList[lang].parent += parents
        else:
            for parent in parents:
                parent_children = list(lang_tree.langList[parent].children.keys())
                other_parents = list(parents.keys())
                n = 0
                for other_parent in other_parents:
                    if other_parent in parent_children:
                        n += 1
                if n == 0:
                    lang_tree.langList[lang].parent += [parent]
    for lang in lang_tree.langList:
        if len(lang_tree.langList[lang].parent) > 1:
            if lang in longTree.langList:
                if status == "classification":
                    lang_tree.langList[lang].parent = longTree.langList[lang].classification["sole parent"]
                if status == "proto":
                    lang_tree.langList[lang].parent = longTree.langList[lang].proto["sole parent"]
    for lang in lang_tree.langList:
        if len(lang_tree.langList[lang].parent) > 1:
            lang_tree.langList[lang].parent = [lang_tree.langList[lang].parent[0]]
    for lang in lang_tree.langList:
        children = lang_tree.langList[lang].children
        for child in children:
            child_parent = list(lang_tree.langList[child].parents.keys())
            child_parent_parent = []
            for x in list(lang_tree.langList[child].parents.keys()):
                child_parent_parent += list(lang_tree.langList[x].parents.keys())
            other_children = list(children.keys())
            n = 0
            for other_child in other_children:
                if other_child in child_parent or other_child in child_parent_parent:
                    n += 1
            if n == 0:
                lang_tree.langList[lang].real_children += [child]
    for lang in lang_tree.langList:
        if len(lang_tree.langList[lang].parent)==0 and len(lang_tree.langList[lang].parents)>0:
            lang_tree.langList[lang].parent = [list(lang_tree.langList[lang].parents.keys())[0]]
    return lang_tree

def find_lineage(json,name,status,form="long"):
    simple_tree = creat_simple_tree(json,status=status,start=None,branch=None)
    tree = create_tree(json,start=None)
    list_1 = [name]
    start = simple_tree.langList[name]
    i = 20
    while i > 0:
        i -= 1
        try:
            list_1.append(", ".join(start.parent))
        except:
            pass
        try:
            start = simple_tree.langList[", ".join(start.parent)]
        except:
            pass
    list_1.reverse()
    list_1 = [x for x in list_1 if x != ""]
    if form=="long":
        for lang in list_1:
            if lang in tree.langList:
                print(tree.langList[lang],"\n") 
            else: 
                print(simple_tree.langList[lang],"\n") 
    if form=="short":
        for lang in list_1:
            print(simple_tree.langList[lang],"\n")

# %%
def find_no_parent(tree):
    list_1 = []
    for lang in tree.langList:
        if len(tree.langList[lang].parent) == 0:
            list_1.append(lang)
            print(tree.langList[lang])
    return "There are "+str(len(list_1))+" language with no parent."

# %%
langTree = create_tree("Indo-European language data.json",start=None)

# %%
simplelangTree = creat_simple_tree("Indo-European language data.json",status="classification")

# %%
simplelangTree.searchLang("Russian")
# Out:
# Language Name: High Prussian
# Parent: East Central German
# Parents: {'East Central German': 1}
# Children:
#
# Language Name: Low Prussian
# Parent: East Low German
# Parents: {'East Low German': 1, 'Low German': 1}
# Children: Werdersch, Nehrungisch, Vistulan, Elbingian, Westkäslausch, Ostkäslausch, Natagian, Samlandic, Eastern Low Prussian
#
# Language Name: Russian
# Parent: East Slavic languages
# Parents: {'East Slavic languages': 1}
# Children: Moscow dialect, Alaskan Russian, Doukhobor Russian
#
# Language Name: Astrakhan Russian
# Parent: East Slavic languages
# Parents: {'East Slavic languages': 1}
# Children:
#
# Language Name: Dagestani Russian
# Parent: East Slavic languages
# Parents: {'East Slavic languages': 1}
# Children:
#
# Language Name: Eastern Low Prussian
# Parent: Low Prussian
# Parents: {'Low Prussian': 1}
# Children:
#
# Language Name: Alaskan Russian
# Parent: Russian
# Parents: {'Russian': 1}
# Children:
#
# Language Name: Doukhobor Russian
# Parent: Russian
# Parents: {'Russian': 1}
# Children:
#
# Language Name: Old Prussian
# Parent: Western Baltic
# Parents: {'Western Baltic': 1}
# Children:

# %%
find_no_parent(simplelangTree)
# Out:
# Language Name: Indo-European
# Parent:
# Parents: {}
# Children: Germanic, Indo-Iranian, Balto-Slavic, Proto-Greek, Graeco-Phrygian, Albanian, Anatolian, Mixed language., Italo-Celtic, Armenic, Tocharian, Illyrian, Sicel, Dacian, Thracian, Paeonian, Liburnian, Classical Armenian, Cilician Armenian/Middle Armenian
# 'There are 1 language with no parent.'

# %%
find_lineage("Indo-European language data.json","French",status="classification",form="short")
# Out:
# Language Name: Indo-European
# Parent:
# Parents: {}
# Children: Germanic, Indo-Iranian, Balto-Slavic, Proto-Greek, Graeco-Phrygian, Albanian, Anatolian, Mixed language., Italo-Celtic, Armenic, Tocharian, Illyrian, Sicel, Dacian, Thracian, Paeonian, Liburnian, Classical Armenian, Cilician Armenian/Middle Armenian
#
# Language Name: Italo-Celtic
# Parent: Indo-European
# Parents: {'Indo-European': 1}
# Children: Italic, Celtic
#
# Language Name: Italic
# Parent: Italo-Celtic
# Parents: {'Indo-European': 1, 'Italo-Celtic': 1}
# Children: Latino-Faliscan, Osco-Umbrian, Aequian, Vestinian, Lusitanian, Ancient Belgian, Venetic, Siculian
#
# Language Name: Latino-Faliscan
# Parent: Italic
# Parents: {'Italic': 1}
# Children: Latin, Faliscan, Lanuvian, Praenestinian
#
# Language Name: Latin
# Parent: Latino-Faliscan
# Parents: {'Italic': 1, 'Latino-Faliscan': 1}
# Children: Romance, Classical Latin, Old Latin, Vulgar Latin, Ecclesiastical Latin, Hiberno-Latin
#
# Language Name: Romance
# Parent: Latin
# Parents: {'Indo-European': 1, 'Italic': 1, 'Latin': 1, 'Latino-Faliscan': 1}
# Children: Italo-Western, Italo-Northern, Eastern Romance, Southern Romance, Sardinian, British Latin, Pannonian Romance
#
# Language Name: Italo-Northern
# Parent: Romance
# Parents: {'Romance': 1}
# Children: Gallo-Iberian
#
# Language Name: Gallo-Iberian
# Parent: Italo-Northern
# Parents: {'Italo-Northern': 1, 'Western Romance': 1}
# Children: Iberian Romance, Gallo-Romance
#
# Language Name: Gallo-Romance
# Parent: Gallo-Iberian
# Parents: {'Gallo-Iberian': 1, 'Italo-Western': 1, 'Romance': 1, 'Western Romance': 1}
# Children: Gallo-Rhaetian, Occitano-Romance, Gallo-Italic, Rhaeto-Romance, Franco-Provençal
#
# Language Name: Gallo-Rhaetian
# Parent: Gallo-Romance
# Parents: {'Gallo-Romance': 1}
# Children: Oïl
#
# Language Name: Oïl
# Parent: Gallo-Rhaetian
# Parents: {'Gallo-Rhaetian': 1, 'Gallo-Romance': 1, 'Romance': 1}
# Children: Norman, French, Lorrain, Walloon, Old French, Francien, Picard, Zarphatic, Moselle Romance, Angevin, Poitevin-Saintongeais, Middle French, Champenois, Gallo, Burgundian, Frainc-Comtou
#
# Language Name: French
# Parent: Oïl
# Parents: {'Oïl': 1}
# Children: French of France, Meridional French, Jersey Legal French, Canadian French, Belgian French, Swiss French, Acadian French, Louisiana French, African French, Quebec French, Missouri French, Newfoundland French, Frenchville French, United States French, Saint-Barthélemy French

# %%
langTree.searchLang("Marathi-Konkani")
# Out:
# English Name: Marathi-Konkani
# URL: https://en.wikipedia.org/wiki/Marathi-Konkani_languages
# Other Names: मराठी-कोंकणी
# Status: Normal
# Geographic distribution: Western India
# Linguistic classification: Indo-European ——> Indo-Iranian ——> Indo-Aryan ——> Southern Indo-Aryan ——> Marathi-Konkani
# Early form: Maharashtri Prakrit ——> Marathi-Konkani
# Linguistic classification corrected: Indo-European ——> Indo-Iranian ——> Indo-Aryan ——> Indo-Aryan ——> Marathi-Konkani
# Early form corrected: Maharashtri Prakrit ——> Marathi-Konkani
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Indo-Iranian_languages, https://en.wikipedia.org/wiki/Indo-Aryan_languages, https://en.wikipedia.org/wiki/List_of_Southern_Indo-Aryan_languages
# Proto-Language Parent:
# Proto-Language Children:
# Proto-Language Depth: 1
# Language Classification Parent: Maharashtri
# Language Classification Children: Marathi, Maharashtri Konkani, Konkani, East Indian language, Kadodi, Katkari, Varli, Phudagi, Canarese Konkani, Andh
# Language Classification Depth: 5

# %%
langTree.searchLang("Dutch")
# Out:
# English Name: Dutch
# URL: https://en.wikipedia.org/wiki/Dutch_language
# Name in Local Language: Nederlands
# Status: Normal
# Native to: Netherlands, Belgium, Suriname, Indonesia and South Africa
# Region: Netherlands, Belgium, Suriname;, Additionally in Aruba, Curaçao, Indonesia, Sint Maarten and French Flanders
# Ethnicity: Indo, Dutch, Flemings
# Native speakers: 25 million (2021) 1 Total (L1 plus L2 speakers): 30 million (2021) 2  3
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Weser-Rhine Germanic ——> Low Franconian ——> Frankish ——> Dutch
# Early forms: Frankish ——> Old Dutch ——> Middle Dutch ——> Dutch
# Writing system: Dutch Braille, Latin (Dutch alphabet)
# Sub Languages: Dependent entities, Dependent entities
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> Weser-Rhine Germanic ——> Low Franconian ——> Dutch
# Early forms corrected: Frankish ——> Old Dutch ——> Middle Dutch ——> Dutch
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/Weser-Rhine_Germanic, https://en.wikipedia.org/wiki/Low_Franconian_languages, https://en.wikipedia.org/wiki/Frankish_language, https://en.wikipedia.org/wiki/Old_Dutch, https://en.wikipedia.org/wiki/Middle_Dutch
# Proto-Language Parent: Middle Dutch
# Proto-Language Children:
# Proto-Language Depth: 3
# Language Classification Parent: Low Franconian
# Language Classification Children: Flemish, West Flemish, Afrikaans, East Flemish, Brabantian, Zeelandic, Kaaps, Jersey Dutch
# Language Classification Depth: 6
#
#
# English Name: Pennsylvania Dutch
# URL: https://en.wikipedia.org/wiki/Pennsylvania_German_language
# Other Names: Pennsylvania German, Pennsilfaanisch Deitsch
# Status: Normal
# Native to: United States, Canada
# Region: Iowa, Ohio, Indiana, Ontario, Illinois, Kentucky, Missouri, New York, Wisconsin, Tennessee, Pennsylvania, West Virginia
# Ethnicity: Pennsylvania Dutch
# Native speakers: 237,000 (2016-2020 American Community Survey) 1 to 350,000 (2012) 2  (L2 speakers: about 3,000)
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Elbe Germanic ——> High German ——> Central German ——> West Central German ——> Rhine Franconian ——> Palatine German ——> Pennsylvania Dutch
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> Elbe Germanic ——> High German dialects ——> Central German, Middle German ——> West Central German ——> Rhenish Franconian ——> Palatine German ——> Pennsylvania Dutch
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/Elbe_Germanic, https://en.wikipedia.org/wiki/High_German_languages, https://en.wikipedia.org/wiki/Central_German, https://en.wikipedia.org/wiki/West_Central_German, https://en.wikipedia.org/wiki/Rhine_Franconian_dialects, https://en.wikipedia.org/wiki/Palatine_German_language
# Proto-Language Parent:
# Proto-Language Children:
# Proto-Language Depth: 0
# Language Classification Parent: Palatine German
# Language Classification Children:
# Language Classification Depth: 10
#
#
# English Name: Old Dutch
# URL: https://en.wikipedia.org/wiki/Old_Dutch
# Name in Local Language: Old Low Franconian
# Status: Normal
# Native to: Holland, Austrasia, Zeeland and Flanders
# Region: The Low Countries
# Era: 5th to middle 12th century AD, gradually developed into Middle Dutch
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Istvaeonic ——> Old Frankish ——> Old Dutch
# Early form: Old Frankish ——> Old Dutch
# Writing system: Runes,, Latin (later)
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> Weser-Rhine Germanic ——> Frankish ——> Old Dutch
# Early form corrected: Old Frankish ——> Old Dutch
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/Weser-Rhine_Germanic, https://en.wikipedia.org/wiki/Frankish_language
# Proto-Language Parent: Frankish
# Proto-Language Children: Middle Dutch
# Proto-Language Depth: 1
# Language Classification Parent: Frankish
# Language Classification Children:
# Language Classification Depth: 6
#
#
# English Name: Middle Dutch
# URL: https://en.wikipedia.org/wiki/Middle_Dutch
# Name in Local Language: dietsc, duutsch
# Status: Normal
# Region: the Low Countries
# Era: developed into modern Dutch around 1500 or c. 1550 1
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Istvaeonic ——> Low Franconian ——> Middle Dutch
# Early forms: Frankish ——> Old Dutch ——> Middle Dutch
# Writing system: Latin
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> Weser-Rhine Germanic ——> Low Franconian ——> Middle Dutch
# Early forms corrected: Frankish ——> Old Dutch ——> Middle Dutch
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/Weser-Rhine_Germanic, https://en.wikipedia.org/wiki/Low_Franconian_languages, https://en.wikipedia.org/wiki/Frankish_language, https://en.wikipedia.org/wiki/Old_Dutch
# Proto-Language Parent: Old Dutch
# Proto-Language Children: Dutch
# Proto-Language Depth: 2
# Language Classification Parent: Low Franconian
# Language Classification Children:
# Language Classification Depth: 6
#
#
# English Name: Pennsylvania Dutch English
# URL: https://en.wikipedia.org/wiki/Pennsylvania_Dutch_English
# Name in Local Language:
# Status: Normal
# Native to: United States, Canada
# Region: Pennsylvania; Ohio; Indiana; Ontario; and elsewhere
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Ingvaeonic ——> Anglo–Frisian ——> Anglic ——> English ——> North American English ——> American English ——> Pennsylvania Dutch English
# Early forms: Old English ——> Middle English ——> Early Modern English ——> Pennsylvania Dutch English
# Writing system: Latin (English alphabet)
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> North Sea Germanic ——> Anglo-Frisian ——> Anglo-Frisian ——> English ——> North American English ——> American English ——> Pennsylvania Dutch English
# Early forms corrected: Old English ——> Middle English ——> Early Modern English ——> Pennsylvania Dutch English
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/North_Sea_Germanic, https://en.wikipedia.org/wiki/Anglo-Frisian_languages, https://en.wikipedia.org/wiki/Anglic_languages, https://en.wikipedia.org/wiki/English_language, https://en.wikipedia.org/wiki/North_American_English, https://en.wikipedia.org/wiki/American_English, https://en.wikipedia.org/wiki/Old_English, https://en.wikipedia.org/wiki/Middle_English, https://en.wikipedia.org/wiki/Early_Modern_English
# Proto-Language Parent: Early Modern English
# Proto-Language Children:
# Proto-Language Depth: 3
# Language Classification Parent: American English
# Language Classification Children:
# Language Classification Depth: 10
#
#
# English Name: Jersey Dutch
# URL: https://en.wikipedia.org/wiki/Jersey_Dutch_language
# Name in Local Language: Duits, Leeg Duits
# Status: Normal
# Region: New Jersey, New York, United States
# Ethnicity: Jersey Dutch, New York Dutch
# Extinct: Early 20th century 1
# Language family: Indo-European ——> Germanic ——> West Germanic ——> Istvaeonic ——> Low Franconian ——> Dutch ——> Jersey Dutch
# Writing system: Latin (Dutch alphabet)
# Language family corrected: Indo-European ——> Germanic ——> West Germanic ——> Weser-Rhine Germanic ——> Low Franconian ——> Dutch ——> Jersey Dutch
# Related URLs: https://en.wikipedia.org/wiki/Indo-European_languages, https://en.wikipedia.org/wiki/Germanic_languages, https://en.wikipedia.org/wiki/West_Germanic_languages, https://en.wikipedia.org/wiki/Weser-Rhine_Germanic, https://en.wikipedia.org/wiki/Low_Franconian_languages, https://en.wikipedia.org/wiki/Dutch_language
# Proto-Language Parent:
# Proto-Language Children:
# Proto-Language Depth: 0
# Language Classification Parent: Dutch
# Language Classification Children:
# Language Classification Depth: 7

# %%
def show_tree(json,status,start=None,branch=None):
    from treelib import Node, Tree
    from collections import Counter
    import re
    simplelangTree = creat_simple_tree(json,status,start,branch=branch)
    tree = Tree()
    added_list = []
    unadded_list = []
    root = None
    if status == "classification":
        for lang in simplelangTree.langList:
            if simplelangTree.langList[lang].parent == []:
                root = lang
                print("Show the linguistic tree of "+root+" languages......")
    elif status == "proto":
        for lang in simplelangTree.langList:
            if simplelangTree.langList[lang].parent == [] and re.findall(json.split(" ")[0],lang,re.M|re.I)!=[]:
                root = lang
                print("Show the linguistic tree of "+root+" languages......")
    tree.create_node(root, root)
    added_list.append(root)
    unadded_num_list = []
    while (len(simplelangTree.langList)-len(added_list)) > 0: 
        if len(unadded_num_list) > 6 and len(set(unadded_num_list[-5:])) == 1:
            break
        else:
            for lang in simplelangTree.langList:
                if lang not in [tree.nodes[k].tag for k in tree.nodes] and lang not in added_list:
                    try:
                        tree.create_node(lang, lang, parent=simplelangTree.langList[lang].parent[0])
                        added_list.append(lang)
                    except:
                        unadded_list.append(lang)   
        unadded_num_list.append(len(simplelangTree.langList)-len(added_list))
        print(str(len(simplelangTree.langList)-len(added_list))+" languages haven't been added.")
    final_unadded = \
    ", ".join(list(set(simplelangTree.langList.keys())-set([tree.nodes[k].tag for k in tree.nodes])))
    print("These languages are not added: "+final_unadded+"\n\n")
    tree.show()

# %%
def show_simple_tree(json,status,start=None,branch=None):
    from treelib import Node, Tree
    from collections import Counter
    import re
    simplelangTree = creat_simple_tree(json,status,start,branch=branch)
    tree = Tree()
    added_list = []
    unadded_list = []
    root = None
    if status == "classification":
        for lang in simplelangTree.langList:
            if simplelangTree.langList[lang].parent == []:
                root = lang
                print("Show the linguistic tree of "+root+" languages......")
    elif status == "proto":
        for lang in simplelangTree.langList:
            if simplelangTree.langList[lang].parent == [] and re.findall(json.split(" ")[0],lang,re.M|re.I)!=[]:
                root = lang
                print("Show the linguistic tree of "+root+" languages......")
    tree.create_node(root, root)
    added_list.append(root)
    unadded_num_list = []
    while (len(simplelangTree.langList)-len(added_list)) > 0: 
        if len(unadded_num_list) > 6 and len(set(unadded_num_list[-5:])) == 1:
            break
        else:
            for lang in simplelangTree.langList:
                if lang not in [tree.nodes[k].tag for k in tree.nodes] and lang not in added_list:
                    try:
                        tree.create_node(lang, lang, parent=simplelangTree.langList[lang].parent[0])
                        added_list.append(lang)
                    except:
                        unadded_list.append(lang)   
        unadded_num_list.append(len(simplelangTree.langList)-len(added_list))
        print(str(len(simplelangTree.langList)-len(added_list))+" languages haven't been added.")
    final_unadded = \
    ", ".join(list(set(simplelangTree.langList.keys())-set([tree.nodes[k].tag for k in tree.nodes])))
    print("These languages are not added: "+final_unadded+"\n\n")
    tree.show()

# %%
show_simple_tree("Indo-European language data.json",status="proto")
# Out:
# Show the linguistic tree of Proto-Indo-European languages......
# 360 languages haven't been added.
# 331 languages haven't been added.
# 304 languages haven't been added.
# 224 languages haven't been added.
# 213 languages haven't been added.
# 211 languages haven't been added.
# 211 languages haven't been added.
# 211 languages haven't been added.
# 211 languages haven't been added.
# 211 languages haven't been added.
# These languages are not added: Romanian, Colombian Spanish, Proto-Greek, Modern Dutch, Old Irish, Wakhi, Old Frankish, Manx, Castilian languages, New England French, Jèrriais, Galician–Asturian, Middle Low German, Medieval Greek, New Latin, Auregnais, Llanito, Belizean Spanish, Canadian French, Bukovinian Romanian, Old Spanish, Sercquiais, Old French Ancien Français, Old Norman, East Sutherland Gaelic, Amazonic Spanish, Tetuani, Swiss French, Belgian French, Connacht Irish, Old Polish, Costa Rican Spanish, Unclear, Attic Greek, Resian, Cilician Armenian/Middle Armenian, Common Brittonic, Middle Persian, Northwestern Slovene dialect, Equatoguinean Spanish, Old Saxon, Romance, Picard, Proto-resian, Renaissance Latin, Sinhala, Strand Frisian, Paraguayan Spanish, Italian, Zarphatic, Ulster Irish, Norman, Malwai, Old Occitan, Venezuelan Spanish, Proto-Armenian, Francien, Jersey Legal French, Haketia, Goidelic, Koine Greek, Scythian, Florentine, French, Megleno-Romanian, Louisiana French, Cotentinais, Old Persian, United States French, Old Frisian, Plautdietsch, Old Punjabi, Elu, Murcian, Acadian French, Gallo-Romance, Western Brythonic, Middle Polish, Limburgish, Panamanian Spanish, Kāmarūpī Apabhraṃśa, Old Gallo-Romance, Fala, Proto-Norseattested, Dutch, Northern Slovene dialect, Old Latin, Extremaduran, Interlingue, Canadian Gaelic, Moldavian, Navarro-Aragonese, Scottish Gaelic, Galician-Portuguese, Lorrain, Yaghnobi, Ancient Greek, Greek, Low Franconian, Old Church Slavonic, Aromanian, Early Modern Spanish, Maharashtri Prakrit, Afrikaans, New Mexican Spanish, Central American Spanish, Azorean dialect, Zeelandic, Istro-Romanian, Occitan, Puerto Rican Spanish, Middle Frisian, Punjabi languages, Eastern Romance, Mid-Minch Gaelic, Cuban Spanish, Śaurasenī Apabhraṃśa, Balearic, Old Dutch, Dominican Spanish, Proto-Tocharian, Hallingen Frisian, Contemporary Latin, Welsh, Canarian Spanish, French of France, Judaeo-Spanish, Philippine Spanish, Old Catalan, Arcadocypriot Greek, Auli, Berlin German, Northern CatalanRoussillonese, Common Romanian, since the New High German time: Old High German and Middle High German, Cauchois, Mycenaean Greek, Florianopolitan dialect, Spanish, Ionic Greek, Law French, Church Slavonic, Aeolic Greek, Brandenburgisch dialect, Poitevin-Saintongeais, Istanbul Greek dialect, Old FrenchAncien Français, Wisconsin Walloon, Tehrani accent, Salvadoran Spanish, Meridional French, Vulgar Latin, Polish, Classical Armenian, Moselle Romance, Kaaps, Middle French, Kuchean, Armenian, Minderico, Honduran Spanish, Saka, Guernésiais, Low German, Middle Dutch, Andalusian Spanish, Marathi-Konkani, Medieval Latin, Middle Welsh, Galician, Classical Latin, Aragonese, St. Marys Bay French, Ecuadorian Spanish, Sauraseni Prakrit, Guatemalan Spanish, Frankish, Upper German, Tuscan, Classical Gaelic, Late Latin, Primitive Irish, Doric Greek, Albanian, Faetar, Old Welsh, Early Modern Irish, Old Armenian, Oïl, Sogdian, East Anglian English, Mercian Old English, Gallo, Nicaraguan Spanish, Early New Persian, Saurashtra Language, Ligurian / Genoese, Anglo-Norman, Modern Greek, Proto-Albanian language, Franco-Provençal, Old Aragonese, Catalan, Walloon, Southern Manx, African French, Middle Irish, Galwegian Gaelic, Portuguese, Munster Irish, United States Spanish
#
#
# Proto-Indo-European
# ├── Proto-Balto-Slavic
# │   ├── Proto-Baltic
# │   │   ├── Latgalian
# │   │   ├── Latvian
# │   │   └── Lithuanian
# │   └── Proto-Slavic
# │       ├── Czech–Slovak
# │       ├── Old East Slavic
# │       │   ├── East Slavic languages
# │       │   ├── Moscow dialect
# │       │   ├── Old Novgorodian
# │       │   ├── Russian
# │       │   └── Ruthenian language
# │       │       ├── Balachka
# │       │       ├── Belarusian
# │       │       ├── Pannonian Rusyn
# │       │       ├── Rusyn language
# │       │       └── Ukrainian
# │       └── West Slavic
# ├── Proto-Germanic
# │   ├── Old English
# │   │   ├── Middle English
# │   │   │   ├── Early Modern English
# │   │   │   │   ├── American English
# │   │   │   │   ├── Anglo-English
# │   │   │   │   ├── Appalachian English
# │   │   │   │   ├── Australian English
# │   │   │   │   ├── Bahamian English
# │   │   │   │   ├── Belizean English
# │   │   │   │   ├── Birmingham dialect
# │   │   │   │   ├── Black Country dialect
# │   │   │   │   ├── British English
# │   │   │   │   │   ├── Myanmar English
# │   │   │   │   │   ├── New Zealand English
# │   │   │   │   │   └── South African English
# │   │   │   │   ├── California English
# │   │   │   │   ├── Cameroon English
# │   │   │   │   ├── Canadian English
# │   │   │   │   ├── Caribbean English
# │   │   │   │   ├── Cayman Islands English
# │   │   │   │   │   └── Bay Islands English
# │   │   │   │   ├── Chinglish
# │   │   │   │   ├── Cockney
# │   │   │   │   ├── Cornish English, Cornish dialect
# │   │   │   │   ├── East Midlands English
# │   │   │   │   ├── English
# │   │   │   │   ├── Falkland Islands English
# │   │   │   │   ├── Hiberno-English
# │   │   │   │   ├── High Tider
# │   │   │   │   ├── Indian English
# │   │   │   │   │   └── Bangladeshi English
# │   │   │   │   ├── Lancashire dialect
# │   │   │   │   ├── Malaysian English
# │   │   │   │   ├── Manx English
# │   │   │   │   ├── Modern English
# │   │   │   │   │   └── Euro English
# │   │   │   │   ├── New England English
# │   │   │   │   ├── New York City English
# │   │   │   │   ├── Newfoundland English
# │   │   │   │   ├── North American English
# │   │   │   │   ├── North-Central American English
# │   │   │   │   ├── Northern American English
# │   │   │   │   ├── Older Southern American English
# │   │   │   │   │   └── Southern American English
# │   │   │   │   ├── Pacific Northwest English
# │   │   │   │   ├── Pakistani English
# │   │   │   │   ├── Pennsylvania Dutch English
# │   │   │   │   ├── Philippine English
# │   │   │   │   ├── Potteries
# │   │   │   │   ├── Quebec English
# │   │   │   │   ├── Scottish English
# │   │   │   │   ├── Scouse
# │   │   │   │   ├── Standard Singapore English
# │   │   │   │   ├── Texan English
# │   │   │   │   ├── Trinidadian and Tobagonian English
# │   │   │   │   ├── Welsh English
# │   │   │   │   ├── West Country English
# │   │   │   │   ├── West Midlands English
# │   │   │   │   ├── Western American English
# │   │   │   │   └── Western Pennsylvania English
# │   │   │   ├── Early Scots
# │   │   │   │   └── Middle Scots
# │   │   │   │       └── Scots
# │   │   │   │           └── Shetland dialect
# │   │   │   ├── Fingallian
# │   │   │   └── Yola
# │   │   └── Northern Middle English
# │   │       └── Early Modern Northern English
# │   │           ├── Cumbrian dialect
# │   │           ├── Northumbrian dialect
# │   │           └── Yorkshire Dialect
# │   ├── Proto-Norse
# │   │   └── Old Norse
# │   │       ├── Dalecarlian
# │   │       ├── Danish
# │   │       ├── Dano-Norwegian
# │   │       │   ├── Norwegian Riksmål
# │   │       │   │   └── Norwegian Bokmål
# │   │       │   └── Urban East Norwegian
# │   │       ├── Greenlandic Norse
# │   │       ├── Icelandic
# │   │       ├── Old Norwegian
# │   │       │   ├── Faroese
# │   │       │   ├── Middle Norwegian
# │   │       │   │   ├── Modern Norwegian
# │   │       │   │   ├── Norwegian
# │   │       │   │   ├── Norwegian Høgnorsk
# │   │       │   │   │   └── Norwegian Nynorsk
# │   │       │   │   └── Sognamål dialect
# │   │       │   └── Norn
# │   │       └── Old Swedish
# │   │           └── Modern Swedish
# │   │               └── Swedish
# │   └── West Germanic
# │       └── Old High German
# │           └── Middle High German
# │               ├── Early New High German
# │               │   ├── German
# │               │   ├── New High German
# │               │   └── Standard High German
# │               └── Yiddish
# └── Proto-Indo-Iranian
#     └── Proto-Indo-Aryan
#         └── Vedic Sanskrit
#             └── Sanskrit
#                 ├── Maharashtri
#                 │   └── Marathi
#                 ├── Prakrit
#                 │   ├── Magadhi Prakrit
#                 │   │   ├── Abahattha
#                 │   │   │   ├── Bengali
#                 │   │   │   └── Early Sylheti
#                 │   │   │       └── Sylheti
#                 │   │   ├── Bengali–Assamese
#                 │   │   ├── Bishnupriya Manipuri
#                 │   │   ├── Eastern Indo-Aryan
#                 │   │   ├── Kamarupi Prakrit
#                 │   │   │   └── Early Assamese
#                 │   │   │       └── Assamese
#                 │   │   ├── Magahi
#                 │   │   └── Odra Prakrit
#                 │   │       └── Old Odia
#                 │   │           └── Odia
#                 │   ├── Old Nepali
#                 │   │   └── Nepali
#                 │   └── Rajasthani
#                 └── Shauraseni Prakrit
#                     ├── Gurjar Apabhraṃśa
#                     │   └── Old Western Rājasthāni
#                     │       └── Middle Gujarati
#                     │           └── Gujarati
#                     └── Old Hindi
#                         └── Hindustani
#                             ├── Kauravi
#                             │   └── Hindi
#                             └── Rekhta
#                                 └── Urdu

# %%
show_simple_tree("Sino-Tibetan language data.json",status="proto")
# Out:
# Show the linguistic tree of Proto-Sino-Tibetan languages......
# 32 languages haven't been added.
# 28 languages haven't been added.
# 28 languages haven't been added.
# 28 languages haven't been added.
# 28 languages haven't been added.
# 28 languages haven't been added.
# 28 languages haven't been added.
# These languages are not added: Proto-Kuki-Chin, Leshan dialect, Ba-Shu ChineseDisputed### Old MandarinDisputed, Middle Burmese, Mandarin, Old National Pronunciation, Zotung, Minjiang dialect, Middle Mandarin, Kokborok, HmarHmar Hwang, Proto-Min, Eastern Han Chinese, Standard Chinese, Classical Newar, Fuzhou dialect, Old Burmese, Middle Chinese, Manmasi, Chinese, Newar, Tukbemsawm, Old Mandarin, Early Tipra, Old Chinese, Burmese, Gan, Nelachal
#
#
# Proto-Sino-Tibetan
# ├── Old Tibetan
# │   └── Classical Tibetan
# │       ├── Dzongkha
# │       ├── Lhasa Tibetan
# │       └── Tibetic
# └── Proto-Tibeto-Burman
#     └── Meitei

# %%
show_simple_tree("Altaic language data.json",status="proto")
# Out:
# Show the linguistic tree of Altaic languages......
# 14 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Altaic
# ├── Ajem-Turkic
# │   └── Azerbaijani
# ├── Kipchak language
# │   └── Old Tatar
# ├── Koreanic
# │   └── Old Korean
# │       └── Middle Korean
# │           ├── Korean
# │           │   ├── North Korean standard language
# │           │   └── Zainichi Korean
# │           └── Yukjin
# ├── Middle Turkic
# │   └── Karakhanid
# │       └── Khorezmian
# │           └── Chagatai
# │               ├── Eastern Turki
# │               │   └── Uyghur
# │               ├── Karluk
# │               └── Uzbek
# ├── Old Anatolian Turkish
# │   └── Ottoman Turkish
# │       └── Turkish
# ├── Old Tatar language
# │   └── Tatar
# ├── Old Turkic
# │   ├── Old Uyghur
# │   │   └── Western Yugur
# │   └── Siberian Turkic
# ├── Proto-Japonic
# │   └── Old Japanese
# │       ├── Early Middle Japanese
# │       │   └── Late Middle Japanese
# │       │       └── Early Modern Japanese
# │       │           └── Japanese
# │       └── Hachijō
# ├── Proto-Koreanic
# └── Volga Turki
#     └── Bashkir

# %%
show_simple_tree("Uralic language data.json",status="proto")
# Out:
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# These languages are not added: Sámi, Proto-Samic
#
#
# 6efc2423-798f-11ed-ab29-3cf862572a4b

# %%
show_simple_tree("Afroasiatic language data.json",status="proto")
# Out:
# 24 languages haven't been added.
# 24 languages haven't been added.
# 24 languages haven't been added.
# 24 languages haven't been added.
# 24 languages haven't been added.
# 24 languages haven't been added.
# 24 languages haven't been added.
# These languages are not added: Aramaic, Hebrew, Old Hejazi, Hejazi Arabic, Demotic, Coptic, Mishnaic Hebrew, Biblical Hebrew, Aweer, Modern Hebrew, Egyptian, Proto-Berber, Judeo-Arabic, Punic, Numidian, Old Aramaic, Modern Standard Arabic, Late Egyptian, Medieval Hebrew, Old Arabic, Babylonian Aramaic, Classical Arabic, Proto-Aweer, Phoenician, Proto-Aweer-Garre
#
#
# 72a16a1d-798f-11ed-8339-3cf862572a4b

# %%
show_simple_tree("Indo-European language data.json",status="classification")
# Out:
# Show the linguistic tree of Indo-European languages......
# 1606 languages haven't been added.
# 996 languages haven't been added.
# 510 languages haven't been added.
# 286 languages haven't been added.
# 67 languages haven't been added.
# 8 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Indo-European
# ├── Albanian
# │   ├── Gheg
# │   │   ├── Arbanasi
# │   │   ├── Istrian Albanian
# │   │   ├── Northeastern Gheg
# │   │   ├── Northern Gheg
# │   │   ├── Northwest Gheg
# │   │   │   └── Istrian Albanian dialect
# │   │   ├── Northwestern Gheg
# │   │   ├── Southern Gheg
# │   │   ├── Upper Reka
# │   │   └── Upper Reka Albanian dialect
# │   ├── Istrian
# │   └── Tosk
# │       ├── Arbëresh
# │       └── Arvanitika
# │           ├── Attiki Arvanitika
# │           ├── Evia Arvanitika
# │           ├── Salamina Arvanitika
# │           └── Viotia Arvanitika
# ├── Anatolian
# │   ├── Carian
# │   ├── Elymian
# │   ├── Hittite
# │   ├── Luwic
# │   │   └── Luwian
# │   ├── Lycian
# │   ├── Lydian
# │   ├── Milyan
# │   ├── Mysian
# │   ├── Palaic
# │   ├── Pisidian
# │   └── Sidetic
# ├── Armenic
# │   └── Armenian
# │       └── Western Armenian
# │           ├── Homshetsi
# │           └── Mush dialect
# ├── Balto-Slavic
# │   ├── Baltic
# │   │   ├── Eastern Baltic
# │   │   │   ├── Latvian
# │   │   │   │   ├── Kursenieki language
# │   │   │   │   └── Latgalian
# │   │   │   ├── Lithuanian
# │   │   │   │   ├── Aukštaitian
# │   │   │   │   ├── Samogitian
# │   │   │   │   └── Samogitian language
# │   │   │   ├── Selonian
# │   │   │   └── Semigallian
# │   │   ├── Old Curonian
# │   │   └── Western Baltic
# │   │       ├── Galindan
# │   │       ├── Old Prussian
# │   │       ├── Skalvian
# │   │       └── Sudovian
# │   └── Slavic
# │       ├── East Slavic languages
# │       │   ├── Astrakhan Russian
# │       │   ├── Belarusian
# │       │   ├── Dagestani Russian
# │       │   ├── Lake Peipus
# │       │   ├── Old East Slavic
# │       │   ├── Old Novgorodian
# │       │   ├── Podlachian
# │       │   ├── Russian
# │       │   │   ├── Alaskan Russian
# │       │   │   ├── Doukhobor Russian
# │       │   │   └── Moscow dialect
# │       │   ├── Rusyn language
# │       │   │   ├── Lemko
# │       │   │   ├── Pannonian
# │       │   │   ├── Pannonian Rusyn
# │       │   │   ├── Prešov
# │       │   │   └── Subcarpathian
# │       │   ├── Ruthenian language
# │       │   └── Ukrainian
# │       │       ├── Among others
# │       │       ├── Balachka
# │       │       ├── Canadian Ukrainian
# │       │       ├── Hutsul
# │       │       ├── Pokuttia-Bukovina
# │       │       ├── West Polesian language
# │       │       │   └── Motolian
# │       │       └── see: Ukrainian dialects
# │       ├── South Slavic
# │       │   ├── Eastern South Slavic
# │       │   │   ├── Bulgarian
# │       │   │   │   ├── Banat Bulgarian
# │       │   │   │   └── Bulgarian dialects
# │       │   │   ├── Church Slavonic
# │       │   │   ├── Old Church Slavonic
# │       │   │   └── Torlakian
# │       │   └── Western South Slavic
# │       │       ├── Serbo-Croatian
# │       │       │   ├── Bosnian
# │       │       │   ├── Bunjevac
# │       │       │   ├── Chakavian
# │       │       │   │   ├── Burgenland Croatian
# │       │       │   │   ├── Buzet
# │       │       │   │   ├── Buzet dialect
# │       │       │   │   ├── Central Chakavian
# │       │       │   │   ├── Northern Chakavian
# │       │       │   │   ├── Southeastern Chakavian
# │       │       │   │   ├── Southern Chakavian
# │       │       │   │   ├── Southern Eastern Chakavian
# │       │       │   │   └── Southwestern Istrian
# │       │       │   ├── Croatian
# │       │       │   ├── Dialects of Serbo-Croatian:
# │       │       │   ├── Kajkavian
# │       │       │   ├── Montenegrin
# │       │       │   ├── Serbian
# │       │       │   ├── Shtokavian
# │       │       │   │   ├── Bunjevac dialect
# │       │       │   │   ├── East Bosnian
# │       │       │   │   ├── Kosovo–Resava
# │       │       │   │   ├── Molise Slavic
# │       │       │   │   ├── Neo-Shtokavian
# │       │       │   │   │   ├── Dubrovnik dialect
# │       │       │   │   │   ├── Eastern Herzegovinian
# │       │       │   │   │   └── Šumadija–Vojvodina dialect
# │       │       │   │   ├── Prizren–South Morava
# │       │       │   │   ├── Slavonian
# │       │       │   │   ├── Smederevo-Vršac
# │       │       │   │   ├── Svrljig-Zaplanje
# │       │       │   │   ├── Timok-Lužnica
# │       │       │   │   ├── Younger Ikavian
# │       │       │   │   ├── Zeta–South Sandžak
# │       │       │   │   └── Šumadija–Vojvodina
# │       │       │   ├── Shtokavianstandard
# │       │       │   └── Slavomolisano
# │       │       └── Slovene
# │       │           ├── Prekmurje Slovene
# │       │           ├── Prekmurje dialect
# │       │           ├── Resian
# │       │           │   ├── eastern microdialects
# │       │           │   └── western microdialects
# │       │           └── approx.  unstandardised dialects
# │       └── West Slavic
# │           ├── Czech–Slovak
# │           │   ├── Czech
# │           │   │   ├── Moravian
# │           │   │   │   └── Central Moravian
# │           │   │   │       └── Hantec
# │           │   │   └── Moravian Wallachian
# │           │   ├── Knaanic
# │           │   └── Slovak
# │           │       └── Eastern Slovak
# │           ├── Lechitic
# │           │   ├── Masurian
# │           │   ├── Middle Polish
# │           │   ├── Old Polish
# │           │   ├── Polabian
# │           │   ├── Polish
# │           │   │   ├── Lesser Poland dialect
# │           │   │   ├── Masovian dialects
# │           │   │   └── Warsaw subdialect
# │           │   ├── Pomeranian
# │           │   │   ├── Kashubian
# │           │   │   └── Slovincian
# │           │   └── Silesian
# │           │       ├── Cieszyn Silesian
# │           │       └── Texas Silesian
# │           └── Sorbian
# │               ├── Lower Sorbian
# │               └── Upper Sorbian
# ├── Cilician Armenian/Middle Armenian
# ├── Classical Armenian
# ├── Dacian
# ├── Germanic
# │   ├── East Germanic
# │   │   ├── Gothic
# │   │   │   └── Crimean Gothic
# │   │   └── Vandalic
# │   ├── North Germanic
# │   │   ├── Continental Scandinavian
# │   │   │   └── Danish
# │   │   │       ├── BornholmianEastern Danish
# │   │   │       ├── Dano-Norwegian
# │   │   │       ├── Insular Danish
# │   │   │       ├── Jutlandic
# │   │   │       │   └── South Jutlandic
# │   │   │       └── Norwegian Bokmål
# │   │   │           └── Norwegian Riksmål
# │   │   ├── East Danish
# │   │   │   ├── Blekingska
# │   │   │   ├── Bornholmsk
# │   │   │   ├── Bornholmska
# │   │   │   ├── Halländska
# │   │   │   ├── Scanian
# │   │   │   └── Skånska
# │   │   ├── East Scandinavian
# │   │   │   ├── Estonian Swedish
# │   │   │   └── Modern Swedish
# │   │   ├── East Scandinavian with West Scandinavian elements
# │   │   │   └── Dalecarlian
# │   │   │       ├── Elfdalian
# │   │   │       ├── Moramål
# │   │   │       └── Orsamål
# │   │   ├── Norwegian Nynorsk
# │   │   ├── Old East Norse
# │   │   │   └── Old Swedish
# │   │   ├── Old Gutnish
# │   │   ├── Old Norse
# │   │   │   ├── Insular Scandinavian
# │   │   │   │   ├── Faroese
# │   │   │   │   ├── Greenlandic Norse
# │   │   │   │   ├── Icelandic
# │   │   │   │   └── Norn
# │   │   │   ├── Norwegian
# │   │   │   │   ├── Arendalsk
# │   │   │   │   ├── Brønnøymål
# │   │   │   │   ├── Middle Norwegian
# │   │   │   │   ├── Midland Norwegian
# │   │   │   │   │   ├── Gudbrandsdalsmål
# │   │   │   │   │   └── Hallingmål-Valdris
# │   │   │   │   ├── Modern Norwegian
# │   │   │   │   ├── Norwegian Høgnorsk
# │   │   │   │   ├── Old Norwegian
# │   │   │   │   ├── Sandnes-mål
# │   │   │   │   ├── Stavangersk
# │   │   │   │   ├── Trøndersk Norwegian
# │   │   │   │   │   └── Meldal Norwegian
# │   │   │   │   ├── Urban East Norwegian
# │   │   │   │   └── Vestlandsk
# │   │   │   └── Sognamål dialect
# │   │   ├── Swedish
# │   │   │   ├── Finland Swedish
# │   │   │   │   └── Åland Swedish
# │   │   │   ├── Jämtland dialects
# │   │   │   └── Nederkalix dialect
# │   │   └── West or East Scandinavian
# │   ├── Proto-Norse
# │   └── West Germanic
# │       ├── Elbe Germanic
# │       │   ├── High German dialects
# │       │   │   ├── Central German, Middle German
# │       │   │   │   ├── East Central German
# │       │   │   │   │   ├── Erzgebirgisch
# │       │   │   │   │   ├── Halcnovian
# │       │   │   │   │   ├── High Prussian
# │       │   │   │   │   ├── Low Lusatian
# │       │   │   │   │   ├── Lusatian
# │       │   │   │   │   ├── North Upper Saxon
# │       │   │   │   │   ├── Schlesisch–Wilmesau
# │       │   │   │   │   │   └── Wymysorys
# │       │   │   │   │   ├── South Marchian
# │       │   │   │   │   ├── Thuringian
# │       │   │   │   │   └── Upper Saxon
# │       │   │   │   └── West Central German
# │       │   │   │       ├── Central Franconian
# │       │   │   │       │   ├── Moselle Franconian
# │       │   │   │       │   │   ├── Hunsrik
# │       │   │   │       │   │   ├── Luxembourgish
# │       │   │   │       │   │   └── Transylvanian Saxon
# │       │   │   │       │   └── Ripuarian
# │       │   │   │       │       ├── Central Ripuarian
# │       │   │   │       │       │   └── Colognian
# │       │   │   │       │       ├── South Bergish dialect
# │       │   │   │       │       └── Southeast Limburgish
# │       │   │   │       │           └── Kerkrade dialect
# │       │   │   │       ├── Lorraine Franconian
# │       │   │   │       └── Rhenish Franconian
# │       │   │   │           ├── Hessian
# │       │   │   │           │   ├── Central Hessian
# │       │   │   │           │   ├── East Hessian
# │       │   │   │           │   ├── North Hessian
# │       │   │   │           │   └── South Hessian
# │       │   │   │           └── Pfälzisch-Lothringisch
# │       │   │   │               └── Palatine German
# │       │   │   │                   └── Pennsylvania Dutch
# │       │   │   ├── German
# │       │   │   │   ├── Brazilian German
# │       │   │   │   ├── Early New High German
# │       │   │   │   ├── Middle High German
# │       │   │   │   ├── New High German
# │       │   │   │   └── United States German
# │       │   │   │       ├── Amana German
# │       │   │   │       └── Wisconsin German
# │       │   │   ├── Standard High German
# │       │   │   │   ├── Austrian German
# │       │   │   │   ├── German Standard German
# │       │   │   │   └── Swiss Standard German
# │       │   │   ├── Texas German
# │       │   │   ├── Upper German
# │       │   │   │   ├── Alemannic
# │       │   │   │   │   ├── High Alemannic
# │       │   │   │   │   │   ├── Bernese German
# │       │   │   │   │   │   └── Zürich German
# │       │   │   │   │   ├── Highest Alemannic German
# │       │   │   │   │   │   └── Walser German
# │       │   │   │   │   ├── Low Alemannic German
# │       │   │   │   │   │   ├── Colonia Tovar
# │       │   │   │   │   │   └── Upper Rhenish
# │       │   │   │   │   │       └── Alsatian
# │       │   │   │   │   ├── Swabian
# │       │   │   │   │   └── Swiss German
# │       │   │   │   ├── Bavarian
# │       │   │   │   │   ├── Central Bavarian
# │       │   │   │   │   │   └── Viennese
# │       │   │   │   │   ├── Cimbrian
# │       │   │   │   │   ├── Gottscheerish
# │       │   │   │   │   ├── Mòcheno
# │       │   │   │   │   ├── Northern Bavarian
# │       │   │   │   │   └── Southern Bavarian
# │       │   │   │   │       └── Hutterite German
# │       │   │   │   └── High Franconian
# │       │   │   │       ├── East Franconian
# │       │   │   │       └── South Franconian
# │       │   │   └── Yiddish
# │       │   └── Lombardic
# │       ├── North Sea Germanic
# │       │   ├── Anglo-Frisian
# │       │   │   ├── Early Modern English
# │       │   │   ├── Early Scots
# │       │   │   ├── English
# │       │   │   │   ├── Australian English
# │       │   │   │   │   └── Australian Aboriginal English
# │       │   │   │   ├── Bangladeshi English
# │       │   │   │   ├── Black Country dialect
# │       │   │   │   ├── British English
# │       │   │   │   │   ├── Anglo-English
# │       │   │   │   │   │   └── Manchester dialect
# │       │   │   │   │   ├── Cockney
# │       │   │   │   │   ├── Cornish English, Cornish dialect
# │       │   │   │   │   ├── East Midlands English
# │       │   │   │   │   ├── Gibraltarian English
# │       │   │   │   │   ├── Malaysian English
# │       │   │   │   │   ├── Manx English
# │       │   │   │   │   ├── Multicultural London English
# │       │   │   │   │   ├── Scottish English
# │       │   │   │   │   ├── Standard Singapore English
# │       │   │   │   │   ├── Welsh English
# │       │   │   │   │   ├── West Country English
# │       │   │   │   │   └── West Midlands English
# │       │   │   │   │       └── Birmingham dialect
# │       │   │   │   ├── Bungi
# │       │   │   │   ├── Cameroon English
# │       │   │   │   ├── Caribbean English
# │       │   │   │   │   ├── Antiguan and Barbudan Creole
# │       │   │   │   │   ├── Bahamian English
# │       │   │   │   │   ├── Barbadian English
# │       │   │   │   │   ├── Bay Islands English
# │       │   │   │   │   ├── Belizean English
# │       │   │   │   │   ├── Bocas del Toro Creole
# │       │   │   │   │   ├── Cayman Islands English
# │       │   │   │   │   ├── Grenadian Creole English
# │       │   │   │   │   ├── Guyanese Creole
# │       │   │   │   │   ├── Jamaican English
# │       │   │   │   │   ├── Limonese Creole
# │       │   │   │   │   ├── Miskito Coast Creole
# │       │   │   │   │   ├── Montserrat Creole
# │       │   │   │   │   ├── Puerto Rican English
# │       │   │   │   │   ├── Rama Cay Creole
# │       │   │   │   │   ├── San Andrés–Providencia Creole
# │       │   │   │   │   ├── Trinidadian and Tobagonian English
# │       │   │   │   │   │   ├── Tobagonian English Creole
# │       │   │   │   │   │   └── Trinidadian English Creole
# │       │   │   │   │   ├── Turks and Caicos Creole
# │       │   │   │   │   ├── Vincentian Creole
# │       │   │   │   │   └── Virgin Islands Creole
# │       │   │   │   ├── Chinglish
# │       │   │   │   ├── Cumbrian dialect
# │       │   │   │   │   └── Cumbrian Dialect
# │       │   │   │   ├── East Anglian English
# │       │   │   │   │   ├── Broad Norfolk
# │       │   │   │   │   ├── Essex
# │       │   │   │   │   ├── Fenland
# │       │   │   │   │   ├── Norfolk dialect
# │       │   │   │   │   └── Suffolk
# │       │   │   │   ├── Euro English
# │       │   │   │   ├── Falkland Islands English
# │       │   │   │   ├── Hiberno-English
# │       │   │   │   ├── Hong Kong English
# │       │   │   │   ├── Indian English
# │       │   │   │   ├── Lancashire dialect
# │       │   │   │   ├── Modern English
# │       │   │   │   ├── Myanmar English
# │       │   │   │   ├── New Zealand English
# │       │   │   │   ├── North American English
# │       │   │   │   │   ├── American English
# │       │   │   │   │   │   ├── African-American English
# │       │   │   │   │   │   ├── New England English
# │       │   │   │   │   │   │   ├── Eastern New England English
# │       │   │   │   │   │   │   └── Western New England English
# │       │   │   │   │   │   ├── New York City English
# │       │   │   │   │   │   ├── Northern American English
# │       │   │   │   │   │   │   └── North-Central American English
# │       │   │   │   │   │   ├── Older Southern American English
# │       │   │   │   │   │   │   └── African-American Vernacular English
# │       │   │   │   │   │   ├── Pennsylvania Dutch English
# │       │   │   │   │   │   ├── Philippine English
# │       │   │   │   │   │   ├── Southern American English
# │       │   │   │   │   │   │   ├── Appalachian English
# │       │   │   │   │   │   │   └── Texan English
# │       │   │   │   │   │   ├── Western American English
# │       │   │   │   │   │   │   ├── California English
# │       │   │   │   │   │   │   └── Pacific Northwest English
# │       │   │   │   │   │   └── Western Pennsylvania English
# │       │   │   │   │   ├── Canadian English
# │       │   │   │   │   │   └── Newfoundland English
# │       │   │   │   │   ├── Canadian English and their subdivisions
# │       │   │   │   │   ├── High Tider
# │       │   │   │   │   └── Quebec English
# │       │   │   │   ├── Northumbrian dialect
# │       │   │   │   ├── Pakistani English
# │       │   │   │   ├── Potteries
# │       │   │   │   ├── Scots
# │       │   │   │   │   ├── Central Scots
# │       │   │   │   │   ├── Glasgow dialect
# │       │   │   │   │   ├── Insular Scots
# │       │   │   │   │   ├── Northern Scots
# │       │   │   │   │   ├── Shetland dialect
# │       │   │   │   │   ├── Southern Scots
# │       │   │   │   │   └── Ulster
# │       │   │   │   ├── Scouse
# │       │   │   │   ├── South African English
# │       │   │   │   └── Yorkshire Dialect
# │       │   │   │       └── Various
# │       │   │   ├── Fingallian
# │       │   │   ├── Frisian
# │       │   │   │   ├── East Frisian
# │       │   │   │   │   ├── Saterland Frisian
# │       │   │   │   │   ├── Wangerooge Frisian
# │       │   │   │   │   └── Wursten Frisian
# │       │   │   │   ├── Middle Frisian
# │       │   │   │   ├── North Frisian
# │       │   │   │   │   ├── Eiderstedt Frisian
# │       │   │   │   │   ├── Insular North Frisian
# │       │   │   │   │   │   ├── Föhr-Amrum
# │       │   │   │   │   │   │   ├── Amrum Frisian
# │       │   │   │   │   │   │   └── Föhr Frisian
# │       │   │   │   │   │   ├── Heligoland Frisian
# │       │   │   │   │   │   └── Sylt Frisian
# │       │   │   │   │   └── Mainland North Frisian
# │       │   │   │   │       ├── Bökingharde Frisian
# │       │   │   │   │       │   ├── East Mooring
# │       │   │   │   │       │   └── West Mooring
# │       │   │   │   │       ├── Goesharde Frisian
# │       │   │   │   │       │   ├── Central Goesharde Frisian
# │       │   │   │   │       │   ├── Northern Goesharde Frisian
# │       │   │   │   │       │   └── Southern Goesharde Frisian
# │       │   │   │   │       ├── Hallingen Frisian
# │       │   │   │   │       ├── Karrharde Frisian
# │       │   │   │   │       ├── Strand Frisian
# │       │   │   │   │       │   └── Halligen Frisian
# │       │   │   │   │       └── Wiedingharde Frisian
# │       │   │   │   └── West Frisian
# │       │   │   │       ├── Hindeloopen Frisian
# │       │   │   │       ├── Schiermonnikoogs
# │       │   │   │       └── Westlauwers–Terschellings
# │       │   │   │           └── Terschellings
# │       │   │   ├── Middle English
# │       │   │   ├── Middle Scots
# │       │   │   ├── Old English
# │       │   │   │   ├── Kentish
# │       │   │   │   ├── Mercian
# │       │   │   │   ├── Northumbrian
# │       │   │   │   └── West Saxon
# │       │   │   ├── Old Frisian
# │       │   │   └── Yola
# │       │   ├── Low German
# │       │   │   ├── East Low German
# │       │   │   │   ├── Berlin German
# │       │   │   │   ├── Brandenburgish
# │       │   │   │   ├── East Pomeranian
# │       │   │   │   ├── Low Prussian
# │       │   │   │   │   ├── Eastern Low Prussian
# │       │   │   │   │   ├── Elbingian
# │       │   │   │   │   ├── Natagian
# │       │   │   │   │   ├── Nehrungisch
# │       │   │   │   │   │   └── Chortitza
# │       │   │   │   │   ├── Ostkäslausch
# │       │   │   │   │   ├── Plautdietsch
# │       │   │   │   │   ├── Samlandic
# │       │   │   │   │   ├── Vistulan
# │       │   │   │   │   ├── Werdersch
# │       │   │   │   │   │   └── Molotschna
# │       │   │   │   │   └── Westkäslausch
# │       │   │   │   └── Mecklenburgisch-Vorpommersch
# │       │   │   ├── Hamburg German
# │       │   │   └── West Low German
# │       │   │       ├── Eastphalian
# │       │   │       ├── Northern Low Saxon
# │       │   │       │   ├── Dithmarsisch
# │       │   │       │   ├── East Frisian Low Saxon
# │       │   │       │   ├── Emsländisch
# │       │   │       │   ├── Gronings
# │       │   │       │   ├── Holsteinisch
# │       │   │       │   ├── North Hanoveranian
# │       │   │       │   ├── Oldenburgisch
# │       │   │       │   └── Schleswigsch
# │       │   │       └── Westphalian
# │       │   │           ├── Drents
# │       │   │           ├── Gelders-Overijssels
# │       │   │           │   ├── Achterhooks
# │       │   │           │   ├── Sallaans
# │       │   │           │   └── Urkers
# │       │   │           ├── Stellingwarfs
# │       │   │           ├── Tweants
# │       │   │           └── Veluws
# │       │   ├── Middle Low German
# │       │   │   ├── East Elbian
# │       │   │   ├── Nordalbingian
# │       │   │   ├── North Low Saxon
# │       │   │   └── incl. East Frisian—Oldenburgish
# │       │   └── Old Saxon
# │       ├── Old High German
# │       └── Weser-Rhine Germanic
# │           ├── Frankish
# │           │   └── Old Dutch
# │           └── Low Franconian
# │               ├── Dutch
# │               │   ├── Afrikaans
# │               │   ├── Brabantian
# │               │   ├── Flemish
# │               │   │   ├── Brabantian a
# │               │   │   ├── East Flemish
# │               │   │   ├── Limburgish b
# │               │   │   └── West Flemish
# │               │   │       ├── French Flemish
# │               │   │       └── Zeelandic
# │               │   ├── Jersey Dutch
# │               │   └── Kaaps
# │               ├── Limburgish
# │               │   ├── Demerkempes
# │               │   │   └── Hasselt dialect
# │               │   ├── Horns
# │               │   │   └── Montfortian
# │               │   ├── Southern East Limburgish
# │               │   │   └── Sittard dialect
# │               │   └── Weertlands
# │               │       └── Weert dialect
# │               ├── Middle Dutch
# │               └── Stadsfries
# │                   ├── Leeuwarden
# │                   └── Liwwarders
# ├── Graeco-Phrygian
# │   ├── Hellenic
# │   │   ├── Ancient Greek
# │   │   ├── Central Hellenic
# │   │   │   ├── Aeolic Greek
# │   │   │   └── Arcadocypriot Greek
# │   │   │       └── Pamphylian Greek
# │   │   ├── Eastern Hellenic
# │   │   ├── Greek
# │   │   │   ├── Ancient dialects
# │   │   │   ├── Attic Greek
# │   │   │   │   ├── Calabrian Greek
# │   │   │   │   ├── Istanbul Greek dialect
# │   │   │   │   ├── Italiot Greek
# │   │   │   │   │   └── Griko
# │   │   │   │   ├── Koine Greek
# │   │   │   │   │   ├── Cypriot Greek
# │   │   │   │   │   └── Medieval Greek
# │   │   │   │   ├── Modern Greek
# │   │   │   │   │   ├── Cappadocian
# │   │   │   │   │   ├── Cretan
# │   │   │   │   │   ├── Cypriot
# │   │   │   │   │   ├── Demoticbase for the St. Mod. Greek
# │   │   │   │   │   ├── Himariote
# │   │   │   │   │   ├── Italiot GreekCalabrian and Griko
# │   │   │   │   │   ├── Katharevousaartificial
# │   │   │   │   │   ├── Maniot
# │   │   │   │   │   ├── Ponticincluding Mariupolitan
# │   │   │   │   │   ├── Yevanic
# │   │   │   │   │   ├── base for the St. Mod. Greek
# │   │   │   │   │   └── other
# │   │   │   │   ├── Pontic Greek
# │   │   │   │   │   ├── Mariupol Greek
# │   │   │   │   │   └── Mariupolitan Greek
# │   │   │   │   └── Southern dialects
# │   │   │   │       └── Cretan Greek
# │   │   │   ├── Doric Greek
# │   │   │   │   ├──  Ancient Macedonian
# │   │   │   │   ├── Achaean Doric
# │   │   │   │   ├── Argolic
# │   │   │   │   ├── Corinthian
# │   │   │   │   ├── Doric proper:
# │   │   │   │   ├── Elean
# │   │   │   │   ├── Epirote
# │   │   │   │   ├── Laconian
# │   │   │   │   ├── Locrian
# │   │   │   │   ├── Locrian Greek
# │   │   │   │   ├── Northwest Doric koine
# │   │   │   │   ├── Northwest Doric:
# │   │   │   │   ├── Phocian
# │   │   │   │   └── Tsakonian
# │   │   │   │       ├── Northern Tsakonian
# │   │   │   │       ├── Propontis
# │   │   │   │       └── Southern Tsakonian
# │   │   │   ├── Himariote Greek
# │   │   │   ├── Koine
# │   │   │   ├── Medieval
# │   │   │   ├── Modern dialects
# │   │   │   └── Mycenaean Greek
# │   │   ├── Macedonian
# │   │   │   └── Kriva Palanka dialect
# │   │   └── Western Hellenic
# │   └── Phrygian
# ├── Illyrian
# │   └── Messapic
# ├── Indo-Iranian
# │   ├── Indo-Aryan
# │   │   ├── Ardhamagadhi Prakrit
# │   │   ├── Bhil
# │   │   │   ├── Bareli
# │   │   │   │   ├── Palya
# │   │   │   │   ├── Pardhi
# │   │   │   │   ├── Pauri
# │   │   │   │   └── Rathwi
# │   │   │   ├── Central Bhil
# │   │   │   │   ├── Bhilali
# │   │   │   │   ├── Bhili
# │   │   │   │   ├── Chodri
# │   │   │   │   ├── Dhanki
# │   │   │   │   └── Dubli
# │   │   │   ├── Gamit
# │   │   │   ├── Kalto
# │   │   │   ├── Northern Bhil
# │   │   │   │   ├── Bauria
# │   │   │   │   ├── Bhilori
# │   │   │   │   ├── Magari
# │   │   │   │   └── Wagdi
# │   │   │   └── Vaagri Booli
# │   │   ├── Central Indo-Aryan
# │   │   │   ├── Awadhi
# │   │   │   │   ├── Fiji Hindi
# │   │   │   │   ├── Gangapari
# │   │   │   │   ├── Pardesi
# │   │   │   │   └── Uttari
# │   │   │   ├── Bagheli
# │   │   │   ├── Bhaya
# │   │   │   ├── Braj Bhasa–Kannauji
# │   │   │   │   └── Kannauji
# │   │   │   ├── Braj Bhasha
# │   │   │   ├── Bundeli
# │   │   │   ├── Chhattisgarhi
# │   │   │   │   └── Surgujia
# │   │   │   ├── Dawoodi
# │   │   │   ├── Dhodia
# │   │   │   ├── Ghera
# │   │   │   ├── Haryanvi
# │   │   │   ├── Hindustani
# │   │   │   │   ├── Andaman
# │   │   │   │   ├── Bambaiya
# │   │   │   │   ├── Bihari Hindi a
# │   │   │   │   ├── Haflong
# │   │   │   │   ├── Hindi
# │   │   │   │   │   ├── Hindi languages
# │   │   │   │   │   └── See
# │   │   │   │   ├── Kauravi
# │   │   │   │   └── Urdu
# │   │   │   │       ├── Deccani
# │   │   │   │       │   ├── Hyderabadi
# │   │   │   │       │   ├── Hyderabadi Urdu
# │   │   │   │       │   └── Mysore
# │   │   │   │       ├── Dhakaiya
# │   │   │   │       ├── Dhakaiya Urdu
# │   │   │   │       ├── Judeo-Urdu
# │   │   │   │       └── Rekhta
# │   │   │   ├── Old Hindi
# │   │   │   ├── Parya
# │   │   │   ├── Rajasthani
# │   │   │   │   ├── Bagri
# │   │   │   │   ├── Dhundhari
# │   │   │   │   ├── Gurgula
# │   │   │   │   ├── Gurjari
# │   │   │   │   ├── Harauti
# │   │   │   │   ├── Lambadi
# │   │   │   │   ├── Loarki
# │   │   │   │   ├── Malvi
# │   │   │   │   │   └── Bhoyari
# │   │   │   │   ├── Marwari
# │   │   │   │   │   ├── Dhatki
# │   │   │   │   │   ├── Goaria
# │   │   │   │   │   ├── Godwari
# │   │   │   │   │   ├── Jogi
# │   │   │   │   │   ├── Mewari
# │   │   │   │   │   └── Mewati
# │   │   │   │   ├── Nimadi
# │   │   │   │   └── Shekhawati
# │   │   │   ├── Romani
# │   │   │   │   ├── Balkan Romani
# │   │   │   │   │   ├── Arli
# │   │   │   │   │   ├── Dzambazi
# │   │   │   │   │   ├── East Bulgarian Romani
# │   │   │   │   │   ├── Greek Romani
# │   │   │   │   │   ├── Ironworker Romani
# │   │   │   │   │   ├── Lovari
# │   │   │   │   │   ├── Rumelian Romani
# │   │   │   │   │   ├── Tinners Romani
# │   │   │   │   │   ├── UrsáriErli
# │   │   │   │   │   ├── Usari
# │   │   │   │   │   └── Zargari
# │   │   │   │   ├── Carpathian Romani
# │   │   │   │   ├── Northern Romani
# │   │   │   │   │   ├── Baltic Romani
# │   │   │   │   │   ├── Finnish Kalo
# │   │   │   │   │   └── Welsh Romani
# │   │   │   │   ├── Northwestern Romani
# │   │   │   │   │   └── Sinte Romani
# │   │   │   │   │       ├── Abbruzzesi
# │   │   │   │   │       ├── Eftawagaria
# │   │   │   │   │       ├── Estracharia
# │   │   │   │   │       ├── Gadschkene
# │   │   │   │   │       ├── Kranaria
# │   │   │   │   │       ├── Krantiki
# │   │   │   │   │       ├── Lallere
# │   │   │   │   │       ├── ManoucheManuche
# │   │   │   │   │       ├── Manush
# │   │   │   │   │       ├── Manuš
# │   │   │   │   │       ├── Piedmont Sintí
# │   │   │   │   │       ├── Praistiki
# │   │   │   │   │       ├── Serbian Romani
# │   │   │   │   │       └── Venetian Sinti
# │   │   │   │   └── Vlax Romani
# │   │   │   │       └── Northern/Vlax I
# │   │   │   │           └── Kalderash Romani
# │   │   │   ├── Romani–Domari
# │   │   │   │   └── Seb Seliyer
# │   │   │   └── Sansi
# │   │   │       └── Kabutra
# │   │   ├── Central Zone
# │   │   ├── Chinali–Lahuli
# │   │   │   ├── Chinali
# │   │   │   └── Lahul Lohar
# │   │   ├── Dardic
# │   │   │   ├── Bateri
# │   │   │   ├── Brokskat
# │   │   │   ├── Chilisso
# │   │   │   ├── Dameli
# │   │   │   ├── Gawar-Bati
# │   │   │   ├── Gawri
# │   │   │   ├── Gowro
# │   │   │   ├── Indus Kohistani
# │   │   │   ├── Kalasha
# │   │   │   │   └── Urtsuniwar
# │   │   │   ├── Kalkoti
# │   │   │   ├── Kashmiri
# │   │   │   │   ├── Kishtwari
# │   │   │   │   └── Poguli
# │   │   │   ├── Khowar
# │   │   │   ├── Kohistani Shina
# │   │   │   │   ├── Jalkoti
# │   │   │   │   ├── Kolai
# │   │   │   │   └── Palasi
# │   │   │   ├── Kundal Shahi
# │   │   │   ├── Mankiyali
# │   │   │   ├── Nangalami
# │   │   │   │   ├── Grangali
# │   │   │   │   └── NangalamiNingalamit
# │   │   │   ├── Palula
# │   │   │   ├── Pashayi
# │   │   │   ├── Sawi
# │   │   │   ├── Shina
# │   │   │   ├── Shumashti
# │   │   │   ├── Tirahi
# │   │   │   ├── Torwali
# │   │   │   ├── Ushoji
# │   │   │   └── Wotapuri-Katarqalai
# │   │   ├── Dhivehi
# │   │   ├── Dom
# │   │   │   └── Domari
# │   │   │       ├── Northern Domari
# │   │   │       └── Southern Domari
# │   │   ├── Eastern Indo-Aryan
# │   │   │   ├── Abahattha
# │   │   │   ├── Bengali–Assamese
# │   │   │   │   ├── Assamese
# │   │   │   │   │   ├── Central Assamese
# │   │   │   │   │   ├── Eastern Assamese
# │   │   │   │   │   ├── Goalpariya
# │   │   │   │   │   │   ├── Eastern Goalpariya
# │   │   │   │   │   │   └── Western Golapariya
# │   │   │   │   │   ├── Kamrupi
# │   │   │   │   │   └── Kamrupi dialects
# │   │   │   │   │       ├── Barpetia
# │   │   │   │   │       ├── Barpetia dialect
# │   │   │   │   │       ├── Nalbariya dialect
# │   │   │   │   │       └── Palasbaria dialect
# │   │   │   │   ├── Bengali
# │   │   │   │   │   ├── Bengali dialects
# │   │   │   │   │   ├── Dhakaiya Kutti
# │   │   │   │   │   ├── Dobhashi Bengali
# │   │   │   │   │   ├── Eastern Bengali
# │   │   │   │   │   ├── Manbhumi
# │   │   │   │   │   ├── Rarhi
# │   │   │   │   │   ├── Sadhu Bhasha
# │   │   │   │   │   ├── Varendri
# │   │   │   │   │   │   ├── Bangladeshi variation
# │   │   │   │   │   │   └── Indian variation
# │   │   │   │   │   └── see
# │   │   │   │   ├── Bishnupriya Manipuri
# │   │   │   │   ├── Brajavali
# │   │   │   │   ├── Chakma
# │   │   │   │   ├── Chittagonian
# │   │   │   │   ├── Early Assamese
# │   │   │   │   │   └── Brajawali
# │   │   │   │   ├── Hajong
# │   │   │   │   │   ├── Barohajarya'
# │   │   │   │   │   ├── Doskina'
# │   │   │   │   │   ├── Korebari
# │   │   │   │   │   ├── Mespa'rya'
# │   │   │   │   │   └── Susung'ya'
# │   │   │   │   ├── KRNB lects
# │   │   │   │   │   ├── Deshi
# │   │   │   │   │   ├── Dhekri
# │   │   │   │   │   ├── Kamtapuri
# │   │   │   │   │   ├── Rajbansi
# │   │   │   │   │   ├── Rangpuri
# │   │   │   │   │   └── Surjapuri
# │   │   │   │   ├── Kharia Thar
# │   │   │   │   ├── Kurmukar
# │   │   │   │   ├── Noakhailla
# │   │   │   │   │   └── Chatkhil
# │   │   │   │   ├── Rajbanshi
# │   │   │   │   ├── Rohingya
# │   │   │   │   ├── Sylheti
# │   │   │   │   └── Tanchangya
# │   │   │   ├── Bihari
# │   │   │   │   ├── Angika
# │   │   │   │   ├── Bajjika
# │   │   │   │   ├── Bhojpuri
# │   │   │   │   │   ├── Caribbean Hindustani
# │   │   │   │   │   │   ├── Guyanese Hindustani
# │   │   │   │   │   │   ├── Sarnami Hindustani
# │   │   │   │   │   │   └── Trinidadian Hindustani
# │   │   │   │   │   ├── Domra
# │   │   │   │   │   ├── Madheshi
# │   │   │   │   │   ├── Mauritian Bhojpuri
# │   │   │   │   │   ├── Musahari
# │   │   │   │   │   ├── Northern Standard Bhojpuri
# │   │   │   │   │   ├── Sarnami Hindoestani
# │   │   │   │   │   ├── South African BhojpuriNaitali
# │   │   │   │   │   ├── Southern Standard Bhojpuri
# │   │   │   │   │   ├── Tharu Bhojpuri
# │   │   │   │   │   └── Western Standard Bhojpuri
# │   │   │   │   ├── Kumhali
# │   │   │   │   ├── Kuswaric
# │   │   │   │   │   ├── Bote-Darai
# │   │   │   │   │   └── Danwar
# │   │   │   │   ├── Magahi
# │   │   │   │   │   ├── Central Magahi
# │   │   │   │   │   ├── Khortha
# │   │   │   │   │   ├── Northern Magahi
# │   │   │   │   │   └── Southern Magahi
# │   │   │   │   ├── Maithili
# │   │   │   │   │   └── Thēthi
# │   │   │   │   ├── Sadanic
# │   │   │   │   │   ├── Kurmali
# │   │   │   │   │   └── Nagpuri
# │   │   │   │   └── Tharu
# │   │   │   │       ├── Buksa
# │   │   │   │       ├── Kochila Tharu
# │   │   │   │       └── Musasa
# │   │   │   ├── Halbic
# │   │   │   │   ├── Bhunjia
# │   │   │   │   ├── Halbi
# │   │   │   │   ├── Kamar
# │   │   │   │   └── Nahari
# │   │   │   └── Odia
# │   │   │       ├── Baleswari Odia
# │   │   │       ├── Bhatri
# │   │   │       ├── Bodo Parja
# │   │   │       ├── Desia
# │   │   │       ├── Ganjami Odia
# │   │   │       ├── Kupia
# │   │   │       ├── Northern Odia
# │   │   │       ├── Northwestern Odia
# │   │   │       ├── Reli
# │   │   │       ├── Sambalpuri
# │   │   │       ├── Southern Odia
# │   │   │       ├── Sundargadi Odia
# │   │   │       └── Western Odia
# │   │   ├── Eḷu
# │   │   ├── Gandhari
# │   │   ├── Kamarupi Prakrit
# │   │   ├── Khandeshi
# │   │   ├── Magadhi Prakrit
# │   │   ├── Maharashtri
# │   │   │   └── Marathi-Konkani
# │   │   │       ├── Andh
# │   │   │       ├── Canarese Konkani
# │   │   │       ├── East Indian language
# │   │   │       ├── Kadodi
# │   │   │       ├── Katkari
# │   │   │       ├── Konkani
# │   │   │       │   ├── Antruz
# │   │   │       │   ├── Bardeskari
# │   │   │       │   ├── Chitpavani
# │   │   │       │   ├── Daldi
# │   │   │       │   ├── Dialect groups: Canara Konkani
# │   │   │       │   ├── Goan Konkani
# │   │   │       │   ├── Individual dialects: Malvani
# │   │   │       │   ├── Kerala Konkani
# │   │   │       │   ├── Koli and Aagri
# │   │   │       │   ├── Maharashtrian Konkani
# │   │   │       │   ├── Malvani
# │   │   │       │   ├── Mangalorean
# │   │   │       │   ├── Pednekari
# │   │   │       │   └── Saxtti
# │   │   │       ├── Maharashtri Konkani
# │   │   │       │   ├── Agri Dhangari
# │   │   │       │   ├── Bankoti
# │   │   │       │   ├── Karadhi
# │   │   │       │   ├── Kiristanv
# │   │   │       │   ├── Koli
# │   │   │       │   ├── Kunbi
# │   │   │       │   ├── Maoli
# │   │   │       │   ├── Parabhi
# │   │   │       │   ├── Sangameshwari
# │   │   │       │   └── Thakri
# │   │   │       ├── Marathi
# │   │   │       │   ├── Berar-Deccan Marathi
# │   │   │       │   │   ├── Bijapuri
# │   │   │       │   │   └── KalvadiDharwar
# │   │   │       │   ├── East Indian Marathi
# │   │   │       │   ├── Judeo-Marathi
# │   │   │       │   ├── Thanjavur Marathi
# │   │   │       │   ├── Varhadi
# │   │   │       │   └── Varhadi Marathi
# │   │   │       ├── Phudagi
# │   │   │       └── Varli
# │   │   ├── Middle Indo-Aryan
# │   │   │   └── Pali
# │   │   ├── North-Western
# │   │   │   └── Kanjari
# │   │   ├── North-Western or Central
# │   │   │   └── Punjabi languages
# │   │   │       ├── Lahnda
# │   │   │       │   ├── Hindko
# │   │   │       │   │   ├── Awankari
# │   │   │       │   │   ├── Chacchi
# │   │   │       │   │   ├── Ghebi
# │   │   │       │   │   ├── Hazara Hindko
# │   │   │       │   │   ├── Kohati
# │   │   │       │   │   └── Peshawari
# │   │   │       │   ├── Inku
# │   │   │       │   ├── Khetrani
# │   │   │       │   ├── Pahari-Pothwari
# │   │   │       │   └── Saraiki
# │   │   │       │       ├── Riasti dialect
# │   │   │       │       └── Thali dialect
# │   │   │       └── Majhi
# │   │   ├── Northern Indo-Aryan
# │   │   │   ├── Bangani
# │   │   │   ├── Garhwali
# │   │   │   │   ├── Gangari/Gangadi
# │   │   │   │   ├── Srinagaria
# │   │   │   │   └── Tehriyali
# │   │   │   ├── Jaunpuri
# │   │   │   ├── Jumli Khas
# │   │   │   │   ├── Asi Darali
# │   │   │   │   ├── Muhu
# │   │   │   │   ├── Rasakoti
# │   │   │   │   └── Tribikoti
# │   │   │   ├── Kumaoni
# │   │   │   ├── Nagpuria
# │   │   │   ├── Nepali
# │   │   │   │   ├── Doteli
# │   │   │   │   └── Palpa
# │   │   │   ├── Rathwali
# │   │   │   └── Salani
# │   │   ├── Northwestern Indo-Aryan
# │   │   │   ├── Punjabi
# │   │   │   │   ├── Eastern Punjabi
# │   │   │   │   │   ├── Doabi Punjabi
# │   │   │   │   │   ├── Malwai
# │   │   │   │   │   └── Puadhi
# │   │   │   │   └── Shahpuri
# │   │   │   └── Sindhi
# │   │   │       ├── Jadgali
# │   │   │       ├── Kholosi
# │   │   │       ├── Kutchi
# │   │   │       ├── Lasi
# │   │   │       ├── Lawati
# │   │   │       ├── Memoni
# │   │   │       └── Sindhi Bhil
# │   │   │           ├── Badin
# │   │   │           ├── Mohrano
# │   │   │           ├── Nuclear Sindhi Bhil
# │   │   │           └── Sindhi Meghwar
# │   │   ├── Od
# │   │   ├── Old Western Rājasthāni
# │   │   ├── Paiśācī Prakrit
# │   │   ├── Prakrit
# │   │   ├── Rajasthani–Marwari
# │   │   ├── Sanskrit
# │   │   ├── Shauraseni Prakrit
# │   │   ├── Sinhala
# │   │   │   ├── Creole language
# │   │   │   └── Vedda
# │   │   ├── Vedic Sanskrit
# │   │   ├── Western Indo-Aryan
# │   │   │   └── Gujarati languages
# │   │   │       ├── Aer
# │   │   │       │   ├── Jamesabad
# │   │   │       │   └── Jikrio Goth
# │   │   │       ├── Gujarati
# │   │   │       ├── Gurjar Apabhraṃśa
# │   │   │       ├── Jandavra
# │   │   │       ├── Kachi Koli
# │   │   │       ├── Lisaan o Da'wat il-Bohra
# │   │   │       ├── Middle Gujarati
# │   │   │       ├── Parkari Koli
# │   │   │       ├── Saurashtra Language
# │   │   │       │   ├── Northern Saurashtra
# │   │   │       │   └── Southern Saurashtra
# │   │   │       ├── Vaghri
# │   │   │       ├── Vasavi
# │   │   │       └── Wadiyara Koli
# │   │   ├── Western Pahari
# │   │   │   ├── Bhadarwahi
# │   │   │   │   ├── Bhadrawahi proper
# │   │   │   │   ├── Bhalesi
# │   │   │   │   ├── Khasali dialect
# │   │   │   │   └── Padri
# │   │   │   ├── Bhateali
# │   │   │   ├── Bilaspuri
# │   │   │   ├── Chambeali
# │   │   │   │   ├── Bansbari
# │   │   │   │   ├── Bansyari
# │   │   │   │   └── Gadi Chameali
# │   │   │   ├── Churahi
# │   │   │   ├── Dogri
# │   │   │   ├── Gaddi
# │   │   │   ├── Hinduri
# │   │   │   ├── Jaunsari
# │   │   │   ├── Kangri
# │   │   │   ├── Kullui
# │   │   │   ├── Mahasu Pahari
# │   │   │   ├── Mandeali
# │   │   │   ├── Pahari Kinnauri
# │   │   │   ├── Pangwali
# │   │   │   │   ├── Dharwasi
# │   │   │   │   ├── Killar
# │   │   │   │   ├── Purthi
# │   │   │   │   └── Sach
# │   │   │   ├── Pogali
# │   │   │   ├── Rambani
# │   │   │   ├── Sarazi
# │   │   │   └── Sirmauri
# │   │   │       ├── Dharthi
# │   │   │       └── Giripari
# │   │   └── Western Zone
# │   ├── Iranian
# │   │   ├── Avestan
# │   │   ├── Eastern Iranian
# │   │   │   ├── Bactrian
# │   │   │   ├── Khwārezmian
# │   │   │   ├── Munji-Yidgha
# │   │   │   │   └── Sarghulami
# │   │   │   ├── Northeastern Eastern Iranian
# │   │   │   │   └── Pashto
# │   │   │   │       ├── Central Pashto
# │   │   │   │       ├── Northern Pashto
# │   │   │   │       ├── Pashto dialects
# │   │   │   │       ├── Southern Pashto
# │   │   │   │       └── Wanetsi
# │   │   │   ├── Northern Eastern Iranian
# │   │   │   │   ├── Scythian
# │   │   │   │   │   ├── Cimmerian
# │   │   │   │   │   ├── Ossetian
# │   │   │   │   │   │   ├── Digor
# │   │   │   │   │   │   │   └── Tual
# │   │   │   │   │   │   ├── Iron
# │   │   │   │   │   │   │   ├── Alagir
# │   │   │   │   │   │   │   ├── Ir
# │   │   │   │   │   │   │   ├── Kurtat
# │   │   │   │   │   │   │   └── Tagaur
# │   │   │   │   │   │   ├── Jassic
# │   │   │   │   │   │   └── Jassicextinct
# │   │   │   │   │   ├── Saka
# │   │   │   │   │   │   ├──  Kanchaki
# │   │   │   │   │   │   ├── Khotanese
# │   │   │   │   │   │   └── Tumshuqese
# │   │   │   │   │   ├── Wakhi
# │   │   │   │   │   └── Yaghnobi
# │   │   │   │   │       ├── Eastern Yaghnobi
# │   │   │   │   │       └── Western Yaghnobi
# │   │   │   │   └── Sogdian
# │   │   │   ├── Ormuri
# │   │   │   ├── Ormuri–Parachi
# │   │   │   │   └── Parachi
# │   │   │   ├── Shughni–Yazgulami
# │   │   │   ├── Southeastern Eastern Iranian
# │   │   │   │   └── Pamir languages
# │   │   │   │       ├── Ishkashimi
# │   │   │   │       ├── Munji
# │   │   │   │       ├── Rushani
# │   │   │   │       ├── Sanglechi
# │   │   │   │       ├── Shughnani
# │   │   │   │       │   ├── Bartangi
# │   │   │   │       │   ├── Khufi
# │   │   │   │       │   ├── Sarikoli
# │   │   │   │       │   └── Shughni
# │   │   │   │       │       ├── Oroshori
# │   │   │   │       │       ├── Oroshori dialect
# │   │   │   │       │       └── Rushani dialect
# │   │   │   │       ├── Yazgulyam
# │   │   │   │       └── Yidgha
# │   │   │   └── Wazirwola
# │   │   │       └── Masidwola
# │   │   ├── Shughni-Yazgulami
# │   │   │   └── Vanji
# │   │   └── Western Iranian
# │   │       ├── Achomi
# │   │       ├── Bashkardi
# │   │       ├── Caspian
# │   │       │   ├── Deilami
# │   │       │   ├── Gilaki
# │   │       │   │   ├── Bie Pas Gilaki
# │   │       │   │   ├── Bie Pish Gilaki
# │   │       │   │   ├── Eastern Gilaki
# │   │       │   │   ├── Galeshi Gilaki
# │   │       │   │   ├── GaleshiDeylami
# │   │       │   │   └── Western Gilaki
# │   │       │   ├── Gorgani
# │   │       │   ├── Mazandarani
# │   │       │   │   ├── Mazandarani-Gilaki
# │   │       │   │   ├── MazandaraniMain
# │   │       │   │   ├── MazandaraniRoyan
# │   │       │   │   └── Shahmirzadi
# │   │       │   └── Talysh
# │   │       ├── Central Iranian Languages
# │   │       │   └── Northwestern Central Iranian Languages
# │   │       │       └── Khansari
# │   │       ├── Central Plateau
# │   │       │   └── Judeo-Hamadani
# │   │       ├── Garmsiri
# │   │       ├── Iranian PersianWestern Persian
# │   │       │   └── Tehrani accent
# │   │       ├── Judeo-Shirazi
# │   │       ├── Kavir
# │   │       │   ├── Farvi
# │   │       │   ├── Garmai
# │   │       │   ├── Iraji
# │   │       │   └── Khuri
# │   │       ├── Kumzari
# │   │       ├── Kurdish
# │   │       │   ├── Central Kurdish
# │   │       │   │   ├── Ardalani
# │   │       │   │   ├── BabaniSilemani
# │   │       │   │   ├── Garmiyani
# │   │       │   │   ├── Hawleri
# │   │       │   │   ├── Jafi
# │   │       │   │   └── Mukriyani
# │   │       │   ├── Central KurdishSorani
# │   │       │   ├── Kordali
# │   │       │   ├── Kurmanji
# │   │       │   │   ├── Ashiti
# │   │       │   │   ├── Badini
# │   │       │   │   ├── Bayezidi
# │   │       │   │   ├── BotaniBoti
# │   │       │   │   ├── Hekari
# │   │       │   │   ├── Marashi
# │   │       │   │   ├── Mihemedi
# │   │       │   │   ├── Shemdinani
# │   │       │   │   ├── Shikaki
# │   │       │   │   └── Silivi
# │   │       │   ├── Laki
# │   │       │   ├── Northern KurdishKurmanji
# │   │       │   ├── Palewani
# │   │       │   ├── Southern Kurdish
# │   │       │   │   └── Laki
# │   │       │   └── Southern KurdishXwarîn
# │   │       ├── Luri
# │   │       │   ├── Bakhtiari
# │   │       │   ├── Central LuriMinjai
# │   │       │   └── Southern Luri
# │   │       │       └── Mamasani Luri
# │   │       ├── Median
# │   │       ├── Northwestern II
# │   │       │   └── Balochi
# │   │       │       ├── Koroshi
# │   │       │       └── Southern Balochi
# │   │       │           └── Makrani
# │   │       │               ├── Coastal
# │   │       │               ├── Karachi
# │   │       │               ├── Kechi
# │   │       │               └── Lashari
# │   │       ├── Old Persian
# │   │       ├── Parthian
# │   │       ├── Persid
# │   │       │   ├── Dezfuli-Shushtari
# │   │       │   │   ├── Dezfuli
# │   │       │   │   └── Shushtari
# │   │       │   └── Kuhmareyi
# │   │       ├── Sangsari
# │   │       ├── Semnani
# │   │       │   ├── Lasgerdi
# │   │       │   │   └── Biyabanaki
# │   │       │   └── Sorkhei
# │   │       │       └── Aftari
# │   │       ├── Sivandi
# │   │       ├── Southwestern Iranian
# │   │       │   └── Persian
# │   │       │       ├── Aimaq dialect
# │   │       │       ├── Dari Persian
# │   │       │       │   ├── Aimaqi
# │   │       │       │   ├── Badakhshi
# │   │       │       │   ├── Hazaragi
# │   │       │       │   ├── Herati
# │   │       │       │   ├── Kaboli
# │   │       │       │   ├── Laghmani
# │   │       │       │   ├── Logari
# │   │       │       │   ├── Madaklashti
# │   │       │       │   ├── Mazari
# │   │       │       │   ├── Panjshiri
# │   │       │       │   └── Sistani
# │   │       │       ├── Hazaragi
# │   │       │       ├── Iranian Persian
# │   │       │       │   ├── Abadani
# │   │       │       │   ├── Araki
# │   │       │       │   ├── Bandari
# │   │       │       │   ├── Basseri
# │   │       │       │   ├── Esfahani
# │   │       │       │   ├── Karbalai
# │   │       │       │   ├── Kashani
# │   │       │       │   ├── Kermani
# │   │       │       │   ├── Mashhadi
# │   │       │       │   ├── Qazvini
# │   │       │       │   ├── Shirazi
# │   │       │       │   ├── Tehrani
# │   │       │       │   └── Yazdi
# │   │       │       ├── Judeo-Persian
# │   │       │       ├── Judeo-Tat
# │   │       │       ├── Pahlavani
# │   │       │       ├── Tajik
# │   │       │       │   └── Bukharian
# │   │       │       └── Tat
# │   │       ├── Southwestern Western Iranian
# │   │       │   └── Middle Persian
# │   │       ├── Talysh group
# │   │       ├── Tati
# │   │       │   ├── Alviri-Vidari
# │   │       │   │   ├── Alvir
# │   │       │   │   └── Vidar
# │   │       │   ├── Harzandi
# │   │       │   │   └── Kilit
# │   │       │   ├── Karingani
# │   │       │   │   └── Kalasuri-Khoynarudi
# │   │       │   ├── Kho'ini
# │   │       │   ├── Maraghei
# │   │       │   ├── Old Azeri
# │   │       │   │   └── Tatic
# │   │       │   │       ├── Gozarkhani
# │   │       │   │       ├── Kajali
# │   │       │   │       ├── Kermanic/Central Plateau
# │   │       │   │       │   ├── Northeastern Kermanic/Central Plateau
# │   │       │   │       │   │   ├── Natanzi
# │   │       │   │       │   │   │   ├── Abyane'i
# │   │       │   │       │   │   │   ├── BadiMedian
# │   │       │   │       │   │   │   ├── Badrudi
# │   │       │   │       │   │   │   ├── Bidhandi
# │   │       │   │       │   │   │   ├── Farizandi
# │   │       │   │       │   │   │   ├── Hanjani
# │   │       │   │       │   │   │   ├── Natanzi proper
# │   │       │   │       │   │   │   └── Yarandi
# │   │       │   │       │   │   └── Soi
# │   │       │   │       │   │       ├── Abuzaydabadi
# │   │       │   │       │   │       ├── Arani-Bidgoli
# │   │       │   │       │   │       ├── Delijani
# │   │       │   │       │   │       ├── Jowshaqani
# │   │       │   │       │   │       ├── Judeo-Kashani
# │   │       │   │       │   │       ├── Kamu'i
# │   │       │   │       │   │       ├── Kesha'i
# │   │       │   │       │   │       ├── Meyma'i
# │   │       │   │       │   │       ├── Nashalji
# │   │       │   │       │   │       ├── Qohrudi
# │   │       │   │       │   │       ├── Soi proper
# │   │       │   │       │   │       ├── TariMedian
# │   │       │   │       │   │       └── Tarqi
# │   │       │   │       │   ├── Southeastern Kermanic/Central Plateau
# │   │       │   │       │   │   ├── Dari
# │   │       │   │       │   │   └── Nayini
# │   │       │   │       │   │       └── Anaraki
# │   │       │   │       │   └── Southwestern Kermanic/Central Plateau
# │   │       │   │       │       └── Gazi
# │   │       │   │       │           ├──  Kuhpa'i
# │   │       │   │       │           ├── Ardestani
# │   │       │   │       │           ├── Gazi proper
# │   │       │   │       │           ├── Jarquya'i
# │   │       │   │       │           ├── Judeo-EsfahaniJudeo-Median of Esfahan
# │   │       │   │       │           ├── Kafrudi
# │   │       │   │       │           ├── Kafruni
# │   │       │   │       │           ├── Nohuji
# │   │       │   │       │           ├── Rudashti
# │   │       │   │       │           ├── Sajzi
# │   │       │   │       │           └── Sedehi
# │   │       │   │       ├── Khalkhalic
# │   │       │   │       │   └── Karan
# │   │       │   │       │       ├── Hezarrudi
# │   │       │   │       │       ├── Kelasi
# │   │       │   │       │       └── Khoresh-e Rostam
# │   │       │   │       ├── Razajerdi
# │   │       │   │       ├── Shahrudi
# │   │       │   │       └── Tafresh
# │   │       │   │           └── Ashtiani
# │   │       │   └── Vafsi
# │   │       └── Zaza–Gorani
# │   │           ├── Gorani
# │   │           │   ├── Bajelani
# │   │           │   ├── Hawrami
# │   │           │   ├── Sarli
# │   │           │   └── Shabaki
# │   │           ├── Shabaki
# │   │           └── Zaza
# │   └── Nuristani
# │       ├── Northern Nuristani
# │       │   ├── Kamkata-vari
# │       │   │   ├── Kamviri
# │       │   │   ├── Kata-vari
# │       │   │   │   └── Eastern Kata-vari
# │       │   │   ├── Mumviri
# │       │   │   └── Shekhani
# │       │   └── Wasi-wari
# │       └── Southern Nuristani
# │           ├── Askuňu
# │           ├── Tregami
# │           ├── Waigali
# │           └── Zemiaki
# ├── Italo-Celtic
# │   ├── Celtic
# │   │   ├── Continental Celtic
# │   │   │   ├── Gaulish
# │   │   │   │   ├── Cisalpine Gaulish
# │   │   │   │   └── Galatian
# │   │   │   └── Hispano-Celtic
# │   │   │       ├── Celtiberian
# │   │   │       └── Gallaecian
# │   │   ├── Gallo-Brittonic
# │   │   ├── Insular Celtic
# │   │   │   ├── Brittonic
# │   │   │   │   ├── Common Brittonic
# │   │   │   │   ├── Middle Welsh
# │   │   │   │   ├── Old Welsh
# │   │   │   │   ├── Pictish
# │   │   │   │   ├── Southwestern Brittonic
# │   │   │   │   │   ├── Breton
# │   │   │   │   │   │   ├── Gwenedeg
# │   │   │   │   │   │   ├── Kerneveg
# │   │   │   │   │   │   ├── Leoneg
# │   │   │   │   │   │   └── Tregerieg
# │   │   │   │   │   └── Cornish
# │   │   │   │   └── Western Brythonic
# │   │   │   │       ├── Cumbric
# │   │   │   │       └── Welsh
# │   │   │   │           ├── Dyfedeg y
# │   │   │   │           ├── Gwenhwyseg
# ...
# │       │   │   │   │       │   │       │   │   ├── Eastern African French
# │       │   │   │   │       │   │       │   │   ├── Indian Ocean French
# │       │   │   │   │       │   │       │   │   ├── Maghreb French
# │       │   │   │   │       │   │       │   │   └── West African French
# │       │   │   │   │       │   │       │   ├── Belgian French
# │       │   │   │   │       │   │       │   ├── Canadian French
# │       │   │   │   │       │   │       │   │   ├── Métis French
# │       │   │   │   │       │   │       │   │   └── New England French
# │       │   │   │   │       │   │       │   ├── French of France
# │       │   │   │   │       │   │       │   ├── Frenchville French
# │       │   │   │   │       │   │       │   ├── Jersey Legal French
# │       │   │   │   │       │   │       │   ├── Louisiana French
# │       │   │   │   │       │   │       │   ├── Meridional French
# │       │   │   │   │       │   │       │   ├── Missouri French
# │       │   │   │   │       │   │       │   ├── Newfoundland French
# │       │   │   │   │       │   │       │   ├── Quebec French
# │       │   │   │   │       │   │       │   ├── Saint-Barthélemy French
# │       │   │   │   │       │   │       │   ├── Swiss French
# │       │   │   │   │       │   │       │   └── United States French
# │       │   │   │   │       │   │       ├── Gallo
# │       │   │   │   │       │   │       ├── Lorrain
# │       │   │   │   │       │   │       │   ├── Gaumais
# │       │   │   │   │       │   │       │   └── Welche
# │       │   │   │   │       │   │       ├── Middle French
# │       │   │   │   │       │   │       ├── Moselle Romance
# │       │   │   │   │       │   │       ├── Norman
# │       │   │   │   │       │   │       │   ├── Anglo-Norman
# │       │   │   │   │       │   │       │   │   ├── Auregnais
# │       │   │   │   │       │   │       │   │   └── Jèrriais
# │       │   │   │   │       │   │       │   │       ├── East Jèrriais
# │       │   │   │   │       │   │       │   │       ├── Sercquiais
# │       │   │   │   │       │   │       │   │       └── West Jèrriais
# │       │   │   │   │       │   │       │   ├── Anglo-NormanAuregnais
# │       │   │   │   │       │   │       │   ├── Augeron
# │       │   │   │   │       │   │       │   ├── Cauchois
# │       │   │   │   │       │   │       │   ├── Cotentinais
# │       │   │   │   │       │   │       │   ├── Guernésiais
# │       │   │   │   │       │   │       │   ├── Law French
# │       │   │   │   │       │   │       │   └── and Sercquiaisd
# │       │   │   │   │       │   │       ├── Old French
# │       │   │   │   │       │   │       ├── Picard
# │       │   │   │   │       │   │       ├── Poitevin-Saintongeais
# │       │   │   │   │       │   │       │   ├── Poitevin
# │       │   │   │   │       │   │       │   ├── Poitevin dialect
# │       │   │   │   │       │   │       │   ├── Saintongeais
# │       │   │   │   │       │   │       │   └── Saintongeais dialect
# │       │   │   │   │       │   │       ├── Walloon
# │       │   │   │   │       │   │       │   └── Wisconsin Walloon
# │       │   │   │   │       │   │       └── Zarphatic
# │       │   │   │   │       │   ├── Occitano-Romance
# │       │   │   │   │       │   │   ├── Catalan
# │       │   │   │   │       │   │   │   ├── Algherese / Alguerese
# │       │   │   │   │       │   │   │   ├── Balearic
# │       │   │   │   │       │   │   │   │   ├── Ibizan
# │       │   │   │   │       │   │   │   │   ├── Majorcan
# │       │   │   │   │       │   │   │   │   └── Minorcan
# │       │   │   │   │       │   │   │   ├── Judaeo-Catalan
# │       │   │   │   │       │   │   │   ├── Menorcan
# │       │   │   │   │       │   │   │   ├── Northern Catalan
# │       │   │   │   │       │   │   │   └── Valencian
# │       │   │   │   │       │   │   ├── Old Catalan
# │       │   │   │   │       │   │   ├── Old Occitan
# │       │   │   │   │       │   │   │   └── Occitanic
# │       │   │   │   │       │   │   │       └── Occitan
# │       │   │   │   │       │   │   │           ├── Auvergnat
# │       │   │   │   │       │   │   │           ├── Gascon
# │       │   │   │   │       │   │   │           │   ├── Aranese
# │       │   │   │   │       │   │   │           │   ├── Bearnese
# │       │   │   │   │       │   │   │           │   ├── Judeo-Gascon
# │       │   │   │   │       │   │   │           │   └── see below
# │       │   │   │   │       │   │   │           ├── Judæo-Occitan
# │       │   │   │   │       │   │   │           ├── Languedocian
# │       │   │   │   │       │   │   │           ├── Languedocien
# │       │   │   │   │       │   │   │           ├── Limousin
# │       │   │   │   │       │   │   │           └── Provençal
# │       │   │   │   │       │   │   │               ├── Niçard
# │       │   │   │   │       │   │   │               └── Vivaro-Alpine
# │       │   │   │   │       │   │   │                   └── Mentonasc
# │       │   │   │   │       │   │   │                       └── Roquebrunasq
# │       │   │   │   │       │   │   └── Pyrenean–Mozarabic
# │       │   │   │   │       │   └── Rhaeto-Romance
# │       │   │   │   │       │       ├── Friulian
# │       │   │   │   │       │       ├── Ladin
# │       │   │   │   │       │       │   ├── Cadorino
# │       │   │   │   │       │       │   ├── Fornes
# │       │   │   │   │       │       │   ├── Nones
# │       │   │   │   │       │       │   └── etc.
# │       │   │   │   │       │       └── Romansh
# │       │   │   │   │       │           ├── Jauer
# │       │   │   │   │       │           ├── Putèr
# │       │   │   │   │       │           ├── Surmiran
# │       │   │   │   │       │           ├── Sursilvan
# │       │   │   │   │       │           └── Vallader
# │       │   │   │   │       └── Iberian Romance
# │       │   │   │   │           └── West Iberian
# │       │   │   │   │               ├── Aragonese
# │       │   │   │   │               │   └── Judaeo-Aragonese
# │       │   │   │   │               ├── Asturleonese
# │       │   │   │   │               │   ├── Asturian
# │       │   │   │   │               │   ├── Cantabrian
# │       │   │   │   │               │   ├── Extremaduran
# │       │   │   │   │               │   ├── Leonese
# │       │   │   │   │               │   └── Mirandese
# │       │   │   │   │               ├── Castilian languages
# │       │   │   │   │               │   ├── Early Modern Spanish
# │       │   │   │   │               │   ├── Judaeo-Spanish
# │       │   │   │   │               │   │   ├── Haketia
# │       │   │   │   │               │   │   │   ├── Tetuani
# │       │   │   │   │               │   │   │   └── Tetuani Ladino
# │       │   │   │   │               │   │   ├── HaketiaTangier
# │       │   │   │   │               │   │   ├── North-Eastern
# │       │   │   │   │               │   │   ├── North-WesternSarajevo
# │       │   │   │   │               │   │   ├── Salonica
# │       │   │   │   │               │   │   ├── South-EasternIstanbul
# │       │   │   │   │               │   │   └── Tétouan
# │       │   │   │   │               │   ├── Old Spanish
# │       │   │   │   │               │   └── Spanish
# │       │   │   │   │               │       ├── Andalusian Spanish
# │       │   │   │   │               │       │   └── Llanito
# │       │   │   │   │               │       ├── Bolivian Spanish
# │       │   │   │   │               │       ├── Canarian Spanish
# │       │   │   │   │               │       ├── Central American Spanish
# │       │   │   │   │               │       │   ├── Belizean Spanish
# │       │   │   │   │               │       │   ├── Costa Rican
# │       │   │   │   │               │       │   ├── Costa Rican Spanish
# │       │   │   │   │               │       │   ├── Guatemalan
# │       │   │   │   │               │       │   ├── Guatemalan Spanish
# │       │   │   │   │               │       │   ├── Honduran
# │       │   │   │   │               │       │   ├── Honduran Spanish
# │       │   │   │   │               │       │   ├── Nicaraguan
# │       │   │   │   │               │       │   ├── Nicaraguan Spanish
# │       │   │   │   │               │       │   ├── Salvadoran
# │       │   │   │   │               │       │   └── Salvadoran Spanish
# │       │   │   │   │               │       │       ├── Caliche
# │       │   │   │   │               │       │       └── Lenca
# │       │   │   │   │               │       ├── Chilean Spanish
# │       │   │   │   │               │       ├── Colombian Spanish
# │       │   │   │   │               │       │   ├── BogotanRolo
# │       │   │   │   │               │       │   ├── Chocoano
# │       │   │   │   │               │       │   ├── Costeño Colombian Spanish
# │       │   │   │   │               │       │   ├── Cundiboyacense
# │       │   │   │   │               │       │   ├── Isleño
# │       │   │   │   │               │       │   ├── Llanero Colombian Spanish
# │       │   │   │   │               │       │   ├── Opita dialect
# │       │   │   │   │               │       │   ├── Paisa
# │       │   │   │   │               │       │   ├── Pastuso
# │       │   │   │   │               │       │   ├── Santanderean
# │       │   │   │   │               │       │   └── Valluno
# │       │   │   │   │               │       ├── Cuban Spanish
# │       │   │   │   │               │       ├── Dominican Spanish
# │       │   │   │   │               │       ├── Ecuadorian Spanish
# │       │   │   │   │               │       ├── Equatoguinean Spanish
# │       │   │   │   │               │       ├── Mexican Spanish
# │       │   │   │   │               │       ├── Murcian
# │       │   │   │   │               │       ├── New Mexican Spanish
# │       │   │   │   │               │       ├── Panamanian Spanish
# │       │   │   │   │               │       ├── Paraguayan Spanish
# │       │   │   │   │               │       ├── Peruvian Spanish
# │       │   │   │   │               │       │   └── Amazonic Spanish
# │       │   │   │   │               │       ├── Philippine Spanish
# │       │   │   │   │               │       ├── Puerto Rican Spanish
# │       │   │   │   │               │       ├── Rioplatense Spanish
# │       │   │   │   │               │       │   ├── BonaerenseEastern
# │       │   │   │   │               │       │   ├── CordobésCentral
# │       │   │   │   │               │       │   ├── CuyanoWestern
# │       │   │   │   │               │       │   ├── GuaraníticoNortheastern
# │       │   │   │   │               │       │   ├── Inner Dialects:
# │       │   │   │   │               │       │   ├── LitoraleñoCoastal
# │       │   │   │   │               │       │   ├── NorteñoNorthern
# │       │   │   │   │               │       │   ├── Outer Dialects:
# │       │   │   │   │               │       │   ├── PatagónicoSouthern
# │       │   │   │   │               │       │   ├── Uruguayan
# │       │   │   │   │               │       │   └── Uruguayan Spanish
# │       │   │   │   │               │       ├── United States Spanish
# │       │   │   │   │               │       └── Venezuelan Spanish
# │       │   │   │   │               │           ├── Amazonian
# │       │   │   │   │               │           ├── Andino
# │       │   │   │   │               │           ├── Central Venezuelan Spanish
# │       │   │   │   │               │           ├── Costeño Venezuelan Spanish
# │       │   │   │   │               │           ├── Eastern Venezuelan Spanish
# │       │   │   │   │               │           ├── Isleño d
# │       │   │   │   │               │           ├── Llanero Venezuelan Spanish
# │       │   │   │   │               │           ├── Oriental
# │       │   │   │   │               │           ├── Western Venezuelan Spanish
# │       │   │   │   │               │           └── Zuliano/Maracucho
# │       │   │   │   │               ├── Galician-Portuguese
# │       │   │   │   │               │   ├── Fala
# │       │   │   │   │               │   ├── Galician
# │       │   │   │   │               │   ├── Galician–Asturian
# │       │   │   │   │               │   └── Portuguese
# │       │   │   │   │               │       ├── Alentejan Portuguese
# │       │   │   │   │               │       ├── Angolan Portuguese
# │       │   │   │   │               │       ├── Brazilian Portuguese
# │       │   │   │   │               │       │   ├── Caipira Brazilian Portuguese dialect
# │       │   │   │   │               │       │   ├── Florianopolitan dialect
# │       │   │   │   │               │       │   ├── Fluminense-Capixaba dialect
# │       │   │   │   │               │       │   │   └── Carioca
# │       │   │   │   │               │       │   ├── Gaúcho dialect
# │       │   │   │   │               │       │   ├── Mineiro dialect
# │       │   │   │   │               │       │   ├── North coast dialect
# │       │   │   │   │               │       │   └── Paulistano dialect
# │       │   │   │   │               │       ├── Cape Verdean Portuguese
# │       │   │   │   │               │       ├── East Timorese Portuguese
# │       │   │   │   │               │       ├── European Portuguese
# │       │   │   │   │               │       ├── Guinean Portuguese
# │       │   │   │   │               │       ├── Macanese Portuguese
# │       │   │   │   │               │       ├── Minderico
# │       │   │   │   │               │       ├── Mozambican Portuguese
# │       │   │   │   │               │       ├── São Toméan Portuguese
# │       │   │   │   │               │       └── Uruguayan Portuguese
# │       │   │   │   │               ├── Mozarabic
# │       │   │   │   │               └── Navarro-Aragonese
# │       │   │   │   ├── Italo-Western
# │       │   │   │   │   ├── Italo-Dalmatian
# │       │   │   │   │   │   ├── Castelmezzano
# │       │   │   │   │   │   ├── Dalmatian
# │       │   │   │   │   │   ├── Dalmatian Romance
# │       │   │   │   │   │   │   └── Istriot
# │       │   │   │   │   │   ├── Extreme Southern Italian
# │       │   │   │   │   │   │   └── Salentino
# │       │   │   │   │   │   ├── Italian
# │       │   │   │   │   │   │   ├── Central Italian
# │       │   │   │   │   │   │   │   ├── Marchigiano
# │       │   │   │   │   │   │   │   ├── Romanesco
# │       │   │   │   │   │   │   │   └── Sabino
# │       │   │   │   │   │   │   ├── Central italian dialects
# │       │   │   │   │   │   │   ├── Tuscan dialects
# │       │   │   │   │   │   │   └── regional Italian
# │       │   │   │   │   │   ├── Judeo-Italian
# │       │   │   │   │   │   ├── Neapolitan
# │       │   │   │   │   │   │   ├── Apulian
# │       │   │   │   │   │   │   │   ├── Barese
# │       │   │   │   │   │   │   │   └── Tarantino
# │       │   │   │   │   │   │   ├── Cilentan
# │       │   │   │   │   │   │   ├── Irpinian dialect
# │       │   │   │   │   │   │   └── Vastese
# │       │   │   │   │   │   ├── Sicilian
# │       │   │   │   │   │   └── Tuscan
# │       │   │   │   │   │       ├── Corsican
# │       │   │   │   │   │       │   └── Gallurese
# │       │   │   │   │   │       ├── Florentine
# │       │   │   │   │   │       └── Sassarese
# │       │   │   │   │   └── Western Romance
# │       │   │   │   │       └── Venetian
# │       │   │   │   │           ├── Chipilo Venetian
# │       │   │   │   │           └── Talian
# │       │   │   │   ├── Pannonian Romance
# │       │   │   │   ├── Sardinian
# │       │   │   │   │   ├── Campidanese Sardinian
# │       │   │   │   │   └── Logudorese Sardinian
# │       │   │   │   └── Southern Romance
# │       │   │   │       └── African Romance
# │       │   │   └── Vulgar Latin
# │       │   └── Praenestinian
# │       ├── Lusitanian
# │       ├── Osco-Umbrian
# │       │   ├── Hernican
# │       │   ├── Marrucinian
# │       │   ├── Marsian
# │       │   ├── Oscan
# │       │   │   └── Sidicini
# │       │   ├── Paelignian language
# │       │   ├── Pre-Samnite
# │       │   ├── Sabine
# │       │   ├── South Picene
# │       │   ├── Umbrian
# │       │   └── Volscian
# │       ├── Siculian
# │       ├── Venetic
# │       └── Vestinian
# ├── Liburnian
# ├── Mixed language.
# │   └── Primarily a mix of Romani and Scots
# │       └── Scottish Cant
# ├── Paeonian
# ├── Proto-Greek
# │   └── Southern Greek
# │       └── Attic–Ionic Greek
# │           └── Ionic Greek
# │               └── Homeric Greek
# ├── Sicel
# ├── Thracian
# └── Tocharian
#     └── Kuchean

# %%
show_simple_tree("Sino-Tibetan language data.json",status="classification")
# Out:
# Show the linguistic tree of Sino-Tibetan languages......
# 959 languages haven't been added.
# 556 languages haven't been added.
# 222 languages haven't been added.
# 48 languages haven't been added.
# 11 languages haven't been added.
# 8 languages haven't been added.
# 8 languages haven't been added.
# 8 languages haven't been added.
# 8 languages haven't been added.
# 8 languages haven't been added.
# These languages are not added: Ponyo, Moji, Thopho, Muji, Core Muji, Muzi, Leinong, Laghuu
#
#
# Sino-Tibetan
# ├── Arunachal
# ├── Gongduk
# ├── Greater Siangic
# │   ├── Digaro
# │   │   ├── Digaro Mishmi
# │   │   └── Idu Mishmi
# │   └── Siangic
# │       ├── Koro
# │       └── Milang
# ├── Hrusish
# │   ├── Hruso
# │   │   └──  Levai
# │   └── Miji
# │       └── Bangru
# ├── Kaman
# ├── Kho-Bwa
# │   ├── Chug
# │   ├── Khowa
# │   ├── Lish
# │   ├── Mey–Sartang
# │   │   └── Sherdukpen
# │   │       ├── Rupa
# │   │       └── Shergaon
# │   └── Puroik
# ├── Lotha
# ├── Miju
# │   └── Zakhring
# ├── Mruic
# │   ├── Anu-Hkongso
# │   │   ├── Anu
# │   │   └── Hkongso
# │   └── Mru
# ├── Nam
# ├── Nungish
# │   ├── Anung
# │   ├── Drung
# │   │   ├── Dulong River
# │   │   └── Nu River
# │   └── Rawang
# │       ├── Longmi
# │       ├── Mutwang
# │       ├── Serwang
# │       └── Tangsarr
# ├── Raji–Raute
# │   ├── Raji
# │   │   ├── Barh Bandale
# │   │   ├── Naukule
# │   │   └── Purbiya
# │   ├── Raute
# │   └── Rawat
# ├── Rangas
# ├── Rung
# ├── Sinitic
# │   ├── Ba-Shu Chinese
# │   ├── Badong Yao
# │   ├── Cai–Long
# │   │   ├── Caijia
# │   │   ├── Longjia
# │   │   └── Lu
# │   ├── Chinese
# │   │   ├── Mandarin
# │   │   │   ├── Beijing
# │   │   │   ├── Beijing Mandarin
# │   │   │   │   ├── Beijing dialect
# │   │   │   │   │   └── Standard Chinese
# │   │   │   │   │       ├── Malaysian Mandarin
# │   │   │   │   │       ├── Mandarin Chinese in the Philippines
# │   │   │   │   │       ├── Sichuanese Standard Mandarin
# │   │   │   │   │       ├── Singaporean Mandarin
# │   │   │   │   │       │   └── Singdarin
# │   │   │   │   │       └── Taiwanese Mandarin
# │   │   │   │   ├── Chengde dialect
# │   │   │   │   └── Chifeng dialect
# │   │   │   ├── Central Plains
# │   │   │   ├── Central Plains Mandarin
# │   │   │   │   ├── Gangou
# │   │   │   │   ├── Guanzhong dialect
# │   │   │   │   ├── Luoyang dialect
# │   │   │   │   ├── Xuzhou dialect
# │   │   │   │   └── Yan-He region
# │   │   │   │       └── Dongping dialect
# │   │   │   ├── Dungan
# │   │   │   ├── Jiao–Liao
# │   │   │   ├── Jiao–Liao Mandarin
# │   │   │   │   ├── Dalian dialect
# │   │   │   │   ├── Qingdao dialect
# │   │   │   │   └── Weihai Dialect
# │   │   │   ├── Ji–Lu
# │   │   │   ├── Ji–Lu Mandarin
# │   │   │   │   ├── Jinan dialect
# │   │   │   │   └── Tianjin dialect
# │   │   │   ├── Junjiahua
# │   │   │   ├── Lan–Yin
# │   │   │   ├── Lan–Yin Mandarin
# │   │   │   ├── Lower Yangtze
# │   │   │   ├── Lower Yangtze Mandarin
# │   │   │   │   ├── Nanjing dialect
# │   │   │   │   └── Tong-Tai Mandarin
# │   │   │   ├── Nanping dialect
# │   │   │   ├── Northeastern Mandarin
# │   │   │   │   ├── Changchun dialect
# │   │   │   │   ├── Harbin dialect
# │   │   │   │   ├── Shenyang dialect
# │   │   │   │   └── Taz
# │   │   │   ├── Old Mandarin
# │   │   │   ├── Old National Pronunciation
# │   │   │   └── Southwestern Mandarin
# │   │   │       ├── Gui–Liu
# │   │   │       │   └── Wuming Mandarin
# │   │   │       ├── Kunming dialect
# │   │   │       ├── Sichuanese
# │   │   │       │   ├── Chengdu-Chongqing dialect
# │   │   │       │   ├── Chengdu–Chongqing dialect
# │   │   │       │   ├── Minjiang dialect
# │   │   │       │   │   └── Leshan dialect
# │   │   │       │   ├── Renshou–Fushun dialect
# │   │   │       │   └── Ya'an–Shimian dialect
# │   │   │       └── Wu-Tian
# │   │   │           └── Wuhan dialect
# │   │   ├── Min
# │   │   │   ├── Central Min
# │   │   │   │   ├── Sanming
# │   │   │   │   ├── Sanming dialect
# │   │   │   │   ├── Shaxian
# │   │   │   │   ├── Shaxian dialect
# │   │   │   │   ├── Yong'an
# │   │   │   │   └── Yong'an dialect
# │   │   │   ├── Coastal Min
# │   │   │   │   └── Hainanese
# │   │   │   │       ├── Haikou dialect
# │   │   │   │       ├── Lingshui dialect
# │   │   │   │       ├── Qionghai dialect
# │   │   │   │       ├── Sanya dialect
# │   │   │   │       ├── Wanning dialect
# │   │   │   │       └── Wenchang dialect
# │   │   │   ├── Northern Min
# │   │   │   │   ├── Chong'an
# │   │   │   │   ├── Jian'ou
# │   │   │   │   ├── Jianyang
# │   │   │   │   ├── Songxi
# │   │   │   │   └── Zhenghe
# │   │   │   ├── Proto-Min
# │   │   │   │   ├── Eastern Min
# │   │   │   │   │   ├── Fu'an dialect
# │   │   │   │   │   ├── Fuzhou dialect
# │   │   │   │   │   │   └── Matsu dialect
# │   │   │   │   │   ├── Houguan
# │   │   │   │   │   │   └── Fuqing dialect
# │   │   │   │   │   ├── Houguan subgroup
# │   │   │   │   │   ├── Longdu dialectGuangdong
# │   │   │   │   │   ├── Mango dialect
# │   │   │   │   │   ├── Manjiang
# │   │   │   │   │   ├── Nanlang dialectGuangdong
# │   │   │   │   │   └── Ningde dialect
# │   │   │   │   ├── Leizhou Min
# │   │   │   │   │   └── Zhanjiang dialect
# │   │   │   │   ├── Shao-Jiang
# │   │   │   │   │   ├── Jiangle dialect
# │   │   │   │   │   └── Shaowu dialect
# │   │   │   │   ├── Southern Min
# │   │   │   │   │   ├── Chaoshan
# │   │   │   │   │   │   ├── Hailufeng
# │   │   │   │   │   │   ├── ShantouSwatow
# │   │   │   │   │   │   ├── Swatow dialect
# │   │   │   │   │   │   ├── Teochew
# │   │   │   │   │   │   └── TeoyeoChaoyang
# │   │   │   │   │   ├── Datian Min
# │   │   │   │   │   ├── Hokkien
# │   │   │   │   │   │   ├── Amoy
# │   │   │   │   │   │   ├── Amoy/Xiamen
# │   │   │   │   │   │   ├── Hui'an dialect
# │   │   │   │   │   │   ├── Longyan
# │   │   │   │   │   │   ├── Medan
# │   │   │   │   │   │   ├── Penang
# │   │   │   │   │   │   ├── Philippine
# │   │   │   │   │   │   ├── Quanzhou
# │   │   │   │   │   │   │   ├── Philippine Hokkien
# │   │   │   │   │   │   │   ├── Singaporean Hokkien
# │   │   │   │   │   │   │   │   └── Southern Malaysia Hokkien
# │   │   │   │   │   │   │   │       └── Melaka Eng ChoonYongchunHokkien
# │   │   │   │   │   │   │   └── Yongchun dialect
# │   │   │   │   │   │   ├── Singaporean
# │   │   │   │   │   │   ├── Southern Peninsular Malaysian
# │   │   │   │   │   │   ├── Taiwanese
# │   │   │   │   │   │   ├── Taiwanese Hokkien
# │   │   │   │   │   │   └── Zhangzhou
# │   │   │   │   │   │       ├── Medan Hokkien
# │   │   │   │   │   │       └── Penang Hokkien
# │   │   │   │   │   └── Zhenan Min
# │   │   │   │   └── Zhongshan Min
# │   │   │   │       ├── Longdu dialect
# │   │   │   │       ├── Nanlang
# │   │   │   │       └── Sanxiang
# │   │   │   └── Puxian
# │   │   │       ├── Putian
# │   │   │       └── Xianyou
# │   │   ├── Wu
# │   │   │   ├── - major groups. Notable localities include
# │   │   │   ├── Chu–Qu Wu
# │   │   │   │   ├── Jiangshan dialect
# │   │   │   │   ├── Qingtian
# │   │   │   │   └── Quzhou dialect
# │   │   │   ├── Oujiang
# │   │   │   │   └── Wenzhounese
# │   │   │   │       ├── Ruian dialect
# │   │   │   │       └── Wencheng dialect
# │   │   │   ├── Shanghainese
# │   │   │   ├── Suzhounese
# │   │   │   ├── Taihu Wu
# │   │   │   │   ├── Hangzhou dialect
# │   │   │   │   ├── Jinxiang dialect
# │   │   │   │   ├── Ningbo dialect
# │   │   │   │   ├── Piling
# │   │   │   │   │   └── Changzhou dialect
# │   │   │   │   ├── Suzhou–Shanghai–Jiaxing
# │   │   │   │   ├── Su–Hu–Jia / Shanghai
# │   │   │   │   └── Su–Jia–Hu
# │   │   │   │       └── Wuxi dialect
# │   │   │   ├── Taizhou Wu
# │   │   │   │   └── Taizhou
# │   │   │   │       └── Tiantai Dialect
# │   │   │   ├── Wuzhou Wu
# │   │   │   │   └── Jinhua dialect
# │   │   │   └── Xuanzhou Wu
# │   │   ├── Xiang
# │   │   │   ├── Chen-Xu Xiang
# │   │   │   ├── Hengzhou Xiang
# │   │   │   ├── Ji-Xu Xiang
# │   │   │   ├── Loushao
# │   │   │   │   └── Xiangxiang dialect
# │   │   │   ├── New Xiang
# │   │   │   │   └── Changsha dialect
# │   │   │   ├── Old Xiang
# │   │   │   │   ├── Shuangfeng dialect
# │   │   │   │   └── Wugang dialect
# │   │   │   ├── Yong-Quan Xiang
# │   │   │   └── Yong–Quan Xiang
# │   │   │       └── Qiyang dialect
# │   │   ├── Xiangnan Tuhua
# │   │   └── Yue
# │   │       ├── Danzhou dialect
# │   │       ├── Gao-Yang Yue
# │   │       ├── Gao–Yang
# │   │       ├── Goulou
# │   │       │   ├── Bobai
# │   │       │   └── Yunan dialect
# │   │       ├── Gou–Lou
# │   │       ├── Luo-Guang Yue
# │   │       ├── Qin-Lian Yue
# │   │       ├── Qin–Lian
# │   │       ├── Siyi
# │   │       │   ├── Enping dialect
# │   │       │   ├── Guzhen dialect
# │   │       │   ├── Kaiping dialect
# │   │       │   ├── Siqian dialect
# │   │       │   ├── Taishan dialect
# │   │       │   ├── Taishanese
# │   │       │   └── Xinhui dialect
# │   │       ├── Siyiincl. Taishanese
# │   │       ├── Wu-Hua Yue
# │   │       ├── Wu–Hua
# │   │       ├── Yong-Xun Yue
# │   │       ├── Yong–Xun
# │   │       ├── Yuehai
# │   │       │   ├── Cantonese
# │   │       │   │   ├── Hong Kong
# │   │       │   │   ├── Hong Kong Cantonese
# │   │       │   │   ├── Malaysian
# │   │       │   │   ├── Malaysian Cantonese
# │   │       │   │   └── Xiguan
# │   │       │   ├── Guanbao
# │   │       │   ├── Guangfu
# │   │       │   ├── Guan–Bao
# │   │       │   │   ├── Dapeng dialect
# │   │       │   │   └── Weitou dialect
# │   │       │   ├── Sanyi
# │   │       │   │   └── Jiujiang dialect
# │   │       │   ├── Xiangshan
# │   │       │   └── Zhongshan
# │   │       │       └── Shiqi dialect
# │   │       └── Yuehaiincl. Cantonese
# │   ├── Classical Chinese
# │   ├── Eastern Han Chinese
# │   ├── Gan
# │   │   ├── Chang-Du
# │   │   ├── Da-Tong
# │   │   ├── Yi-Liu
# │   │   └── Ying-Yi
# │   ├── Greater Bai
# │   │   └── Bai
# │   │       ├── Jianchuan-Dali
# │   │       ├── Lama
# │   │       └── Panyi–Lama
# │   ├── Hakka
# │   │   ├── Hailu dialect
# │   │   ├── Huizhou dialect
# │   │   ├── Raoping
# │   │   ├── Tingzhou dialect
# │   │   │   └── Changting dialect
# │   │   └── Yue-Tai
# │   │       ├── Mei-Hui
# │   │       │   └── Sixian dialect
# │   │       │       ├── Northern Sixian
# │   │       │       └── Southern Sixian
# │   │       └── Taiwanese Hakka
# │   ├── Huizhou
# │   ├── Jin
# │   │   └── Zhangjiakou–Hohhot
# │   ├── Maihua
# │   ├── Middle Chinese
# │   ├── Old Chinese
# │   ├── Pinghua
# │   │   ├── Guibei Pinghua
# │   │   │   └── Tongdao Pinghua
# │   │   └── Younian dialect
# │   ├── She
# │   ├── Tuhua
# │   ├── Waxiang
# │   └── Yeheni
# ├── Taman
# ├── Tibeto-Burman
# │   ├── Burmo-Qiangic
# │   │   ├── Lolo-Burmese
# │   │   │   ├── Bailang
# │   │   │   ├── Burmish
# │   │   │   │   ├── Burmese
# │   │   │   │   │   ├── Arakanese
# │   │   │   │   │   │   ├── Marma
# │   │   │   │   │   │   └── Ramree
# │   │   │   │   │   ├── Intha-Danu
# │   │   │   │   │   │   ├── Danu
# │   │   │   │   │   │   └── Intha
# │   │   │   │   │   ├── Myeik
# │   │   │   │   │   ├── Tavoyan
# │   │   │   │   │   └── Yaw
# │   │   │   │   ├── Burmic
# │   │   │   │   │   ├── Achang
# │   │   │   │   │   └── Hpon
# │   │   │   │   ├── Maruic
# │   │   │   │   │   ├── Chashan
# │   │   │   │   │   ├── Lashi
# │   │   │   │   │   ├── Lhao Vo
# │   │   │   │   │   ├── Pela
# │   │   │   │   │   └── Zaiwa
# │   │   │   │   ├── Middle Burmese
# │   │   │   │   ├── Old Burmese
# │   │   │   │   └── Southern Burmish
# │   │   │   ├── Gong
# │   │   │   ├── Loloish
# │   │   │   │   ├── Alu
# │   │   │   │   ├── Central Loloish
# │   │   │   │   │   ├── Lawoish
# │   │   │   │   │   │   ├── Awu
# │   │   │   │   │   │   ├── Lawu
# │   │   │   │   │   │   └── Lewu
# │   │   │   │   │   ├── Lisoish
# │   │   │   │   │   │   ├── Lalo–Lavu
# │   │   │   │   │   │   │   ├── Lalo
# │   │   │   │   │   │   │   │   ├── Core Lalo
# │   │   │   │   │   │   │   │   ├── Eka
# │   │   │   │   │   │   │   │   ├── Mangdi
# │   │   │   │   │   │   │   │   ├── Xuzhang
# │   │   │   │   │   │   │   │   └── Yangliu
# │   │   │   │   │   │   │   ├── Lavu–Kuansi
# │   │   │   │   │   │   │   │   ├── Gomotage
# │   │   │   │   │   │   │   │   ├── Kua-nsi
# │   │   │   │   │   │   │   │   ├── Kuamasi
# │   │   │   │   │   │   │   │   ├── Laizisi
# │   │   │   │   │   │   │   │   ├── Lavu
# │   │   │   │   │   │   │   │   ├── Sonaga
# │   │   │   │   │   │   │   │   └── Zibusi
# │   │   │   │   │   │   │   └── Taloid
# │   │   │   │   │   │   │       ├── Lang'e
# │   │   │   │   │   │   │       ├── Naruo
# │   │   │   │   │   │   │       ├── Popei
# │   │   │   │   │   │   │       ├── Tagu
# │   │   │   │   │   │   │       └── Talu
# │   │   │   │   │   │   ├── Limi
# │   │   │   │   │   │   ├── Lipo–Lolopo
# │   │   │   │   │   │   │   ├── Hlersu
# │   │   │   │   │   │   │   ├── Lipo
# │   │   │   │   │   │   │   └── Lolopo
# │   │   │   │   │   │   ├── Lisu–Lalo
# │   │   │   │   │   │   │   ├── Lisu
# │   │   │   │   │   │   │   └── Micha
# │   │   │   │   │   │   │       └── Lamu
# │   │   │   │   │   │   └── Tanglang
# │   │   │   │   │   └── Samatu
# │   │   │   │   ├── Kazhuoish
# │   │   │   │   │   ├── Katso
# │   │   │   │   │   ├── Meuma
# │   │   │   │   │   ├── Sadu
# │   │   │   │   │   ├── Samu
# │   │   │   │   │   └── Sanie
# │   │   │   │   ├── Lahoish
# │   │   │   │   │   └── Lahu
# │   │   │   │   │       └── Kucong
# │   │   │   │   ├── Ni–Li–Kazhuoish
# │   │   │   │   │   └── Nisoish
# │   │   │   │   │       ├── Nisoid
# │   │   │   │   │       │   └── Nuosu
# │   │   │   │   │       ├── Northern Loloish
# │   │   │   │   │       │   ├── Nasoid
# │   │   │   │   │       │   │   └── Nasu
# │   │   │   │   │       │   │       ├── Aluo
# │   │   │   │   │       │   │       ├── Chesu
# │   │   │   │   │       │   │       ├── Gepo
# │   │   │   │   │       │   │       ├── Ku
# │   │   │   │   │       │   │       └── Luoji
# │   │   │   │   │       │   └── Nisu
# │   │   │   │   │       ├── Nyisu
# │   │   │   │   │       ├── Pholo
# │   │   │   │   │       └── Southeastern Loloish
# │   │   │   │   │           ├── Ache
# │   │   │   │   │           ├── Alingpo
# │   │   │   │   │           ├── Ati
# │   │   │   │   │           ├── Highland Phula
# │   │   │   │   │           │   └── Phowa
# │   │   │   │   │           │       ├── Hlepho–Phukha
# │   │   │   │   │           │       │   └── Phukha
# │   │   │   │   │           │       └── Khlula–Zokhuo
# │   │   │   │   │           │           ├── Khlula
# │   │   │   │   │           │           └── Zokhuo
# │   │   │   │   │           ├── Long
# │   │   │   │   │           ├── Lope
# │   │   │   │   │           ├── Riverine Phula
# │   │   │   │   │           │   ├── Phola
# │   │   │   │   │           │   └── Phupha
# │   │   │   │   │           ├── Sani–Azha
# │   │   │   │   │           │   ├── Axi
# │   │   │   │   │           │   ├── Azha
# │   │   │   │   │           │   ├── Azhe
# │   │   │   │   │           │   ├── Samei
# │   │   │   │   │           │   └── Sani
# │   │   │   │   │           └── Xiqi
# │   │   │   │   ├── Nusoish
# │   │   │   │   │   ├── Nusu
# │   │   │   │   │   └── Zauzou
# │   │   │   │   └── Southern Loloish
# │   │   │   │       ├── Angluo
# │   │   │   │       ├── Bi-Ka
# │   │   │   │       │   └── Piyo
# │   │   │   │       │       ├── Enu
# │   │   │   │       │       └── Kaduo
# │   │   │   │       ├── Bisoid
# │   │   │   │       │   ├── Bantang
# │   │   │   │       │   ├── Cantan
# │   │   │   │       │   ├── Cauho
# │   │   │   │       │   ├── Cốông
# │   │   │   │       │   ├── Habei
# │   │   │   │       │   ├── Khongsat
# │   │   │   │       │   ├── Laomian
# │   │   │   │       │   │   ├── Dako
# │   │   │   │       │   │   ├── Huaipa
# │   │   │   │       │   │   ├── Lanmeng
# │   │   │   │       │   │   └── Laopin
# │   │   │   │       │   ├── Laopan
# │   │   │   │       │   ├── Laoseng
# │   │   │   │       │   ├── Phongku
# │   │   │   │       │   ├── Phongset
# │   │   │   │       │   ├── Phunoi–Bisu
# │   │   │   │       │   │   ├── Bisu
# │   │   │   │       │   │   └── Phunoi
# │   │   │   │       │   ├── Phunyot
# │   │   │   │       │   ├── Pyen
# │   │   │   │       │   ├── Sangkong
# │   │   │   │       │   ├── Sinsali
# │   │   │   │       │   └── Tsukong
# │   │   │   │       ├── Duota
# │   │   │   │       ├── Hanoid
# │   │   │   │       │   ├── Akha
# │   │   │   │       │   │   ├── Akeu
# │   │   │   │       │   │   ├── Ako
# │   │   │   │       │   │   ├── Asong
# │   │   │   │       │   │   ├── Gokhy
# │   │   │   │       │   │   ├── Muda
# │   │   │   │       │   │   └── Muteun
# │   │   │   │       │   ├── Chepya
# │   │   │   │       │   ├── Gehuo
# │   │   │   │       │   ├── Guohe
# │   │   │   │       │   ├── Guozuo
# │   │   │   │       │   ├── Hani
# │   │   │   │       │   ├── Honi
# │   │   │   │       │   │   ├── Amu
# │   │   │   │       │   │   ├── Asuo
# │   │   │   │       │   │   ├── Baihong
# │   │   │   │       │   │   ├── Budu
# │   │   │   │       │   │   ├── Bukong
# │   │   │   │       │   │   ├── Duoni
# │   │   │   │       │   │   ├── Haoni
# │   │   │   │       │   │   ├── Suobi
# │   │   │   │       │   │   └── Woni
# │   │   │   │       │   ├── Khabi
# │   │   │   │       │   ├── Lami
# │   │   │   │       │   ├── Luomian
# │   │   │   │       │   ├── Nuobi
# │   │   │   │       │   ├── Nuomei
# │   │   │   │       │   ├── Qidi
# │   │   │   │       │   └── Yiche
# │   │   │   │       ├── Jino
# │   │   │   │       │   ├── Buyuan Jino
# │   │   │   │       │   └── Youle Jino
# │   │   │   │       ├── Mpi
# │   │   │   │       └── Siloid
# │   │   │   │           ├── Cosao
# │   │   │   │           ├── Khir
# │   │   │   │           ├── Paza
# │   │   │   │           ├── Phanaʼ
# │   │   │   │           ├── Sila
# │   │   │   │           └── Wanyä
# │   │   │   ├── Mondzish
# │   │   │   │   ├── Kathu
# │   │   │   │   │   └── Thou
# │   │   │   │   ├── Maang
# │   │   │   │   ├── Manga
# │   │   │   │   ├── Mango
# │   │   │   │   ├── Mantsi
# │   │   │   │   ├── Mauphu
# │   │   │   │   ├── Maza
# │   │   │   │   ├── Mongphu
# │   │   │   │   ├── Motang
# │   │   │   │   └── Muangphe
# │   │   │   ├── Naic
# │   │   │   │   ├── Naish
# │   │   │   │   │   ├── Laze
# │   │   │   │   │   └── Naxi
# │   │   │   │   ├── Namuzi
# │   │   │   │   └── Shixing
# │   │   │   └── Xiandao
# │   │   └── Qiangic
# │   │       ├── Chamdo
# │   │       │   ├── Drag-yab
# │   │       │   ├── Lamo
# │   │       │   └── Larong
# │   │       ├── Ersu–Namuzi
# │   │       │   └── Ersu
# │   │       │       ├── Lizu
# │   │       │       └── Tosu
# │   │       ├── Guiqiong
# │   │       ├── Gyalrongic
# │   │       │   ├── Gyalrong
# │   │       │   │   ├── Japhug
# │   │       │   │   ├── Situ
# │   │       │   │   ├── Tshobdun
# │   │       │   │   └── Zbu
# │   │       │   ├── Horpa
# │   │       │   ├── Simbaksuruk
# │   │       │   └── West Gyalrongic
# │   │       │       └── Tangut
# │   │       ├── Northern Qiangic
# │   │       │   └── Muya
# │   │       │       ├── East
# │   │       │       └── West
# │   │       ├── Pumi
# │   │       ├── Qiang
# │   │       │   ├── Northern Qiang
# │   │       │   └── Southern Qiang
# │   │       └── Zhaba–Queyu
# │   │           ├── Choyo
# │   │           └── Zhaba
# │   ├── Central Tibeto-Burman
# │   │   ├── Kuki-Chin–Naga
# │   │   │   ├── Angami–Pochuri
# │   │   │   │   ├── Angami
# │   │   │   │   │   └── Poula
# │   │   │   │   ├── Chokri
# │   │   │   │   ├── Khezha
# │   │   │   │   ├── Ntenyi
# │   │   │   │   ├── Pochuri
# │   │   │   │   │   └── Maluri
# │   │   │   │   ├── Rengma
# │   │   │   │   └── Sümi
# │   │   │   ├── Ao
# │   │   │   │   ├── Chirr
# │   │   │   │   ├── Chungli Ao
# │   │   │   │   ├── Long Phuri
# │   │   │   │   ├── Makury
# │   │   │   │   ├── Mongsen Ao
# │   │   │   │   ├── Para
# │   │   │   │   ├── Sangtam
# │   │   │   │   ├── Tikhir
# │   │   │   │   └── Yimkhiungrü
# │   │   │   ├── Karbi
# │   │   │   ├── Kuki-Chin
# │   │   │   │   ├── Aimol
# │   │   │   │   ├── Central Kuki-Chin
# │   │   │   │   │   ├── Bawm
# │   │   │   │   │   ├── Falam
# │   │   │   │   │   │   ├── Chorei
# │   │   │   │   │   │   ├── Khualsim
# │   │   │   │   │   │   ├── Laizo
# │   │   │   │   │   │   ├── Lente
# │   │   │   │   │   │   ├── Sim
# │   │   │   │   │   │   ├── Tapong
# │   │   │   │   │   │   ├── Tlaisun
# │   │   │   │   │   │   ├── Torr
# │   │   │   │   │   │   ├── Zahau
# │   │   │   │   │   │   └── Zanniat
# │   │   │   │   │   ├── Hakha Chin
# │   │   │   │   │   ├── Hmar cluster
# │   │   │   │   │   │   └── Hmar
# │   │   │   │   │   ├── HmarHmar Hwang
# │   │   │   │   │   │   └── Darlong
# │   │   │   │   │   ├── Hrangkhol
# │   │   │   │   │   ├── Lai
# │   │   │   │   │   ├── Mizo
# │   │   │   │   │   ├── Pangkhua
# │   │   │   │   │   ├── Saihriem
# │   │   │   │   │   └── Tawr
# │   │   │   │   ├── Khomic
# │   │   │   │   │   ├── Khumi
# │   │   │   │   │   ├── Mro-Khimi
# │   │   │   │   │   └── Rengmitca
# │   │   │   │   ├── Maraic
# │   │   │   │   │   ├── Lutuv
# │   │   │   │   │   ├── Mara
# │   │   │   │   │   │   ├── Tlosaih Kiasie
# │   │   │   │   │   │   ├── Tlosaih Saikao
# │   │   │   │   │   │   ├── Tlosaih Siaha
# │   │   │   │   │   │   └── Tlosaih Tokalo
# │   │   │   │   │   ├── Senthang
# │   │   │   │   │   └── Zyphe
# │   │   │   │   ├── Northern Kuki-Chin
# │   │   │   │   │   ├── Biate
# │   │   │   │   │   ├── Ngawn
# │   │   │   │   │   ├── Paite
# │   │   │   │   │   ├── Ralte
# │   │   │   │   │   ├── Simte
# │   │   │   │   │   ├── Sizang
# │   │   │   │   │   ├── Tedim
# │   │   │   │   │   ├── Thadou or Thadou-Kuki
# │   │   │   │   │   ├── Total population
# │   │   │   │   │   └── Vaiphei
# │   │   │   │   ├── Ranglong
# │   │   │   │   ├── Sorbung
# │   │   │   │   ├── Southern Kuki-Chin
# │   │   │   │   │   ├── Dai
# │   │   │   │   │   ├── Ekai
# │   │   │   │   │   ├── Kaang
# │   │   │   │   │   ├── Kʼchò
# │   │   │   │   │   ├── Laitu
# │   │   │   │   │   ├── Matu
# │   │   │   │   │   ├── Rungtu
# │   │   │   │   │   ├── Shö
# │   │   │   │   │   ├── Songlai
# │   │   │   │   │   ├── Sumtu
# │   │   │   │   │   ├── Thaiphum
# │   │   │   │   │   └── Welaung
# │   │   │   │   ├── Southern Naga
# │   │   │   │   │   ├── Anāl
# │   │   │   │   │   │   └── Langet
# │   │   │   │   │   ├── Chiru
# │   │   │   │   │   ├── Kharam
# │   │   │   │   │   ├── Lamkaang
# │   │   │   │   │   ├── Moyon
# │   │   │   │   │   └── Tarao
# │   │   │   │   └── Zotung
# │   │   │   │       ├── Calthawng
# │   │   │   │       ├── Lungngo
# │   │   │   │       └── Rezua
# │   │   │   ├── Naga languages
# │   │   │   ├── Tangkhul–Maring
# │   │   │   │   ├── Maring
# │   │   │   │   └── Tangkhulic
# │   │   │   │       ├── Akyaung Ari
# │   │   │   │       ├── Champhung
# │   │   │   │       ├── Huishu
# │   │   │   │       ├── Kaachai-Padāng
# │   │   │   │       ├── Khangoi
# │   │   │   │       ├── Koki
# │   │   │   │       ├── Somra
# │   │   │   │       ├── Suansu
# │   │   │   │       ├── Tangkhul
# │   │   │   │       │   ├── KupomeLuhupa
# │   │   │   │       │   ├── Phadang
# │   │   │   │       │   └── Ukhrul
# │   │   │   │       └── Tusom
# │   │   │   │           └── East Tusom
# │   │   │   └── Zemeic
# │   │   │       ├── Inpui
# │   │   │       ├── Liangmai
# │   │   │       ├── Mzieme
# │   │   │       ├── Rongmei
# │   │   │       └── Zeme
# │   │   ├── Meitei
# │   │   └── Sal
# │   │       ├── Boro–Garo
# │   │       │   ├── Barman Thar
# │   │       │   ├── Boroic
# │   │       │   │   ├── Boro
# │   │       │   │   ├── Kachari
# │   │       │   │   ├── Moran
# │   │       │   │   └── Tiwa
# │   │       │   ├── Deori
# │   │       │   ├── Dimasa
# │   │       │   ├── GaroA•chikku
# │   │       │   │   ├── Garo
# │   │       │   │   │   ├── Am•beng
# │   │       │   │   │   ├── A•tong
# │   │       │   │   │   ├── A•we ba A•kawe
# │   │       │   │   │   ├── Chibok
# │   │       │   │   │   ├── Chisak
# │   │       │   │   │   ├── Dual
# │   │       │   │   │   ├── Gara-Ganching
# │   │       │   │   │   ├── Kamrup
# │   │       │   │   │   ├── Matabeng
# │   │       │   │   │   ├── Matchi
# │   │       │   │   │   └── Me•gam
# │   │       │   │   └── Megam
# │   │       │   ├── Koch
# │   │       │   │   ├── A.tong
# │   │       │   │   ├── Rabha
# │   │       │   │   │   ├── Maituri
# │   │       │   │   │   └── Rongdani
# │   │       │   │   └── Ruga
# │   │       │   └── Kokborok
# │   │       ├── Jingpho–Luish
# │   │       │   ├── Jingpho
# │   │       │   │   ├── DziliJili
# │   │       │   │   └── Singpho
# │   │       │   └── Luish
# │   │       │       ├── Chakpa
# │   │       │       │   ├── Andro
# │   │       │       │   ├── Chairel
# │   │       │       │   ├── Phayeng
# │   │       │       │   └── SengmaiSekmai
# │   │       │       ├── Ganan
# │   │       │       ├── Kadu
# │   │       │       │   ├── Mawkhwin
# │   │       │       │   ├── Mawteik
# │   │       │       │   └── Settaw
# │   │       │       ├── Pyu
# │   │       │       └── Sak
# │   │       └── Konyak
# │   │           ├── Konyak–Chang
# │   │           │   ├── Chang
# │   │           │   ├── Khiamniungan
# │   │           │   ├── Phom
# │   │           │   └── Wancho
# │   │           ├── Makyam
# │   │           └── Tangsa–Nocte
# │   │               ├── Nocte
# │   │               ├── Tangsa
# │   │               │   ├── Muklom
# │   │               │   ├── Pangwa Naga
# │   │               │   ├── Ponthai
# │   │               │   └── Tikhak
# │   │               └── Tutsa
# │   ├── Classical Nepal Bhasa
# │   ├── Himalayish
# │   ├── Karenic
# │   │   ├── Pa'O
# │   │   ├── Pwo
# │   │   ├── Sgaw–Bghai
# │   │   │   ├── Bghai
# │   │   │   │   ├── Bwe
# │   │   │   │   ├── Geba
# │   │   │   │   ├── Geko
# │   │   │   │   ├── Lahta
# │   │   │   │   └── Padaung
# │   │   │   ├── Karenni
# │   │   │   ├── Kayaw
# │   │   │   └── S’gaw Karen language
# │   │   └── Western Bwe
# │   │       └── Blimaw
# │   ├── Lepcha
# │   ├── Newaric
# │   │   ├── Baram–Thangmi
# │   │   │   ├── Baram
# │   │   │   └── Thangmi
# │   │   │       ├── Dolakha
# │   │   │       └── Sindhupalcok
# │   │   └── Newar
# │   │       ├── Banepa
# │   │       ├── Bhaktapur
# │   │       ├── Chitlang
# │   │       ├── Dhulikhel
# │   │       ├── Dolakha Newar language
# │   │       ├── Dolakhae
# │   │       ├── Hetauda
# │   │       ├── Kathmandu
# │   │       ├── Lalitpur
# │   │       ├── Panauti
# │   │       └── Sindhupalchok
# │   ├── Tani
# │   │   ├── Adi
# │   │   │   └── Mising Language
# │   │   │       ├── Minyong
# │   │   │       └── MisingPlains Miri
# │   │   ├── Ashing
# │   │   ├── Eastern Tani
# │   │   │   ├── Bokar
# │   │   │   │   └── Ramo
# │   │   │   └── Bori
# │   │   │       ├── Karko
# │   │   │       ├── Komkar
# │   │   │       ├── Pasi
# │   │   │       └── Shimong
# │   │   ├── Nishi
# │   │   │   └── Yano
# │   │   ├── Padam
# │   │   ├── West Tani
# │   │   │   └── Nyishi
# │   │   │       ├── Aka
# │   │   │       ├── Akang
# │   │   │       ├── Aya
# │   │   │       ├── Bangni
# │   │   │       ├── Leil
# │   │   │       └── Nishang
# │   │   └── Western Tani
# │   │       ├── Apatani
# │   │       ├── Damu
# │   │       │   └──  Panggi
# │   │       ├── Subansiri
# │   │       │   ├── Bangni-Tagin
# │   │       │   │   ├── Bangniincl. Na
# │   │       │   │   ├── Na
# │   │       │   │   └── Tagin
# │   │       │   └── Galo
# │   │       │       ├── Gensi
# │   │       │       ├── Karka
# │   │       │       ├── Lare
# │   │       │       ├── Pugo
# │   │       │       ├── Taipodia
# │   │       │       └── Zɨrdo
# │   │       └── Tangam
# │   └── Tibeto-Kanauri
# │       ├── Bodish
# │       │   ├── Basum
# │       │   ├── Central Bodish
# │       │   │   ├── Lhowa
# │       │   │   │   ├── Lower MustangBahragaunle
# │       │   │   │   └── Upper Mustang
# │       │   │   └── Tibetic
# │       │   │       ├── Amdolese
# │       │   │       │   └── Choni
# │       │   │       │       ├── Hbrugchu
# │       │   │       │       └── Thewo
# │       │   │       ├── Baima
# │       │   │       │   ├── Northern Baima
# │       │   │       │   ├── Southern Baima
# │       │   │       │   └── Western Baima
# │       │   │       ├── Central Tibetan
# │       │   │       │   ├── Dolpo-Tichurong
# │       │   │       │   │   └── Tichurong
# │       │   │       │   └── Lhasa Tibetan
# │       │   │       ├── Classical Tibetan
# │       │   │       ├── Drugchu
# │       │   │       ├── Dzongkha–Lhokä
# │       │   │       │   ├── Brokkat
# │       │   │       │   ├── Brokpa
# │       │   │       │   ├── Chocha Ngacha
# │       │   │       │   ├── Dzongkha
# │       │   │       │   │   ├── Adap
# │       │   │       │   │   ├── Laya
# │       │   │       │   │   └── Lunana
# │       │   │       │   ├── Groma
# │       │   │       │   ├── Lakha
# │       │   │       │   ├── Naaba
# │       │   │       │   └── Sikkimese
# │       │   │       ├── Gserpa
# │       │   │       ├── Humla Tibetan
# │       │   │       │   ├── Eastern Humla
# │       │   │       │   ├── Lower Humla
# │       │   │       │   └── Upper Humla
# │       │   │       ├── Jirel
# │       │   │       ├── Khalong Tibetan
# │       │   │       ├── Khams Tibetan
# │       │   │       │   ├── Dongwang Tibetan
# │       │   │       │   └── Tseku
# │       │   │       ├── Kyirong–Kagate
# │       │   │       │   ├── Gyalsumdo
# │       │   │       │   ├── Hyolmo
# │       │   │       │   │   ├── Chhimi
# │       │   │       │   │   ├── Eastern YolmoSermathang
# │       │   │       │   │   ├── Ilam Yolmo
# │       │   │       │   │   ├── Lamjung Yolmo
# │       │   │       │   │   └── Western YolmoNuwakot District
# │       │   │       │   ├── Kagate
# │       │   │       │   ├── Nubri
# │       │   │       │   │   ├── Lho
# │       │   │       │   │   ├── Prok
# │       │   │       │   │   └── Sama
# │       │   │       │   └── Tsum
# │       │   │       ├── Ladakhi–Balti
# │       │   │       │   ├── Balti
# │       │   │       │   ├── Ladakhi
# │       │   │       │   │   ├── Shamskat
# │       │   │       │   │   └── Zangskari
# │       │   │       │   └── Purki
# │       │   │       ├── Lahuli–Spiti
# │       │   │       │   └── Stod Bhoti
# │       │   │       ├── Mugom-Karmarong
# │       │   │       │   ├── Karmarong
# │       │   │       │   ├── Karmarong dialect
# │       │   │       │   ├── Mugom
# │       │   │       │   └── Mugom dialect
# │       │   │       ├── Old Tibetan
# │       │   │       ├── South-Western Tibetic
# │       │   │       │   └── WDT Bhote
# │       │   │       │       └── Walungge
# │       │   │       ├── Southern Tibetic
# │       │   │       │   └── Sherpa
# │       │   │       ├── Spiti Bhoti
# │       │   │       │   └── Jad
# │       │   │       ├── Zhongu Tibetan
# │       │   │       └── Zitsadegu
# │       │   ├── East Bodish
# │       │   │   ├── Bumthang
# │       │   │   ├── Chali
# │       │   │   ├── Dzala
# │       │   │   ├── Kheng
# │       │   │   ├── Kurtöp
# │       │   │   ├── Nupbikha
# │       │   │   ├── Nyenkha
# │       │   │   └── Takpa
# │       │   └── Tshangla
# │       │       ├── Bhutan TshanglaTrashigang
# │       │       ├── India
# │       │       ├── Pemako Tshangla
# │       │       ├── Pemako Tshangla dialectTibet
# │       │       ├── West Kameng Tshangla dialectkalaktang
# │       │       └── dirang West Kameng
# │       ├── Mahakiranti
# │       │   ├── Greater Magaric
# │       │   │   ├── Chepangic
# │       │   │   │   ├── Bhujel
# │       │   │   │   └── Chepang
# │       │   │   ├── Chepangic-Raji
# │       │   │   ├── Dura
# │       │   │   ├── Magar
# │       │   │   │   └── Magar Kham
# │       │   │   └── Tandrange
# │       │   └── Kiranti
# │       │       ├── Bantawa
# │       │       ├── Central Kiranti
# │       │       │   ├── Khambu
# │       │       │   │   └── Nachhiring
# │       │       │   ├── Khambu Rai
# │       │       │   │   └── Sampang
# │       │       │   ├── Saam
# │       │       │   │   ├── Bungla
# │       │       │   │   ├── Lingkhim
# │       │       │   │   └── Sambya
# │       │       │   ├── Southern Central
# │       │       │   │   └── Dungmali
# │       │       │   └── Southern Central Kiranti
# │       │       │       └── Puma
# │       │       ├── Central, Western
# │       │       │   └── Tilung
# │       │       │       ├── Choskule
# │       │       │       ├── Dorungkecha
# │       │       │       └── Tilung proper
# │       │       ├── Chamling
# │       │       ├── Dhimalish
# │       │       │   ├── Dhimal
# │       │       │   ├── Lhokpu
# │       │       │   └── Toto
# │       │       ├── Eastern Kiranti
# │       │       │   ├── Chintang
# │       │       │   ├── Greater Yakkha
# │       │       │   │   ├── Athpare
# │       │       │   │   ├── Belhare
# │       │       │   │   ├── Chulung
# │       │       │   │   └── Yakkha
# │       │       │   └── Upper Arun
# │       │       │       ├── Lohorung
# │       │       │       ├── Meohang
# │       │       │       └── Yamphu
# │       │       ├── Kulung
# │       │       │   └── Chukwa
# │       │       ├── Limbu
# │       │       │   ├── Chhathare
# │       │       │   ├── Maiwakhole
# │       │       │   ├── Miwakhole
# │       │       │   ├── Phedape
# │       │       │   ├── Tambarkhole
# │       │       │   └── Tamrange & Panthare
# │       │       ├── Sunuwar
# │       │       │   ├── Surel
# │       │       │   └── Vayu
# │       │       └── Western Kiranti
# │       │           ├── Chaurasiya
# │       │           │   ├── Jerung
# │       │           │   └── Wambule
# │       │           ├── Northwestern Western
# │       │           ├── Sunwari
# │       │           │   └── Bahing
# │       │           ├── Thulung
# │       │           └── Upper Dudhkosi
# │       │               ├── Dumi
# │       │               ├── Khaling
# │       │               └── Koyee
# │       ├── Tamangic
# │       │   ├── Chhantyal
# │       │   ├── Ghale
# │       │   │   └── Kutang
# │       │   ├── Gurung
# │       │   ├── Kaike
# │       │   ├── Manang
# │       │   │   ├── Gyasumdo
# │       │   │   ├── Nar Phu
# │       │   │   │   ├── NarLower Nar
# │       │   │   │   └── PhuUpper Nar
# │       │   │   ├── Nar-Phu
# │       │   │   └── Nyeshangte  /'Nyishangba
# │       │   ├── Tamang
# │       │   └── Thakali
# │       │       ├── Chuksang
# │       │       ├── Tangbe
# │       │       └── Tetang
# │       └── West Himalayish
# │           ├── Almora
# │           │   ├── Byangsi
# │           │   ├── Chaudangsi
# │           │   ├── Darma
# │           │   ├── Dhuleli
# │           │   └── Zhang-Zhung
# │           ├── Bunan
# │           ├── Kanashi
# │           ├── Kanauri
# │           │   ├── Chitkuli Kinnauri
# │           │   └── Kinnauri
# │           │       └── Sunam
# │           ├── Lahaulic
# │           │   ├── Pattani
# │           │   └── Tinani
# │           └── Rangpo–Almora
# │               └── Rangpo
# ├── Tujia
# └── ʼOle

# %%
show_simple_tree("Altaic language data.json",status="classification")
# Out:
# Show the linguistic tree of Altaic languages......
# 145 languages haven't been added.
# 6 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Altaic
# ├── Ainu
# │   ├── Hokkaido Ainu
# │   ├── Kuril Ainu
# │   └── Sakhalin Ainu
# │       └── Taraika
# ├── Japonic
# │   ├── Japanese
# │   │   ├── Chūgoku Japanese
# │   │   ├── Early Middle Japanese
# │   │   ├── Early Modern Japanese
# │   │   ├── Hachijō
# │   │   ├── Hichiku Japanese
# │   │   ├── Hokkaido dialect
# │   │   ├── Hokuriku Japanese
# │   │   │   └── Kaga dialect
# │   │   │       ├── DaishōjiSouth
# │   │   │       ├── KanazawaNorth
# │   │   │       └── KomatsuCentral
# │   │   ├── Hōnichi Japanese
# │   │   │   └── Ōita dialect
# │   │   ├── Kagoshima Japanese
# │   │   │   ├── Koshikijima
# │   │   │   ├── Morokata
# │   │   │   ├── Satsuma
# │   │   │   ├── Tanegashima
# │   │   │   ├── Tokara
# │   │   │   ├── Yakushima
# │   │   │   └── Ōsumi
# │   │   ├── Kansai Japanese
# │   │   ├── Kantō Japanese
# │   │   │   ├── Eastern Kantō Japanese
# │   │   │   │   ├── Ibaraki dialect
# │   │   │   │   │   ├── Northern Ibaraki dialect
# │   │   │   │   │   ├── Southern Ibaraki dialect
# │   │   │   │   │   └── Southwest
# │   │   │   │   └── Tochigi dialect
# │   │   │   ├── Northern Izu Archipelago dialects
# │   │   │   │   ├── Izu Ōshima
# │   │   │   │   ├── Kōzu-shima
# │   │   │   │   ├── Mikura-jima
# │   │   │   │   ├── Miyake-jima
# │   │   │   │   ├── Nii-jima
# │   │   │   │   ├── Shikine-jima
# │   │   │   │   └── To-shima
# │   │   │   └── Western Kantō Japanese
# │   │   │       ├── Gunma dialect
# │   │   │       │   ├── Heiya
# │   │   │       │   ├── Sankan
# │   │   │       │   └── Southeast
# │   │   │       ├── Kanagawa dialects
# │   │   │       │   ├── Northern Kanagawa dialects
# │   │   │       │   ├── Sagami Bay
# │   │   │       │   ├── Sagami River East
# │   │   │       │   └── Sagami River West
# │   │   │       └── Tokyo dialect
# │   │   │           └── Okinawan Japanese
# │   │   ├── Late Middle Japanese
# │   │   ├── Shikoku Japanese
# │   │   ├── Tōhoku Japanese
# │   │   │   ├── Nanbu dialect
# │   │   │   │   ├── CentralIwate
# │   │   │   │   ├── CoastalIwate
# │   │   │   │   ├── KamikitaAomori
# │   │   │   │   ├── Kazuno
# │   │   │   │   ├── NorthernIwate
# │   │   │   │   ├── SanpachiAomori
# │   │   │   │   └── Shimokita
# │   │   │   ├── Northern Tōhoku Japanese
# │   │   │   │   ├── Akita dialect
# │   │   │   │   │   ├── Central Akita dialect
# │   │   │   │   │   ├── Northern Akita dialect
# │   │   │   │   │   └── Southern Akita dialect
# │   │   │   │   └── Tsugaru dialect
# │   │   │   └── Southern Tōhoku Japanese
# │   │   │       ├── Nairiku dialect
# │   │   │       │   ├── Mogami
# │   │   │       │   ├── Murayama
# │   │   │       │   └── Okitama
# │   │   │       ├── Southern Iwate dialect
# │   │   │       │   └── Kesen
# │   │   │       └── Yamagata dialect
# │   │   ├── Tōkai–Tōsan Japanese
# │   │   └── Umpaku Japanese
# │   ├── Old Japanese
# │   ├── Peninsular Japonic
# │   └── Ryukyuan
# │       ├── Northern Ryukyuan
# │       │   ├── Amami
# │       │   │   └── Southern Amami Ōshima
# │       │   ├── Amami languages
# │       │   │   ├──  Kikai
# │       │   │   ├──  Okinoerabu
# │       │   │   ├──  Yoron
# │       │   │   ├── Amami Ōshima
# │       │   │   ├── Kikai
# │       │   │   ├── Okinoerabu
# │       │   │   ├── Tokunoshima
# │       │   │   └── Yoron
# │       │   ├── Kunigami
# │       │   ├── Okinawan
# │       │   └── Ōshima–Tokunoshima
# │       └── Southern Ryukyuan
# │           ├── Macro-Yaeyama
# │           │   ├── Yaeyama
# │           │   └── Yonaguni
# │           └── Miyakoan
# │               ├── Ikema-Irabu
# │               ├── Miyako Island
# │               ├── Tarama
# │               │   └── Tarama Island
# │               └── Ōgami
# ├── Koreanic
# │   ├── Baekje
# │   ├── Han
# │   │   └── Old Korean
# │   │       └── Korean
# │   │           ├── Chungcheong
# │   │           │   ├── Northern Chungcheong
# │   │           │   └── Southern Chungcheong
# │   │           ├── Gyeonggi
# │   │           │   ├── Kaesŏnɡ dialect
# │   │           │   ├── North Gyeonggi dialect
# │   │           │   ├── Old Seoul dialect
# │   │           │   ├── South Gyeonggi dialect
# │   │           │   └── Yeongseo dialect
# │   │           ├── Gyeongsang
# │   │           │   ├── North Gyeongsang
# │   │           │   └── South Gyeongsang
# │   │           ├── Hamgyŏng
# │   │           ├── Korean dialects
# │   │           ├── Koryo-mar
# │   │           ├── Northern Korean
# │   │           │   └── Pyongan
# │   │           └── Southern Korean
# │   │               └── Jeolla
# │   │                   ├── Northern Jeolla
# │   │                   └── Southern Jeolla
# │   ├── Jeju
# │   ├── Middle Korean
# │   ├── North Korean standard language
# │   ├── Puyŏ
# │   │   ├── Buyeo
# │   │   └── Goguryeo
# │   ├── Ye-Maek
# │   ├── Yukjin
# │   └── Zainichi Korean
# ├── One of the world's primary language families
# ├── Proposed as a major language family by some
# ├── Proposed language family
# ├── Serbi–Mongolic
# │   ├── Mongolic
# │   │   ├── Central Mongolic
# │   │   │   ├── Buryat
# │   │   │   ├── Darkhat
# │   │   │   ├── Khamnigan Mongol
# │   │   │   ├── Oirat
# │   │   │   │   └── Torgut
# │   │   │   │       └── Kalmyk
# │   │   │   └── Ordos
# │   │   ├── Chakhar Mongolian
# │   │   ├── Dagur
# │   │   ├── Mogholi
# │   │   ├── Mongolian
# │   │   │   └── Khalkha
# │   │   ├── Shirongolic
# │   │   │   ├── Bonan
# │   │   │   ├── Kangjia
# │   │   │   ├── Monguor
# │   │   │   │   ├── Mangghuer
# │   │   │   │   └── Mongghul
# │   │   │   └── Santa
# │   │   ├── Southern Mongolic
# │   │   │   └── Eastern Yugur
# │   │   └── Tuoba
# │   └── Para-Mongolic
# │       ├── Khitan
# │       └── Tuyuhun
# ├── Tungusic
# │   ├── Northern Tungusic
# │   │   ├── Even
# │   │   └── Evenki group
# │   │       ├── Evenki
# │   │       │   └── Oroqen
# │   │       ├── Kili
# │   │       └── Negidal
# │   ├── Southern Tungusic
# │   │   ├── Jurchenic
# │   │   │   └── Bala
# │   │   ├── Manchu group
# │   │   │   ├── Jurchen
# │   │   │   ├── Manchu
# │   │   │   └── Sibe
# │   │   └── Nanai group
# │   │       ├── Nanai
# │   │       │   ├── Akani
# │   │       │   ├── Birar
# │   │       │   └── Samagir
# │   │       └── Ulch
# │   ├── Southern/Central
# │   │   └── Central-Western/Nanai group
# │   │       └── Uilta
# │   └── Udegheic
# │       ├── Oroch
# │       └── Udege Group
# │           └── Udege
# ├── Turkic
# │   ├── Common Turkic
# │   │   ├── Arghu
# │   │   │   └── Khalaj
# │   │   │       ├── Dāγān  :
# │   │   │       ├── Talx-āb  :   a
# │   │   │       └── Xarrāb  :
# │   │   ├── Karluk
# │   │   │   ├── Chagatai
# │   │   │   ├── Ili Turki
# │   │   │   ├── Khorezmian
# │   │   │   ├── Middle Turkic
# │   │   │   │   └── Karakhanid
# │   │   │   ├── Uyghur
# │   │   │   │   └── Lop
# │   │   │   └── Uzbek
# │   │   ├── Kipchak
# │   │   │   ├── Eastern Kipchak
# │   │   │   │   └── Fergana Kipchak
# │   │   │   ├── Kipchak-Nogay
# │   │   │   │   └── Siberian Tatar
# │   │   │   │       └── Baraba
# │   │   │   ├── Kipchak–Bulgar
# │   │   │   │   ├── Old Tatar
# │   │   │   │   └── Tatar
# │   │   │   ├── Kipchak–Cuman
# │   │   │   │   ├── Armeno-Kipchak
# │   │   │   │   └── Karachay-Balkar
# │   │   │   │       ├── Balkar
# │   │   │   │       └── Karachay
# │   │   │   ├── Kipchak–Nogai
# │   │   │   │   ├── Karakalpak
# │   │   │   │   ├── Kazakh
# │   │   │   │   └── Nogai
# │   │   │   ├── Kypchak–Cuman
# │   │   │   │   ├── Cuman
# │   │   │   │   │   ├── Crimean Tatar
# │   │   │   │   │   └── Krymchak
# │   │   │   │   ├── Karaim
# │   │   │   │   └── Kumyk
# │   │   │   ├── Kyrgyz–Kipchak
# │   │   │   │   ├── Kyrgyz
# │   │   │   │   └── Southern Altai Turkic
# │   │   │   │       └── Southern Altai
# │   │   │   ├── Mamluk-Kipchak
# │   │   │   ├── North Kipchak
# │   │   │   │   └── Bashkir
# │   │   │   └── West Kypchak
# │   │   │       └── Urum
# │   │   │           ├── North Azovian
# │   │   │           └── Tsalka
# │   │   ├── Oghuz languages
# │   │   │   ├── Balkan Gagauz
# │   │   │   ├── Eastern Oghuz
# │   │   │   │   ├── Khorasani Turkic
# │   │   │   │   └── Turkmen
# │   │   │   │       └── Trukhmen
# │   │   │   ├── Old Anatolian Turkish
# │   │   │   │   └── Ajem-Turkic
# │   │   │   ├── Pecheneg
# │   │   │   ├── Salar
# │   │   │   │   ├── GaiziJiezi
# │   │   │   │   ├── Ili Salar
# │   │   │   │   └── Mengda
# │   │   │   ├── Southern Oghuz
# │   │   │   │   ├── Chaharmahali Turkic
# │   │   │   │   └── Qashqai
# │   │   │   └── Western Oghuz
# │   │   │       ├── Azerbaijani
# │   │   │       │   ├── Afshar
# │   │   │       │   ├── Salchuq
# │   │   │       │   ├── Sonqori
# │   │   │       │   └── Yerevan
# │   │   │       ├── Gagauz
# │   │   │       ├── Ottoman Turkish
# │   │   │       └── Turkish
# │   │   │           ├── Cypriot Turkish
# │   │   │           ├── Iraqi Turkmen
# │   │   │           ├── Karamanli Turkish
# │   │   │           ├── Karamanlı Turkish
# │   │   │           ├── Meskhetian Turkish
# │   │   │           ├── Rumelian Turkish
# │   │   │           └── Syrian Turkish
# │   │   └── Siberian Turkic
# │   │       ├── Northern Siberian
# │   │       │   ├── Dolgan
# │   │       │   │   ├── Avam Dialect
# │   │       │   │   ├── Khatanga Dialect
# │   │       │   │   ├── Norilsk Dialect
# │   │       │   │   └── Yenisei Dialect
# │   │       │   └── Yakut
# │   │       ├── Old Turkic
# │   │       │   ├── Old Uyghur
# │   │       │   └── Orkhon Turkic
# │   │       ├── South Siberian
# │   │       │   ├── Chulym
# │   │       │   │   ├── Lower Chulym
# │   │       │   │   └── Middle Chulym
# │   │       │   ├── Sayan Turkic
# │   │       │   │   ├── Dukha
# │   │       │   │   ├── Soyot-Tsaatan
# │   │       │   │   ├── Tofa
# │   │       │   │   └── Tuvan
# │   │       │   └── Yenisei Turkic
# │   │       │       ├── Fuyu Kyrgyz
# │   │       │       ├── Khakas
# │   │       │       │   └── Fuyü Gïrgïs
# │   │       │       ├── Northern Altai
# │   │       │       │   ├──  Tubalar
# │   │       │       │   ├── Chelkan
# │   │       │       │   └── Kumandy
# │   │       │       ├── Shor
# │   │       │       └── Western Yugur
# │   │       ├── Southern Siberian
# │   │       └── Southern Siberian or Kyrgyz–Kipchak
# │   │           └── Altai
# │   └── Oghuric
# │       ├── Bulgar
# │       ├── Chuvash
# │       └── Khazar
# ├── Unclassified, possiblyPara-Mongolic or isolate
# ├── convergence zone
# ├── proposed language family
# └── Äynu

# %%
show_simple_tree("Uralic language data.json",status="classification")
# Out:
# Show the linguistic tree of Uralic languages......
# 85 languages haven't been added.
# 32 languages haven't been added.
# 0 languages haven't been added.
# These languages are not added:
#
#
# Uralic
# ├── Finno-Samic
# ├── Finno-Ugric
# │   ├── Finno-Permic
# │   │   ├── Finnic
# │   │   │   ├── Meryan
# │   │   │   ├── Northern Finnic
# │   │   │   │   ├── Finnish
# │   │   │   │   │   ├── Ingrian Finnish
# │   │   │   │   │   ├── Kven
# │   │   │   │   │   ├── Meänkieli
# │   │   │   │   │   ├── Rauma dialect
# │   │   │   │   │   └── Värmland Finnish dialect
# │   │   │   │   ├── Ingrian
# │   │   │   │   ├── Karelian
# │   │   │   │   │   └── Livvi-Karelian
# │   │   │   │   ├── Ludic
# │   │   │   │   └── Veps
# │   │   │   ├── South Estonian
# │   │   │   │   ├── Kraasna
# │   │   │   │   ├── Leivu
# │   │   │   │   ├── Ludza
# │   │   │   │   └── Võro
# │   │   │   │       └── Seto
# │   │   │   └── Southern Finnic
# │   │   │       ├── Estonian
# │   │   │       ├── Livonian
# │   │   │       │   ├── Courland
# │   │   │       │   └── Salaca
# │   │   │       └── Votic
# │   │   │           ├── Krevinian
# │   │   │           └── Kukkuzi
# │   │   ├── Finno-Volgaic
# │   │   │   └── Mordvinic
# │   │   │       ├── Erzya
# │   │   │       ├── Meshchera
# │   │   │       └── Moksha
# │   │   ├── Mari
# │   │   │   ├── Meadow Mari
# │   │   │   └── Western Mari
# │   │   │       ├── Hill Mari
# │   │   │       └── Northwestern Mari
# │   │   ├── Permic
# │   │   │   ├── Komi language
# │   │   │   │   └── Komi-Yodz
# │   │   │   ├── Permyak
# │   │   │   └── Udmurt
# │   │   └── Sámi
# │   │       ├── Akkala Sámi
# │   │       ├── Inari Sámi
# │   │       ├── Kainuu Sámi
# │   │       ├── Kemi Sámi
# │   │       ├── Lule Sámi
# │   │       ├── Northern Sámi
# │   │       ├── Peninsula
# │   │       │   └── Kildin Sámi
# │   │       ├── Pite Sámi
# │   │       ├── Skolt Sámi
# │   │       ├── Southern Sámi
# │   │       ├── Ter Sámi
# │   │       └── Ume Sámi
# │   └── Ugric
# │       ├── Hungarian
# │       └── Ob-Ugric
# │           ├── Khanty
# │           │   ├── Far Eastern
# │           │   ├── Northern Khanty
# │           │   ├── Southern Khanty
# │           │   └── Surgut
# │           └── Mansi
# │               ├── Eastern Mansi
# │               ├── Northern Mansi
# │               ├── Southern Mansi
# │               └── Western Mansi
# └── Samoyedic
#     ├── Core Samoyedic
#     │   └── Kamas–Selkup
#     │       ├── Kamassian
#     │       │   └── Koibal
#     │       └── Selkup
#     ├── Enets
#     │   └── Nenets
#     │       ├── Forest Nenets
#     │       └── Tundra Nenets
#     ├── Enets–Nenets
#     │   └── Yurats
#     ├── Mator
#     │   ├── Karagas
#     │   └── Taygi
#     └── Nganasan
#         ├── Avam
#         └── Vadey

# %%
show_simple_tree("Afroasiatic language data.json",status="classification")
# Out:
# Show the linguistic tree of Afro-Asiatic languages......
# Show the linguistic tree of Afroasiatic languages......
# 345 languages haven't been added.
# 183 languages haven't been added.
# 75 languages haven't been added.
# 8 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# 1 languages haven't been added.
# These languages are not added: Afro-Asiatic
#
#
# Afroasiatic
# ├── Chadic
# │   ├── Biu–Mandara
# │   │   ├── Bachama
# │   │   ├── Bana
# │   │   ├── Bata
# │   │   ├── Boga
# │   │   ├── Bura
# │   │   ├── Bura–Higi
# │   │   ├── Cibak
# │   │   ├── East
# │   │   │   ├── Glavda
# │   │   │   ├── Kachama-Ganjule
# │   │   │   │   ├── Ganjule
# │   │   │   │   ├── Gidicho
# │   │   │   │   └── Kachama
# │   │   │   ├── Koorete
# │   │   │   ├── Wandala
# │   │   │   └── Zayse-Zergulla
# │   │   ├── East–Central
# │   │   │   ├── Gidar
# │   │   │   └── Muskum
# │   │   │       ├── Mbara
# │   │   │       └── Musgu
# │   │   │           ├── BeegeJafga
# │   │   │           ├── Mpus
# │   │   │           └── VulumMulwi
# │   │   ├── Fali
# │   │   │   ├── BahuliFali of Bahuli
# │   │   │   ├── MadzarinFali of Muchalla
# │   │   │   ├── UramɓwiinFali of Bagira
# │   │   │   └── UroovinFali of Vimtim
# │   │   ├── Ga'anda
# │   │   │   └── Gabin
# │   │   ├── Gude
# │   │   ├── Gudu
# │   │   ├── Holma
# │   │   ├── Huba
# │   │   ├── Hwana
# │   │   ├── Hya
# │   │   ├── Jara
# │   │   ├── Jilbe
# │   │   ├── Jimi
# │   │   ├── Jina
# │   │   │   └── Muxule
# │   │   ├── Kamwe
# │   │   │   └── Psikye
# │   │   ├── Kirya-Konzəl
# │   │   ├── Majera
# │   │   ├── Marghi South
# │   │   ├── Margi
# │   │   ├── Matal
# │   │   ├── Nggwahyi
# │   │   ├── Ngwaba
# │   │   ├── North
# │   │   │   ├── Afade
# │   │   │   ├── Basketo
# │   │   │   ├── Buwal
# │   │   │   ├── Dorze
# │   │   │   ├── Gamo-Gofa-Dawro
# │   │   │   ├── Gavar
# │   │   │   ├── Malgbe
# │   │   │   ├── Mao
# │   │   │   │   ├── Bambassi
# │   │   │   │   ├── Ganza
# │   │   │   │   └── Hozo
# │   │   │   ├── Maroua
# │   │   │   │   └── Baldemu
# │   │   │   ├── Maslam
# │   │   │   ├── Massa
# │   │   │   ├── Melo
# │   │   │   ├── Mpadə
# │   │   │   ├── Musey–Azumeina
# │   │   │   │   └── Musey
# │   │   │   ├── Musey–Marba
# │   │   │   │   └── Marba
# │   │   │   ├── Oyda
# │   │   │   ├── Wolaita Language
# │   │   │   ├── Zala
# │   │   │   └── Zumaya
# │   │   ├── Northeast
# │   │   │   ├── Mbuko
# │   │   │   └── Vame
# │   │   ├── Nzanyi
# │   │   ├── Parkwa
# │   │   ├── Putai
# │   │   ├── Sharwa
# │   │   ├── South
# │   │   │   ├── Cuvok
# │   │   │   ├── Daba
# │   │   │   │   ├── Mazagway
# │   │   │   │   │   ├── KpalaKola
# │   │   │   │   │   └── MazagwayMusgoi
# │   │   │   │   ├── MazagwayMusgoy
# │   │   │   │   ├── Nive
# │   │   │   │   ├── Pologozom
# │   │   │   │   └── TpalaKola
# │   │   │   ├── Lagwan
# │   │   │   ├── Mafa
# │   │   │   ├── Maɗa
# │   │   │   ├── Mbudum
# │   │   │   ├── Mefele
# │   │   │   ├── Merey
# │   │   │   ├── Mesmé
# │   │   │   ├── Mina
# │   │   │   │   ├── Besleri
# │   │   │   │   ├── Gamdugun
# │   │   │   │   └── Jɨŋjɨŋ
# │   │   │   ├── Mofu-Gudur
# │   │   │   ├── Moloko
# │   │   │   ├── Msər
# │   │   │   ├── Muyang
# │   │   │   ├── North Giziga
# │   │   │   ├── North Mofu
# │   │   │   ├── Peve–Kaɗo
# │   │   │   │   ├── Ngeté-Herdé
# │   │   │   │   │   ├── Dzəpaw
# │   │   │   │   │   ├── He’dé
# │   │   │   │   │   └── Ngeté
# │   │   │   │   └── Pévé
# │   │   │   ├── South Giziga
# │   │   │   ├── Wuzlam
# │   │   │   ├── Zulgo-Gemzek
# │   │   │   │   ├── Gemzek
# │   │   │   │   └── Zəlgwa-Minew
# │   │   │   └── Ɗugwor
# │   │   │       └── Mikere
# │   │   ├── Sukur
# │   │   ├── Tera
# │   │   │   ├── Hinna and Deba
# │   │   │   └── PidlimdiKurba
# │   │   ├── Tsuvan
# │   │   ├── Wandala–Mafa
# │   │   ├── West
# │   │   │   ├── Dghweɗe
# │   │   │   ├── Guduf-Gava
# │   │   │   │   └── Cineni
# │   │   │   ├── Gvoko
# │   │   │   ├── Lamang
# │   │   │   │   ├── Hdi
# │   │   │   │   └── WogaWaha
# │   │   │   ├── Seze
# │   │   │   └── Vemgo-Mabas
# │   │   │       ├── Mabas
# │   │   │       └── Vemgo
# │   │   ├── Yedina
# │   │   │   ├── Buduma
# │   │   │   └── Kuri
# │   │   └── Zizilivakan
# │   ├── East Chadic
# │   │   ├── Barein
# │   │   ├── Bidiyo
# │   │   ├── Birgit
# │   │   ├── Boor
# │   │   ├── Dangaléat
# │   │   ├── Gabri
# │   │   │   ├── Buruwa
# │   │   │   ├── Darbe
# │   │   │   └── Moonde
# │   │   ├── Gadang
# │   │   ├── Jelkung
# │   │   ├── Jonkor Bourmataguil
# │   │   ├── Kabalai
# │   │   ├── Kajakse
# │   │   ├── Kera
# │   │   ├── Kimré
# │   │   ├── Kwang
# │   │   ├── Lele
# │   │   ├── Mabire
# │   │   ├── Masmaje
# │   │   ├── Mawa
# │   │   ├── Migaama
# │   │   ├── Miltu
# │   │   ├── Mire
# │   │   ├── Mogum
# │   │   ├── Mokilko
# │   │   ├── Mubi
# │   │   ├── Nancere
# │   │   ├── Ndam
# │   │   ├── Saba
# │   │   ├── Sarua
# │   │   ├── Sokoro
# │   │   ├── Somrai
# │   │   ├── Tamki
# │   │   ├── Tobanga
# │   │   ├── Toram
# │   │   ├── Tumak
# │   │   │   ├── Mawer
# │   │   │   └── Motun
# │   │   ├── Ubi
# │   │   └── Zirenkel
# │   ├── Masa
# │   └── West Chadic
# │       ├── Angas
# │       │   ├── Belnəng
# │       │   ├── Cakfem-Mushere
# │       │   ├── Chakato
# │       │   ├── Koenoem
# │       │   ├── Kofyar
# │       │   ├── Miship
# │       │   ├── Montol
# │       │   ├── Mwaghavul
# │       │   ├── Ngas
# │       │   ├── Nteng
# │       │   ├── Pan
# │       │   │   └── Jibyal
# │       │   ├── Pyapun
# │       │   └── Tal
# │       ├── Bade
# │       │   ├── Auyokawa
# │       │   ├── Ngizim
# │       │   ├── Teshenawa
# │       │   └── Ɗuwai
# │       ├── Bole–Tangale
# │       │   ├── Bole
# │       │   ├── Bure
# │       │   ├── Daza
# │       │   ├── Deno
# │       │   ├── Dera
# │       │   ├── Galambu
# │       │   ├── Gera
# │       │   ├── Geruma
# │       │   ├── Giiwo
# │       │   ├── Goji
# │       │   ├── Karai-Karai
# │       │   ├── Kubi
# │       │   ├── Kulung
# │       │   ├── Kwaami
# │       │   ├── Kúttò
# │       │   ├── Maaka
# │       │   ├── Ngamo
# │       │   ├── Nyam
# │       │   ├── Pali
# │       │   ├── Pero
# │       │   ├── Piya-Kwonci
# │       │   │   ├── Kwonci
# │       │   │   └── Piya
# │       │   ├── Tangale
# │       │   └── Ɓeele
# │       ├── Goemai
# │       │   ├── Dorok
# │       │   ├── Duut
# │       │   ├── East Ankwe
# │       │   └── K'wo
# │       ├── Hausa–Gwandara
# │       │   ├── Gwandara
# │       │   └── Hausa
# │       ├── North Bauchi
# │       │   ├── Ajawa
# │       │   ├── Ciwogai
# │       │   ├── Diri
# │       │   ├── Kariya
# │       │   ├── Mburku
# │       │   ├── Miya
# │       │   ├── Paʼa
# │       │   ├── Siri
# │       │   ├── Warji
# │       │   └── Zumbun
# │       ├── Poki
# │       ├── Ron
# │       │   ├── Duhwa
# │       │   ├── Fyer
# │       │   ├── Kulere
# │       │   ├── Mundat
# │       │   ├── Sha
# │       │   └── Tambas
# │       ├── South Bauchi
# │       │   ├── Boghom
# │       │   ├── Dass
# │       │   │   ├── Dot
# │       │   │   ├── Durr-Baraza
# │       │   │   ├── Lukshi
# │       │   │   ├── Wandi
# │       │   │   └── Zumbul
# │       │   ├── Geji
# │       │   │   ├── Buu
# │       │   │   └── Gyaazi & Mәgang
# │       │   ├── Guruntum
# │       │   ├── Ju
# │       │   ├── Kir-Balar
# │       │   ├── Mantsi
# │       │   ├── Saya
# │       │   │   ├── Sahng
# │       │   │   └── ZaarVigzar
# │       │   ├── Tala
# │       │   ├── Zangwal
# │       │   ├── Zari
# │       │   │   ├── Bibot
# │       │   │   ├── BotoBoot
# │       │   │   ├── Kwapm
# │       │   │   ├── ZakshiZaksa
# │       │   │   └── ZariKopti
# │       │   └── Zeem
# │       │       ├──  Lushi
# │       │       ├── Caari
# │       │       ├── Danshe
# │       │       ├── Dyarim
# │       │       └── Tule
# │       └── Yiwom
# ├── Cushitic
# │   ├── Agaw
# │   │   ├── Awngi
# │   │   │   └── Kunfäl
# │   │   └── Northern Agaw
# │   │       ├── Bilen
# │   │       ├── Qimant
# │   │       │   ├── Kayla
# │   │       │   └── Qwara
# │   │       └── Xamtanga
# │   ├── Beja
# │   ├── Dullay
# │   │   ├── Ale
# │   │   │   ├── Dihina
# │   │   │   ├── Gawwada proper
# │   │   │   ├── Gergere
# │   │   │   ├── Gollango
# │   │   │   ├── Gorose
# │   │   │   └── Harso
# │   │   ├── Dobase
# │   │   │   ├── DobaseGobeze
# │   │   │   ├── Lohu
# │   │   │   └── Mashole
# │   │   └── Tsamai
# │   ├── Highland East Cushitic
# │   │   └── Burji
# │   ├── Lowland East Cushitic
# │   │   ├── Boon
# │   │   ├── Dahalo
# │   │   ├── Omo–Tana
# │   │   │   ├── East Omo-Tana
# │   │   │   │   ├── Ashraaf
# │   │   │   │   ├── Aweer-Garre
# │   │   │   │   │   └── Aweer
# │   │   │   │   │       ├── Baddey
# │   │   │   │   │       ├── Bireeri
# │   │   │   │   │       ├── Kijee
# │   │   │   │   │       ├── Kilii
# │   │   │   │   │       └── Safaree
# │   │   │   │   ├── Baiso-Jiddu
# │   │   │   │   │   └── Baiso
# │   │   │   │   └── Girirra
# │   │   │   ├── Macro-Somali
# │   │   │   │   └── Rendille–Boni
# │   │   │   │       └── Rendille
# │   │   │   └── Western Omo–Tana
# │   │   │       ├── Arbore
# │   │   │       ├── Daasanach
# │   │   │       ├── El Molo
# │   │   │       └── Yaaku
# │   │   ├── Oromoid
# │   │   │   └── Oromo
# │   │   │       └── Southern Oromo
# │   │   │           └── Waata
# │   │   ├── Saho–Afar
# │   │   │   ├── Afar
# │   │   │   └── Saho
# │   │   └── Somali
# │   │       ├── Benaadir
# │   │       ├── Jiiddu
# │   │       ├── Mai-Mai
# │   │       │   └── RaxanweynReewin
# │   │       │       ├── Af-Garre
# │   │       │       ├── Dabarre
# │   │       │       └── Tunni
# │   │       └── Northern Somali
# │   └── South Cushitic
# │       ├── East Rift
# │       │   ├── Asa
# │       │   └── Kwʼadza
# │       ├── Rift
# │       │   └── West Rift
# │       │       ├── Burunge
# │       │       └── NW Rift
# │       │           ├── Alagwa
# │       │           └── Iraqwoid
# │       │               ├── Gorowa
# │       │               └── Iraqw
# │       └── Taita Cushitic
# ├── Egyptian
# │   ├──  Lower
# │   ├──  Upper
# │   ├── Coptic
# │   │   ├── Akhmimic
# │   │   ├── Bohairic
# │   │   ├── Fayyumic
# │   │   ├── Lycopolitan
# │   │   ├── Oxyrhynchite
# │   │   └── Sahidic
# │   ├── Coptic dialects
# │   └── Late Egyptian
# ├── Kujargé
# ├── North Afroasiatic
# ├── Omotic
# │   ├── Aroid
# │   │   ├── Aari
# │   │   ├── Dime
# │   │   ├── Gayil
# │   │   └── Hamer-Banna
# │   │       ├── Banna
# │   │       ├── Hamer
# │   │       └── Karo
# │   ├── Bosha
# │   └── North Omotic
# │       ├── Bench
# │       │   ├── Benc NonBenesho
# │       │   ├── MerMieru
# │       │   └── SheKaba
# │       ├── Dizoid
# │       │   ├── Dizin
# │       │   ├── Nayi
# │       │   └── Sheko
# │       ├── Gonga
# │       │   ├── Anfillo
# │       │   ├── Kafa–Shekkacho
# │       │   │   ├── Kafa
# │       │   │   └── Shekkacho
# │       │   └── Shinasha
# │       │       ├── Amuru
# │       │       ├── Gamila
# │       │       ├── Guba
# │       │       └── Wembera
# │       ├── Ometo
# │       │   ├── Chara
# │       │   └── Maale
# │       └── Yem
# │           └── Fuga
# ├── Semitic
# │   ├── East Semitic
# │   │   ├── Akkadian
# │   │   └── Eblaite
# │   ├── Sutean
# │   └── West Semitic
# │       ├── Central Semitic
# │       │   ├── Arabic
# │       │   │   ├── Classical Arabic
# │       │   │   ├── Modern Standard Arabic
# │       │   │   ├── Old Hejazi
# │       │   │   ├── Shirvani Arabic
# │       │   │   └── Varieties of Arabic
# │       │   │       ├── Central Asian Arabic
# │       │   │       │   ├── Bakhtiari
# │       │   │       │   ├── Bukharian
# │       │   │       │   ├── Kashkadarian
# │       │   │       │   ├── Khorasani
# │       │   │       │   └── Khorasani Arabic
# │       │   │       ├── Egyptian Arabic
# │       │   │       │   ├── Judeo-Egyptian Arabic
# │       │   │       │   └── Upper Egyptian Arabic
# │       │   │       ├── Levantine Arabic
# │       │   │       │   ├── North Levantine
# │       │   │       │   ├── North Levantine Arabic
# │       │   │       │   │   ├── Damascus Arabic
# │       │   │       │   │   ├── Lebanese Arabic
# │       │   │       │   │   │   ├── Beqaa Arabic
# │       │   │       │   │   │   ├── Iqlim-Al-Kharrub Sunni Arabic
# │       │   │       │   │   │   ├── Jdaideh Arabic
# │       │   │       │   │   │   ├── North Lebanese Arabic
# │       │   │       │   │   │   ├── North-Central Lebanese Arabic
# │       │   │       │   │   │   ├── Saida Sunni Arabic
# │       │   │       │   │   │   ├── South Lebanese Arabic
# │       │   │       │   │   │   ├── South-Central Lebanese Arabic
# │       │   │       │   │   │   └── Sunni Beiruti Arabic
# │       │   │       │   │   ├── Syrian Arabic
# │       │   │       │   │   └── Çukurova Arabic
# │       │   │       │   ├── South Levantine
# │       │   │       │   └── South Levantine Arabic
# │       │   │       │       ├── Jordanian Arabic
# │       │   │       │       │   ├── Fellahirural
# │       │   │       │       │   └── Madaniurban
# │       │   │       │       └── Palestinian Arabic
# │       │   │       │           ├── Fellahi
# │       │   │       │           └── Madani
# │       │   │       ├── Maghrebi Arabic
# │       │   │       │   ├── Algerian Arabic
# │       │   │       │   │   ├── Eastern Algerian Arabic
# │       │   │       │   │   ├── Western Algerian
# │       │   │       │   │   └── Western Algerian Arabic
# │       │   │       │   ├── Algerian Saharan Arabic
# │       │   │       │   ├── Andalusi Arabic
# │       │   │       │   ├── Hilalian dialects
# │       │   │       │   ├── Jebli
# │       │   │       │   ├── Jijeli
# │       │   │       │   ├── Judeo-Tripolitanian Arabic
# │       │   │       │   ├── Judeo-Tunisian Arabic
# │       │   │       │   ├── Libyan Arabic
# │       │   │       │   ├── Moroccan Arabic
# │       │   │       │   │   ├── East Moroccan Arabic
# │       │   │       │   │   ├── Judeo-Moroccan Arabic
# │       │   │       │   │   └── West Moroccan Arabic
# │       │   │       │   ├── Siculo-Arabic
# │       │   │       │   │   └── Maltese
# │       │   │       │   │       ├── Australian
# │       │   │       │   │       ├── Gozitan
# │       │   │       │   │       ├── Maltralian
# │       │   │       │   │       ├── Qormi
# │       │   │       │   │       ├── Qormi dialect
# │       │   │       │   │       ├── Żejtun dialect
# │       │   │       │   │       └── Żejtuni
# │       │   │       │   ├── Tunisian
# │       │   │       │   └── Ḥassānīya
# │       │   │       │       ├── Imraguen
# │       │   │       │       └── Nemadi
# │       │   │       ├── Mashriqi Arabic
# │       │   │       ├── Mesopotamian Arabic
# │       │   │       │   ├── Baghdadi Arabic
# │       │   │       │   ├── Khuzestani Arabic
# │       │   │       │   ├── North Mesopotamian Arabic
# │       │   │       │   │   ├── Anatolian Arabic
# │       │   │       │   │   ├── Cypriot Arabic
# │       │   │       │   │   ├── Jewish Baghdadi Arabic
# │       │   │       │   │   ├── Judeo-Arabic
# │       │   │       │   │   │   └── Judeo-Iraqi Arabic
# │       │   │       │   │   │       └── Baghdad Jewish Arabic
# │       │   │       │   │   └── Siirt–Muş–Batman
# │       │   │       │   └── South Mesopotamian Arabic
# │       │   │       ├── Northwest Arabian Arabic
# │       │   │       ├── Old Arabic
# │       │   │       │   └── Hismaic
# │       │   │       ├── Peninsular
# │       │   │       │   └── Bareqi Arabic
# │       │   │       ├── Peninsular Arabic
# │       │   │       │   ├── Bahrani Arabic
# │       │   │       │   │   └── Bahrani
# │       │   │       │   ├── Dhofari Arabic
# │       │   │       │   ├── Gulf Arabic
# │       │   │       │   │   └── Emirati Arabic
# │       │   │       │   │       └── Shihhi Arabic
# │       │   │       │   ├── Hejazi Arabic
# │       │   │       │   ├── Najdi Arabic
# │       │   │       │   ├── Omani Arabic
# │       │   │       │   └── Yemeni Arabic
# │       │   │       │       ├── Hadrami Arabic
# │       │   │       │       ├── Judeo-Yemeni Arabic
# │       │   │       │       ├── Sanʽani Arabic
# │       │   │       │       └── Taʽizzi-Adeni Arabic
# │       │   │       │           ├── Adeni Arabic
# │       │   │       │           └── Ta'izzi Arabic
# │       │   │       └── Sudanese Arabic
# │       │   │           └── Chadian Arabic
# │       │   ├── Dadanitic
# │       │   └── Northwest Semitic
# │       │       ├── Amorite
# │       │       │   └── Ugaritic
# │       │       ├── Aramaic
# │       │       │   ├── Eastern Aramaic
# │       │       │   │   ├── Central Neo-Aramaic
# │       │       │   │   │   ├── Mlaḥsô
# │       │       │   │   │   └── Turoyo
# │       │       │   │   ├── Northeastern Neo-Aramaic
# │       │       │   │   │   ├── Barzani Jewish Neo-Aramaic
# │       │       │   │   │   ├── Hertevin
# │       │       │   │   │   ├── Hulaulá
# │       │       │   │   │   ├── Inter-Zab Jewish Neo-Aramaic
# │       │       │   │   │   ├── Koy Sanjaq Surat
# │       │       │   │   │   ├── Lishán Didán
# │       │       │   │   │   └── Suret
# │       │       │   │   │       ├── Bohtan Neo-Aramaic
# │       │       │   │   │       ├── Jilu
# │       │       │   │   │       ├── Nineveh; others
# │       │       │   │   │       ├── Senaya
# │       │       │   │   │       ├── Tyari; SouthernArbela
# │       │       │   │   │       └── Urmian including Urban Koine; Nōčiyay; Hakkari groupsBarwari
# │       │       │   │   ├── Southeastern Aramaic
# │       │       │   │   │   └── Mandaic
# │       │       │   │   │       └── Neo-Mandaic
# │       │       │   │   ├── Southeastern Eastern Aramaic
# │       │       │   │   │   └── Babylonian Aramaic
# │       │       │   │   └── Syriac
# │       │       │   ├── Hatran
# │       │       │   ├── Neo-Aramaic
# │       │       │   │   └── Lishana Deni
# │       │       │   ├── Old Aramaic
# │       │       │   └── Western Aramaic
# │       │       │       ├── Jewish Palestinian Aramaic
# │       │       │       ├── Nabataean Aramaic
# │       │       │       ├── Palestinian Aramaic
# │       │       │       │   └── Samaritan Aramaic
# │       │       │       ├── Palmyrene Aramaic
# │       │       │       └── Western Neo-Aramaic
# │       │       ├── Canaanite
# │       │       │   ├── Ammonite
# │       │       │   ├── Biblical Hebrew
# │       │       │   ├── Edomite
# │       │       │   ├── Hebrew
# │       │       │   │   └── Modern Hebrew
# │       │       │   ├── Medieval Hebrew
# │       │       │   ├── Mishnaic Hebrew
# │       │       │   ├── Moabite
# │       │       │   └── Phoenician
# │       │       │       └── Punic
# │       │       ├── Samalian
# │       │       └── Taymanitic
# │       └── South Semitic
# │           ├── Ethiopian Semitic
# │           │   ├── North Ethiopic
# │           │   │   ├── Geʽez
# │           │   │   │   └── Dahalik
# │           │   │   └── Tigrinya
# │           │   └── South Ethiopic
# │           │       ├── Outer South Ethiopic
# │           │       │   ├── North Gurage
# │           │       │   │   └── Soddo
# │           │       │   │       └── GoggotDobi
# │           │       │   ├── West Gurage
# │           │       │   │   └── Mesqan
# │           │       │   └── n-group
# │           │       │       └── Gafat
# │           │       └── Transversal South Ethiopic
# │           │           ├── Amharic–Argobba
# │           │           │   ├── Amharic
# │           │           │   └── Argobba
# │           │           ├── Harari – East Gurage
# │           │           │   ├── East Gurage
# │           │           │   │   ├── Inor
# │           │           │   │   ├── Mesmes
# │           │           │   │   ├── Muher
# │           │           │   │   ├── Sebat Bet Gurage
# │           │           │   │   │   └── Chaha
# │           │           │   │   ├── Siltʼe
# │           │           │   │   └── Zay
# │           │           │   └── Harari
# │           │           └── Harari–East Gurage
# │           ├── Modern South Arabian
# │           │   ├── Baṭḥari
# │           │   ├── Harsusi
# │           │   ├── Hobyot
# │           │   ├── Mehri
# │           │   ├── Shehri
# │           │   └── Soqoṭri
# │           ├── Old South Arabian
# │           │   ├── Faifi
# │           │   ├── Hadhramautic
# │           │   ├── Himyaritic
# │           │   ├── Minaean
# │           │   ├── Qatabānian
# │           │   ├── Razihi
# │           │   └── Sabaic
# │           └── Western South Semitic
# └── Tamazight
#     ├── Eastern Berber
#     │   ├── Awjila Berber language
#     │   ├── Ghadamès
#     │   │   ├── Ayt Ulid
#     │   │   └── Ayt Waziten
#     │   ├── Nafusi
#     │   ├── Siwi
#     │   ├── Sokna
#     │   │   ├── FezzanFoqaha
#     │   │   └── Tmessa
#     │   └── Zurg
#     ├── Guanche
#     ├── Northern Berber
#     │   ├── Atlas languages
#     │   │   ├── Central Atlas Tamazight
#     │   │   ├── Ghomara
#     │   │   ├── Sanhaja de Srair
#     │   │   └── Shilha
#     │   ├── Kabyle
#     │   ├── Standard Moroccan Amazigh
#     │   └── Zenati
#     │       ├── Beni Snous
#     │       ├── East Zenati
#     │       │   ├── Jerba
#     │       │   ├── Matmata Berber
#     │       │   ├── Sened
#     │       │   └── Zuwara
#     │       ├── Eastern Middle Atlas Berber
#     │       │   ├── Ait Seghrouchen Berber
#     │       │   ├── Ayt Seghrushen
#     │       │   └── Ayt Warayn etc.
#     │       ├── Eastern Morocco Zenati
#     │       ├── Iznasen
#     │       ├── Mzab–Wargla
#     │       │   ├── Gurara
#     │       │   ├── Mozabite
#     │       │   ├── Ouargli
#     │       │   ├── South Oran and Figuig Berber
#     │       │   ├── Tidikelt Tamazight
#     │       │   ├── Tugurt
#     │       │   └── Tuwat
#     │       ├── Riff
#     │       ├── Shawiya
#     │       ├── Shenwa
#     │       └── Tarifit
#     ├── Numidian
#     │   ├── East-Numidian
#     │   ├── Gaetulian
#     │   ├── Mauretanian
#     │   └── West-Numidian
#     ├── Tuareg
#     │   ├── Northern Tuareg
#     │   │   └── Tamahaq
#     │   └── Southern Tuareg
#     │       ├── Tamashek
#     │       ├── Tawellemmet
#     │       └── Tayart
#     │           ├── AirTayiṛt
#     │           └── TanassfarwatTamagarast
#     └── Western Berber
#         ├── Tetserret
#         └── Zenaga
